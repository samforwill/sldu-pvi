# %%
import pandas as pd
import os
import geopandas as gpd

# %% [markdown]
# Now that I've assigned a PVI-score to all the State Legislative Districts' Upper chambers, it's time to set about mapping to create a chloropleth map.
#
# First I downloaded all the shapefiles for State Legislative Districts from the Census Bureau [here](https://www2.census.gov/geo/tiger/TIGER2023/SLDU/)
#
# The shapefiles had to be downloaded individually state-by-state and unzipped. The naming conventions followed the Federal Information Processing System (FIPS) Codes for States and Counties, so "tl_2023_01_sldu" corresponds to Alabama (01). In each folder were 7 files, but I want to start off by explowing the shapefile, which has the extension .shp to see how to relate my PVI scores Dataframe to the shapefile to merge those scores on.

# %%
# Path to the shapefile
shapefile_path = 'data/sldu_shapefiles/original/tl_2023_01_sldu/tl_2023_01_sldu.shp'

# Load the shapefile
gdf = gpd.read_file(shapefile_path)

# Display the first few rows of the GeoDataFrame
print(gdf.head())
# Out:
#   STATEFP SLDUST  GEOID         GEOIDFQ                  NAMELSAD LSAD   LSY  \
# 0      01    004  01004  610U800US01004   State Senate District 4   LU  2022
# 1      01    026  01026  610U800US01026  State Senate District 26   LU  2022
# 2      01    005  01005  610U800US01005   State Senate District 5   LU  2022
# 3      01    027  01027  610U800US01027  State Senate District 27   LU  2022
# 4      01    028  01028  610U800US01028  State Senate District 28   LU  2022
#
#    MTFCC FUNCSTAT       ALAND     AWATER     INTPTLAT      INTPTLON  \
# 0  G5210        N  5413280608  104587341  +34.1280167  -087.3603043
# 1  G5210        N   733846256   24874680  +32.3151157  -086.3030980
# 2  G5210        N  7446353264  104880595  +33.6831584  -087.5989849
# 3  G5210        N  2832119021   97219299  +32.7206526  -085.6135364
# 4  G5210        N  8420147207   98988580  +31.9939325  -085.4502090
#
#                                             geometry
# 0  POLYGON ((-88.20722 34.05840, -88.20711 34.059...
# 1  POLYGON ((-86.49853 32.33975, -86.49850 32.339...
# 2  POLYGON ((-88.27459 33.53425, -88.27450 33.534...
# 3  POLYGON ((-86.00917 33.09026, -86.00717 33.090...
# 4  POLYGON ((-86.02316 32.41927, -86.02312 32.419...

# %% [markdown]
# Great, so first I can immediately see that GEOIDFQ may correspond directly to my previous Dataframe's 'GEOID' column. Let's load the PVI dataframe

# %%
pvi_df = pd.read_csv('data/sldu_pvi_adjusted.csv')
pvi_df.head(50)
# Out:
#     Unnamed: 0           GEOID        PVI  \
# 0            0  610U800US0200A  -9.685082
# 1            1  610U800US0200B   6.186881
# 2            2  610U800US0200C  -3.191946
# 3            3  610U800US0200D -22.635338
# 4            4  610U800US0200E   4.823058
# 5            5  610U800US0200F   1.524090
# 6            6  610U800US0200G   0.068112
# 7            7  610U800US0200H  -2.752143
# 8            8  610U800US0200I  14.371795
# 9            9  610U800US0200J  20.299703
# 10          10  610U800US0200K   4.064564
# 11          11  610U800US0200L -17.878620
# 12          12  610U800US0200M -21.792577
# 13          13  610U800US0200N -24.044383
# 14          14  610U800US0200O -11.109221
# 15          15  610U800US0200P -23.695810
# 16          16  610U800US0200Q -20.966242
# 17          17  610U800US0200R  -0.943336
# 18          18  610U800US0200S  24.010341
# 19          19  610U800US0200T  22.373751
# 20          20  610U800US01001 -21.444727
# 21          21  610U800US01002  -2.755100
# 22          22  610U800US01003 -18.106662
# 23          23  610U800US01004 -31.609660
# 24          24  610U800US01005 -35.588052
# 25          25  610U800US01006 -25.397709
# 26          26  610U800US01007  -3.031428
# 27          27  610U800US01008 -22.877885
# 28          28  610U800US01009 -25.386094
# 29          29  610U800US01010 -20.750518
# 30          30  610U800US01011 -23.639833
# 31          31  610U800US01012 -12.934532
# 32          32  610U800US01013 -16.424010
# 33          33  610U800US01014 -19.946762
# 34          34  610U800US01015 -14.136788
# 35          35  610U800US01016  -8.751649
# 36          36  610U800US01017 -30.897839
# 37          37  610U800US01018  25.141705
# 38          38  610U800US01019  12.921479
# 39          39  610U800US01020  20.680963
# 40          40  610U800US01021  -4.515492
# 41          41  610U800US01022 -19.362707
# 42          42  610U800US01023   1.447150
# 43          43  610U800US01024   1.955320
# 44          44  610U800US01025 -13.839292
# 45          45  610U800US01026  25.843760
# 46          46  610U800US01027  -1.992014
# 47          47  610U800US01028   6.907190
# 48          48  610U800US01029 -24.193884
# 49          49  610U800US01030 -17.309760
#
#                         Formatted_District
# 0   State Senate District A (2022), Alaska
# 1   State Senate District B (2022), Alaska
# 2   State Senate District C (2022), Alaska
# 3   State Senate District D (2022), Alaska
# 4   State Senate District E (2022), Alaska
# 5   State Senate District F (2022), Alaska
# 6   State Senate District G (2022), Alaska
# 7   State Senate District H (2022), Alaska
# 8   State Senate District I (2022), Alaska
# 9   State Senate District J (2022), Alaska
# 10  State Senate District K (2022), Alaska
# 11  State Senate District L (2022), Alaska
# 12  State Senate District M (2022), Alaska
# 13  State Senate District N (2022), Alaska
# 14  State Senate District O (2022), Alaska
# 15  State Senate District P (2022), Alaska
# 16  State Senate District Q (2022), Alaska
# 17  State Senate District R (2022), Alaska
# 18  State Senate District S (2022), Alaska
# 19  State Senate District T (2022), Alaska
# 20                               AL-Sen-01
# 21                               AL-Sen-02
# 22                               AL-Sen-03
# 23                               AL-Sen-04
# 24                               AL-Sen-05
# 25                               AL-Sen-06
# 26                               AL-Sen-07
# 27                               AL-Sen-08
# 28                               AL-Sen-09
# 29                               AL-Sen-10
# 30                               AL-Sen-11
# 31                               AL-Sen-12
# 32                               AL-Sen-13
# 33                               AL-Sen-14
# 34                               AL-Sen-15
# 35                               AL-Sen-16
# 36                               AL-Sen-17
# 37                               AL-Sen-18
# 38                               AL-Sen-19
# 39                               AL-Sen-20
# 40                               AL-Sen-21
# 41                               AL-Sen-22
# 42                               AL-Sen-23
# 43                               AL-Sen-24
# 44                               AL-Sen-25
# 45                               AL-Sen-26
# 46                               AL-Sen-27
# 47                               AL-Sen-28
# 48                               AL-Sen-29
# 49                               AL-Sen-30

# %%
pvi_df[pvi_df['Formatted_District'] == 'AL-Sen-04']
# Out:
#     Unnamed: 0           GEOID       PVI Formatted_District
# 23          23  610U800US01004 -31.60966          AL-Sen-04

# %% [markdown]
# Ok, I confirmed the GEOID in my PVI Datframe, pvi_df, is an exact match to the GEOIDFQ in the GeoDataFrame, gdf. Time to attach the PVI scores

# %%
# filter and rename columns for merging, I don't need all the demographic info anymore
pvi_filtered = pvi_df[['GEOID', 'Formatted_District', 'PVI']]
pvi_filtered = pvi_filtered.rename(columns={'PVI': 'pred_PVI',
                                           'Formatted_District': 'district'}) #ESRI column names can only have 10 characters

# Merge the filtered DataFrame info to the gdf
merged_gdf = gdf.merge(pvi_filtered, left_on='GEOIDFQ', right_on='GEOID', how='left')


print(merged_gdf.head())
# Out:
#   STATEFP SLDUST GEOID_x         GEOIDFQ                  NAMELSAD LSAD   LSY  \
# 0      01    004   01004  610U800US01004   State Senate District 4   LU  2022
# 1      01    026   01026  610U800US01026  State Senate District 26   LU  2022
# 2      01    005   01005  610U800US01005   State Senate District 5   LU  2022
# 3      01    027   01027  610U800US01027  State Senate District 27   LU  2022
# 4      01    028   01028  610U800US01028  State Senate District 28   LU  2022
#
#    MTFCC FUNCSTAT       ALAND     AWATER     INTPTLAT      INTPTLON  \
# 0  G5210        N  5413280608  104587341  +34.1280167  -087.3603043
# 1  G5210        N   733846256   24874680  +32.3151157  -086.3030980
# 2  G5210        N  7446353264  104880595  +33.6831584  -087.5989849
# 3  G5210        N  2832119021   97219299  +32.7206526  -085.6135364
# 4  G5210        N  8420147207   98988580  +31.9939325  -085.4502090
#
#                                             geometry         GEOID_y  \
# 0  POLYGON ((-88.20722 34.05840, -88.20711 34.059...  610U800US01004
# 1  POLYGON ((-86.49853 32.33975, -86.49850 32.339...  610U800US01026
# 2  POLYGON ((-88.27459 33.53425, -88.27450 33.534...  610U800US01005
# 3  POLYGON ((-86.00917 33.09026, -86.00717 33.090...  610U800US01027
# 4  POLYGON ((-86.02316 32.41927, -86.02312 32.419...  610U800US01028
#
#     district   pred_PVI
# 0  AL-Sen-04 -31.609660
# 1  AL-Sen-26  25.843760
# 2  AL-Sen-05 -35.588052
# 3  AL-Sen-27  -1.992014
# 4  AL-Sen-28   6.907190

# %%
# Define the path for the new shapefile
output_path = 'data/sldu_shapefiles/processed/AL_SLDU/AL_SLDU_PVI.shp'

# Save the merged GeoDataFrame as a new shapefile
merged_gdf.to_file(output_path, driver='ESRI Shapefile')

# %% [markdown]
# ### Add my NC-specific things

# %%
nc_pvi = pd.read_csv('data/nc_pvi.csv')

# %% [markdown]
# Ok, so now we can create a system based on our above steps to iterate over all the other state codes. First, let's map the FIPS codes to the states

# %%
fips_to_state = {
    '01': 'AL', '02': 'AK', '04': 'AZ', '05': 'AR', '06': 'CA',
    '08': 'CO', '09': 'CT', '10': 'DE', '11': 'DC', '12': 'FL',
    '13': 'GA', '15': 'HI', '16': 'ID', '17': 'IL', '18': 'IN',
    '19': 'IA', '20': 'KS', '21': 'KY', '22': 'LA', '23': 'ME',
    '24': 'MD', '25': 'MA', '26': 'MI', '27': 'MN', '28': 'MS',
    '29': 'MO', '30': 'MT', '31': 'NE', '32': 'NV', '33': 'NH',
    '34': 'NJ', '35': 'NM', '36': 'NY', '37': 'NC', '38': 'ND',
    '39': 'OH', '40': 'OK', '41': 'OR', '42': 'PA', '44': 'RI',
    '45': 'SC', '46': 'SD', '47': 'TN', '48': 'TX', '49': 'UT',
    '50': 'VT', '51': 'VA', '53': 'WA', '54': 'WV', '55': 'WI',
    '56': 'WY', '72': 'PR'  # Including Puerto Rico
}

# %% [markdown]
# This following code automates the process of merging the predicted PVI sccores with the shapefiles for each state's legislative upper chambers (SLDU). Steps:
# 1. Iterate over each state using a dictionary map above of FIPS codes to state abbreviations.
# 2. Use the FIPS codes to identify file paths for input shapefiles and output directories based on these codes.
# 3. Check if the output folder exists and creating it if not
# 4. Load the shapefiles and PVI data, filtering and renaming columns to be less than 10-characters according to ESRI column naming requirements
# 5. Merge the PVI and District onto the geographic data of the shapefiles
# 6. Save the merged data as new shapefiles in state-specific folders.

# %%
# Directory where all the shapefiles are stored
base_input_path = 'data/sldu_shapefiles/original/'
base_output_path = 'data/sldu_shapefiles/processed/'

# Iterate over each state in the FIPS code dictionary
for fips, state_abbr in fips_to_state.items():
    input_path = f"{base_input_path}tl_2023_{fips}_sldu/tl_2023_{fips}_sldu.shp"
    output_dir = f"{base_output_path}{state_abbr}_SLDU"
    output_path = f"{output_dir}/{state_abbr}_SLDU_PVI.shp"

    # Check if the output directory exists, create if not
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Load the shapefile
    gdf = gpd.read_file(input_path)
    
    # Prepare PVI data (filtering and renaming)
    pvi_filtered = pvi_df[pvi_df['GEOID'].apply(lambda x: x.split('US')[-1][:2] == fips)] #the FIPS code is after the 'US' in the GEOID
    pvi_filtered = pvi_filtered[['GEOID', 'Formatted_District', 'PVI']].rename(columns={
        'PVI': 'pred_PVI',  # Ensure this is within 10 characters
        'Formatted_District': 'district'  # Ensure this is within 10 characters
    })
    
    # Merge the GeoDataFrame with the PVI DataFrame
    merged_gdf = gdf.merge(pvi_filtered, left_on='GEOIDFQ', right_on='GEOID', how='left')
    
    # Save the merged GeoDataFrame as a new shapefile
    merged_gdf.to_file(output_path, driver='ESRI Shapefile')
    
    print(f"Processed and saved shapefile for {state_abbr}")
# Out:
# Processed and saved shapefile for AL
# Processed and saved shapefile for AK
# Processed and saved shapefile for AZ
# Processed and saved shapefile for AR
# Processed and saved shapefile for CA
# Processed and saved shapefile for CO
# Processed and saved shapefile for CT
# Processed and saved shapefile for DE
# Processed and saved shapefile for DC
# Processed and saved shapefile for FL
# Processed and saved shapefile for GA
# Processed and saved shapefile for HI
# Processed and saved shapefile for ID
# Processed and saved shapefile for IL
# Processed and saved shapefile for IN
# Processed and saved shapefile for IA
# Processed and saved shapefile for KS
# Processed and saved shapefile for KY
# Processed and saved shapefile for LA
# Processed and saved shapefile for ME
# Processed and saved shapefile for MD
# Processed and saved shapefile for MA
# Processed and saved shapefile for MI
# Processed and saved shapefile for MN
# Processed and saved shapefile for MS
# Processed and saved shapefile for MO
# Processed and saved shapefile for MT
# Processed and saved shapefile for NE
# Processed and saved shapefile for NV
# Processed and saved shapefile for NH
# Processed and saved shapefile for NJ
# Processed and saved shapefile for NM
# Processed and saved shapefile for NY
# Processed and saved shapefile for NC
# Processed and saved shapefile for ND
# Processed and saved shapefile for OH
# Processed and saved shapefile for OK
# Processed and saved shapefile for OR
# Processed and saved shapefile for PA
# Processed and saved shapefile for RI
# Processed and saved shapefile for SC
# Processed and saved shapefile for SD
# Processed and saved shapefile for TN
# Processed and saved shapefile for TX
# Processed and saved shapefile for UT
# Processed and saved shapefile for VT
# Processed and saved shapefile for VA
# Processed and saved shapefile for WA
# Processed and saved shapefile for WV
# Processed and saved shapefile for WI
# Processed and saved shapefile for WY
# Processed and saved shapefile for PR

# %% [markdown]
# ## Add my NC-specific things to that shapefile

# %%
nc_pvi = pd.read_csv('data/nc_pvi.csv')

# %%
nc_pvi
# Out:
#     Unnamed: 0           GEOID   district   pred_PVI  District_Number  \
# 0            0  610U800US37001  NC-Sen-01 -19.280423                1
# 1            1  610U800US37002  NC-Sen-02 -10.854440                2
# 2            2  610U800US37003  NC-Sen-03  -4.840893                3
# 3            3  610U800US37004  NC-Sen-04  -6.718213                4
# 4            4  610U800US37005  NC-Sen-05   6.734699                5
# 5            5  610U800US37006  NC-Sen-06 -19.080914                6
# 6            6  610U800US37007  NC-Sen-07  -2.557613                7
# 7            7  610U800US37008  NC-Sen-08 -15.614870                8
# 8            8  610U800US37009  NC-Sen-09 -15.626561                9
# 9            9  610U800US37010  NC-Sen-10 -19.624622               10
# 10          10  610U800US37011  NC-Sen-11  -7.069531               11
# 11          11  610U800US37012  NC-Sen-12 -14.977336               12
# 12          12  610U800US37013  NC-Sen-13   4.380787               13
# 13          13  610U800US37014  NC-Sen-14  14.450182               14
# 14          14  610U800US37015  NC-Sen-15  11.364032               15
# 15          15  610U800US37016  NC-Sen-16   3.572904               16
# 16          16  610U800US37017  NC-Sen-17 -11.195215               17
# 17          17  610U800US37018  NC-Sen-18  -4.582513               18
# 18          18  610U800US37019  NC-Sen-19  -3.218117               19
# 19          19  610U800US37020  NC-Sen-20   7.980420               20
# 20          20  610U800US37021  NC-Sen-21  -2.676076               21
# 21          21  610U800US37022  NC-Sen-22  13.692756               22
# 22          22  610U800US37023  NC-Sen-23   4.788501               23
# 23          23  610U800US37024  NC-Sen-24  -1.134348               24
# 24          24  610U800US37025  NC-Sen-25 -13.956067               25
# 25          25  610U800US37026  NC-Sen-26 -18.204487               26
# 26          26  610U800US37027  NC-Sen-27  -2.584828               27
# 27          27  610U800US37028  NC-Sen-28  17.573601               28
# 28          28  610U800US37029  NC-Sen-29 -18.874399               29
# 29          29  610U800US37030  NC-Sen-30 -26.112223               30
# 30          30  610U800US37031  NC-Sen-31 -10.000738               31
# 31          31  610U800US37032  NC-Sen-32   3.459034               32
# 32          32  610U800US37033  NC-Sen-33 -23.413607               33
# 33          33  610U800US37034  NC-Sen-34  -9.525924               34
# 34          34  610U800US37035  NC-Sen-35 -15.595868               35
# 35          35  610U800US37036  NC-Sen-36 -31.169909               36
# 36          36  610U800US37037  NC-Sen-37 -15.376429               37
# 37          37  610U800US37038  NC-Sen-38  27.214759               38
# 38          38  610U800US37039  NC-Sen-39  10.838447               39
# 39          39  610U800US37040  NC-Sen-40  15.523467               40
# 40          40  610U800US37041  NC-Sen-41  11.243860               41
# 41          41  610U800US37042  NC-Sen-42  -1.616908               42
# 42          42  610U800US37043  NC-Sen-43 -14.600084               43
# 43          43  610U800US37044  NC-Sen-44 -26.506825               44
# 44          44  610U800US37045  NC-Sen-45 -25.798338               45
# 45          45  610U800US37046  NC-Sen-46 -20.301126               46
# 46          46  610U800US37047  NC-Sen-47 -20.294515               47
# 47          47  610U800US37048  NC-Sen-48 -22.351541               48
# 48          48  610U800US37049  NC-Sen-49  -4.084548               49
# 49          49  610U800US37050  NC-Sen-50 -22.789365               50
#
#     pred_PVI_shifted predicted_party Party  District                 Member  \
# 0         -13.030423      Republican     R         1    Norman W. Sanderson
# 1          -4.604440      Republican     R         2              Jim Perry
# 2           1.409107      Democratic     R         3            Bobby Hanig
# 3          -0.468213      Republican     R         4            Buck Newton
# 4          12.984699      Democratic     D         5        Kandie D. Smith
# 5         -12.830914      Republican     R         6     Michael A. Lazzara
# 6           3.692387      Democratic     R         7         Michael V. Lee
# 7          -9.364870      Republican     R         8             Bill Rabon
# 8          -9.376561      Republican     R         9          Brent Jackson
# 9         -13.374622      Republican     R        10       Benton G. Sawrey
# 10         -0.819531      Republican     R        11         Lisa S. Barnes
# 11         -8.727336      Republican     R        12             Jim Burgin
# 12         10.630787      Democratic     D        13         Lisa Grafstein
# 13         20.700182      Democratic     D        14               Dan Blue
# 14         17.614032      Democratic     D        15       Jay J. Chaudhuri
# 15          9.822904      Democratic     D        16            Gale Adcock
# 16         -4.945215      Republican     D        17           Sydney Batch
# 17          1.667487      Democratic     D        18        Mary Wills Bode
# 18          3.031883      Democratic     D        19         Val Applewhite
# 19         14.230420      Democratic     D        20     Natalie S. Murdock
# 20          3.573924      Democratic     R        21            Tom McInnis
# 21         19.942756      Democratic     D        22           Mike Woodard
# 22         11.038501      Democratic     D        23            Graig Meyer
# 23          5.115652      Democratic     R        24  Danny Earl Britt, Jr.
# 24         -7.706067      Republican     R        25           Amy S. Galey
# 25        -11.954487      Republican     R        26            Phil Berger
# 26          3.665172      Democratic     D        27        Michael Garrett
# 27         23.823601      Democratic     D        28     Gladys A. Robinson
# 28        -12.624399      Republican     R        29   David W. Craven, Jr.
# 29        -19.862223      Republican     R        30           Steve Jarvis
# 30         -3.750738      Republican     R        31          Joyce Krawiec
# 31          9.709034      Democratic     D        32      Paul A. Lowe, Jr.
# 32        -17.163607      Republican     R        33              Carl Ford
# 33         -3.275924      Republican     R        34            Paul Newton
# 34         -9.345868      Republican     R        35           Todd Johnson
# 35        -24.919909      Republican     R        36        Eddie D. Settle
# 36         -9.126429      Republican     R        37          Vickie Sawyer
# 37         33.464759      Democratic     D        38    Mujtaba A. Mohammed
# 38         17.088447      Democratic     D        39      DeAndrea Salvador
# 39         21.773467      Democratic     D        40          Joyce Waddell
# 40         17.493860      Democratic     D        41      Natasha R. Marcus
# 41          4.633092      Democratic     D        42            Rachel Hunt
# 42         -8.350084      Republican     R        43          Brad Overcash
# 43        -20.256825      Republican     R        44       W. Ted Alexander
# 44        -19.548338      Republican     R        45           Dean Proctor
# 45        -14.051126      Republican     R        46          Warren Daniel
# 46        -14.044515      Republican     R        47             Ralph Hise
# 47        -16.101541      Republican     R        48     Timothy D. Moffitt
# 48          2.165452      Democratic     D        49         Julie Mayfield
# 49        -16.539365      Republican     R        50           Kevin Corbin
#
#                                  Counties Represented competitiveness
# 0   Carteret,                         Chowan,     ...         Solid R
# 1   Beaufort,                         Craven,     ...          Tilt R
# 2   Bertie,                         Camden,       ...         Toss Up
# 3   Greene,                         Wayne,        ...         Toss Up
# 4             Edgecombe,                         Pitt         Solid D
# 5                                              Onslow         Solid R
# 6                                         New Hanover          Tilt D
# 7   Brunswick,                         Columbus,  ...        Likely R
# 8   Bladen,                         Duplin,       ...        Likely R
# 9                                            Johnston         Solid R
# 10  Franklin,                         Nash,       ...         Toss Up
# 11  Harnett,                         Lee,         ...        Likely R
# 12                                               Wake        Likely D
# 13                                               Wake   Super Solid D
# 14                                               Wake         Solid D
# 15                                               Wake        Likely D
# 16                                               Wake          Tilt R
# 17            Granville,                         Wake         Toss Up
# 18                                         Cumberland          Tilt D
# 19            Chatham,                         Durham         Solid D
# 20          Cumberland,                         Moore          Tilt D
# 21                                             Durham         Solid D
# 22  Caswell,                         Orange,      ...        Likely D
# 23  Hoke,                         Robeson,        ...          Tilt D
# 24         Alamance,                         Randolph        Likely R
# 25       Guilford,                         Rockingham        Likely R
# 26                                           Guilford          Tilt D
# 27                                           Guilford   Super Solid D
# 28  Anson,                         Montgomery,    ...         Solid R
# 29            Davidson,                         Davie         Solid R
# 30            Forsyth,                         Stokes          Tilt R
# 31                                            Forsyth        Likely D
# 32              Rowan,                         Stanly         Solid R
# 33                                           Cabarrus          Tilt R
# 34            Cabarrus,                         Union        Likely R
# 35  Alexander,                         Surry,     ...   Super Solid R
# 36       Iredell,                         Mecklenburg        Likely R
# 37                                        Mecklenburg   Super Solid D
# 38                                        Mecklenburg         Solid D
# 39                                        Mecklenburg   Super Solid D
# 40                                        Mecklenburg         Solid D
# 41                                        Mecklenburg          Tilt D
# 42                                             Gaston        Likely R
# 43  Cleveland,                         Gaston,    ...   Super Solid R
# 44          Caldwell,                         Catawba         Solid R
# 45  Buncombe,                         Burke,      ...         Solid R
# 46  Alleghany,                         Ashe,      ...         Solid R
# 47  Henderson,                         Polk,      ...         Solid R
# 48                                           Buncombe          Tilt D
# 49  Cherokee,                         Clay,       ...         Solid R

# %%
# Path to the shapefile
shapefile_path_nc = 'data/sldu_shapefiles/processed/NC_SLDU/NC_SLDU_PVI.shp'

# Load the shapefile
gdf_nc = gpd.read_file(shapefile_path_nc)

# Display the first few rows of the GeoDataFrame
print(gdf_nc.head())
# Out:
#   STATEFP SLDUST GEOID_x         GEOIDFQ                  NAMELSAD LSAD   LSY  \
# 0      37    001   37001  610U800US37001   State Senate District 1   LU  2022
# 1      37    045   37045  610U800US37045  State Senate District 45   LU  2022
# 2      37    002   37002  610U800US37002   State Senate District 2   LU  2022
# 3      37    046   37046  610U800US37046  State Senate District 46   LU  2022
# 4      37    003   37003  610U800US37003   State Senate District 3   LU  2022
#
#    MTFCC FUNCSTAT        ALAND      AWATER     INTPTLAT      INTPTLON  \
# 0  G5210        N   7337196471  8634304882  +35.4708260  -076.2280820
# 1  G5210        N   1458893938    44980017  +35.7207490  -081.2800714
# 2  G5210        N   5020420966   515666201  +35.3239689  -077.0768755
# 3  G5210        N   3275977742    36637476  +35.7001279  -082.0008389
# 4  G5210        N  11479387894  1634070383  +36.2159332  -076.9498283
#
#           GEOID_y   district   pred_PVI  \
# 0  610U800US37001  NC-Sen-01 -13.030423
# 1  610U800US37045  NC-Sen-45 -19.548338
# 2  610U800US37002  NC-Sen-02  -4.604440
# 3  610U800US37046  NC-Sen-46 -14.051126
# 4  610U800US37003  NC-Sen-03   1.409107
#
#                                             geometry
# 0  POLYGON ((-77.16777 34.79100, -77.16772 34.791...
# 1  POLYGON ((-81.59180 35.81549, -81.59177 35.815...
# 2  POLYGON ((-77.83420 35.17889, -77.83415 35.179...
# 3  POLYGON ((-82.60950 35.75606, -82.60941 35.756...
# 4  POLYGON ((-78.32399 36.54382, -78.31796 36.543...

# %%
filtered_nc_pvi = nc_pvi[["GEOID","pred_PVI_shifted","district","Party", "predicted_party","Member","Counties Represented"]]


# Merge the GeoDataFrame with the NC DataFrame
merged_gdf_nc = gdf_nc.merge(filtered_nc_pvi, left_on='GEOIDFQ', right_on='GEOID', how='left')

# %%
# Save the merged GeoDataFrame as a new shapefile
merged_gdf_nc.to_file('data/sldu_shapefiles/processed/NC_SLDU/NC_SLDU_PVI_shifted.shp', driver='ESRI Shapefile')
# Out:
# /var/folders/h4/j84n8y_50sq08cp7wghj5_xm0000gn/T/ipykernel_47989/4031908064.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   merged_gdf_nc.to_file('data/sldu_shapefiles/processed/NC_SLDU/NC_SLDU_PVI_shifted.shp', driver='ESRI Shapefile')

# %%
merged_gdf_nc
# Out:
#   STATEFP SLDUST GEOID_x         GEOIDFQ                            NAMELSAD  \
# 0      72    002   72002  610U800US72002             State Senate District 2
# 1      72    003   72003  610U800US72003             State Senate District 3
# 2      72    004   72004  610U800US72004             State Senate District 4
# 3      72    005   72005  610U800US72005             State Senate District 5
# 4      72    001   72001  610U800US72001             State Senate District 1
# 5      72    006   72006  610U800US72006             State Senate District 6
# 6      72    007   72007  610U800US72007             State Senate District 7
# 7      72    008   72008  610U800US72008             State Senate District 8
# 8      72    ZZZ   72ZZZ  610U800US72ZZZ  State Senate Districts not defined
#
#   LSAD   LSY  MTFCC FUNCSTAT       ALAND  ...     INTPTLAT      INTPTLON  \
# 0   LU  2022  G5210        N   280691528  ...  +18.3784878  -066.1920839
# 1   LU  2022  G5210        N  1169035960  ...  +18.4077416  -066.6006571
# 2   LU  2022  G5210        N  1323107551  ...  +18.3680326  -067.1695965
# 3   LU  2022  G5210        N  2256090004  ...  +18.1448211  -066.7638082
# 4   LU  2022  G5210        N   250484698  ...  +18.3310563  -066.0923742
# 5   LU  2022  G5210        N  1658731794  ...  +18.1200943  -066.2898554
# 6   LU  2022  G5210        N  1086059024  ...  +18.1494771  -065.9186732
# 7   LU  2022  G5210        N   844831018  ...  +18.3044582  -065.6987107
# 8   00  2022  G5210        F           0  ...  +18.3838790  -065.7072300
#
#                                             geometry GEOID_y pred_PVI_shifted  \
# 0  MULTIPOLYGON (((-66.18960 18.47591, -66.18955 ...     NaN              NaN
# 1  MULTIPOLYGON (((-66.47913 18.47266, -66.47910 ...     NaN              NaN
# 2  MULTIPOLYGON (((-67.13316 17.95010, -67.13313 ...     NaN              NaN
# 3  MULTIPOLYGON (((-66.52977 17.88404, -66.52973 ...     NaN              NaN
# 4  MULTIPOLYGON (((-66.04487 18.46470, -66.04471 ...     NaN              NaN
# 5  MULTIPOLYGON (((-66.20501 17.93086, -66.20500 ...     NaN              NaN
# 6  MULTIPOLYGON (((-65.73504 18.15786, -65.73503 ...     NaN              NaN
# 7  MULTIPOLYGON (((-65.39710 18.33626, -65.39540 ...     NaN              NaN
# 8  POLYGON ((-67.32325 18.36388, -67.32227 18.368...     NaN              NaN
#
#    district Party predicted_party Member Counties Represented
# 0       NaN   NaN             NaN    NaN                  NaN
# 1       NaN   NaN             NaN    NaN                  NaN
# 2       NaN   NaN             NaN    NaN                  NaN
# 3       NaN   NaN             NaN    NaN                  NaN
# 4       NaN   NaN             NaN    NaN                  NaN
# 5       NaN   NaN             NaN    NaN                  NaN
# 6       NaN   NaN             NaN    NaN                  NaN
# 7       NaN   NaN             NaN    NaN                  NaN
# 8       NaN   NaN             NaN    NaN                  NaN
#
# [9 rows x 21 columns]

# %%
# Path to the shapefile
shapefile_path = 'data/sldu_shapefiles/processed/TX_SLDU/TX_SLDU_PVI.shp'

# Load the shapefile
gdf = gpd.read_file(shapefile_path)

# Display the first few rows of the GeoDataFrame
print(gdf.head())
# Out:
#   STATEFP SLDUST GEOID_x         GEOIDFQ                  NAMELSAD LSAD   LSY  \
# 0      48    013   48013  610U800US48013  State Senate District 13   LU  2022
# 1      48    014   48014  610U800US48014  State Senate District 14   LU  2022
# 2      48    015   48015  610U800US48015  State Senate District 15   LU  2022
# 3      48    016   48016  610U800US48016  State Senate District 16   LU  2022
# 4      48    017   48017  610U800US48017  State Senate District 17   LU  2022
#
#    MTFCC FUNCSTAT        ALAND      AWATER     INTPTLAT      INTPTLON  \
# 0  G5210        N    617613393     8635514  +29.6505395  -095.4493287
# 1  G5210        N   1333734713    13709274  +30.3276222  -097.6766210
# 2  G5210        N    652950020    20167237  +29.9314444  -095.4725906
# 3  G5210        N    666191013    14954059  +32.8011437  -096.7930861
# 4  G5210        N  14869099752  2140958283  +29.1816806  -096.0594832
#
#           GEOID_y   district   pred_PVI  \
# 0  610U800US48013  TX-Sen-13  22.887156
# 1  610U800US48014  TX-Sen-14  15.256809
# 2  610U800US48015  TX-Sen-15   9.123569
# 3  610U800US48016  TX-Sen-16  13.292141
# 4  610U800US48017  TX-Sen-17  -8.332801
#
#                                             geometry
# 0  POLYGON ((-95.61969 29.73591, -95.61811 29.735...
# 1  POLYGON ((-98.01141 30.24856, -98.01140 30.248...
# 2  POLYGON ((-95.58813 29.91135, -95.58706 29.911...
# 3  POLYGON ((-97.03518 32.76047, -97.03518 32.760...
# 4  POLYGON ((-96.93503 29.06587, -96.91392 29.081...

# %%
max_abs_pvi = max(abs(overall_min_pvi), abs(overall_max_pvi))
color_scale_min = -max_abs_pvi
color_scale_max = max_abs_pvi

# %%
max_abs_pvi
# Out:
# 56.96250276800477

# %%
# Path to the shapefile
shapefile_path = 'data/tl_2023_37_tract/tl_2023_37_tract.shp'

# Load the shapefile
gdf_tracts = gpd.read_file(shapefile_path)

# Display the first few rows of the GeoDataFrame
print(gdf_tracts.head())
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ    NAME  \
# 0      37      179  020501  37179020501  1400000US37179020501  205.01
# 1      37      179  020308  37179020308  1400000US37179020308  203.08
# 2      37      179  020317  37179020317  1400000US37179020317  203.17
# 3      37      179  020312  37179020312  1400000US37179020312  203.12
# 4      37      179  021015  37179021015  1400000US37179021015  210.15
#
#               NAMELSAD  MTFCC FUNCSTAT     ALAND  AWATER     INTPTLAT  \
# 0  Census Tract 205.01  G5020        S  11143598   13751  +34.9695439
# 1  Census Tract 203.08  G5020        S  23664083  103158  +34.9929515
# 2  Census Tract 203.17  G5020        S   7083961   39798  +35.0314519
# 3  Census Tract 203.12  G5020        S  12820999   48324  +35.0837483
# 4  Census Tract 210.15  G5020        S  76054915  400014  +34.8644931
#
#        INTPTLON                                           geometry
# 0  -080.5777153  POLYGON ((-80.60981 34.96665, -80.60914 34.966...
# 1  -080.6410664  POLYGON ((-80.67362 35.01833, -80.67362 35.018...
# 2  -080.6626738  POLYGON ((-80.68760 35.01981, -80.68659 35.020...
# 3  -080.6592068  POLYGON ((-80.69094 35.09573, -80.69087 35.095...
# 4  -080.7502614  POLYGON ((-80.79747 34.81989, -80.79696 34.823...

# %% [markdown]
# ## Randolph County is 37-151

# %%
randolph_gdf = gdf_tracts[gdf_tracts['COUNTYFP']== '151']

# %%
randolph_gdf.head(34)
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ    NAME  \
# 197       37      151  031303  37151031303  1400000US37151031303  313.03
# 552       37      151  030400  37151030400  1400000US37151030400     304
# 553       37      151  031501  37151031501  1400000US37151031501  315.01
# 554       37      151  030202  37151030202  1400000US37151030202  302.02
# 555       37      151  030600  37151030600  1400000US37151030600     306
# 556       37      151  030201  37151030201  1400000US37151030201  302.01
# 557       37      151  031200  37151031200  1400000US37151031200     312
# 558       37      151  030100  37151030100  1400000US37151030100     301
# 559       37      151  030900  37151030900  1400000US37151030900     309
# 560       37      151  030700  37151030700  1400000US37151030700     307
# 1564      37      151  031001  37151031001  1400000US37151031001  310.01
# 1566      37      151  031401  37151031401  1400000US37151031401  314.01
# 1567      37      151  031308  37151031308  1400000US37151031308  313.08
# 1653      37      151  031402  37151031402  1400000US37151031402  314.02
# 1654      37      151  031002  37151031002  1400000US37151031002  310.02
# 1655      37      151  031307  37151031307  1400000US37151031307  313.07
# 1657      37      151  030803  37151030803  1400000US37151030803  308.03
# 1658      37      151  031101  37151031101  1400000US37151031101  311.01
# 1659      37      151  030805  37151030805  1400000US37151030805  308.05
# 1660      37      151  030806  37151030806  1400000US37151030806  308.06
# 1661      37      151  030804  37151030804  1400000US37151030804  308.04
# 1662      37      151  031102  37151031102  1400000US37151031102  311.02
# 2417      37      151  030301  37151030301  1400000US37151030301  303.01
# 2437      37      151  030302  37151030302  1400000US37151030302  303.02
# 2438      37      151  030502  37151030502  1400000US37151030502  305.02
# 2439      37      151  031503  37151031503  1400000US37151031503  315.03
# 2488      37      151  031601  37151031601  1400000US37151031601  316.01
# 2489      37      151  031602  37151031602  1400000US37151031602  316.02
# 2507      37      151  030504  37151030504  1400000US37151030504  305.04
# 2508      37      151  031305  37151031305  1400000US37151031305  313.05
# 2510      37      151  030503  37151030503  1400000US37151030503  305.03
# 2511      37      151  031505  37151031505  1400000US37151031505  315.05
# 2512      37      151  031504  37151031504  1400000US37151031504  315.04
# 2513      37      151  031304  37151031304  1400000US37151031304  313.04
#
#                  NAMELSAD  MTFCC FUNCSTAT      ALAND   AWATER     INTPTLAT  \
# 197   Census Tract 313.03  G5020        S   24010210    96870  +35.8444486
# 552      Census Tract 304  G5020        S   11522059    38234  +35.7404541
# 553   Census Tract 315.01  G5020        S   40154751   271952  +35.8529741
# 554   Census Tract 302.02  G5020        S   18558316   146828  +35.6663310
# 555      Census Tract 306  G5020        S   84046862   153086  +35.6676050
# 556   Census Tract 302.01  G5020        S    4048977        0  +35.6987298
# 557      Census Tract 312  G5020        S   90596223   712472  +35.8640230
# 558      Census Tract 301  G5020        S    9752363     6441  +35.6721415
# 559      Census Tract 309  G5020        S  219198149   224191  +35.6178904
# 560      Census Tract 307  G5020        S  363485606   569652  +35.5925546
# 1564  Census Tract 310.01  G5020        S   54497506   275086  +35.7228398
# 1566  Census Tract 314.01  G5020        S   20498424  1738907  +35.8248083
# 1567  Census Tract 313.08  G5020        S   26784969   133660  +35.8881018
# 1653  Census Tract 314.02  G5020        S   15298965    90318  +35.7838685
# 1654  Census Tract 310.02  G5020        S   93864664   501332  +35.7780822
# 1655  Census Tract 313.07  G5020        S   80884661    82492  +35.8645066
# 1657  Census Tract 308.03  G5020        S  142260251   233098  +35.5598370
# 1658  Census Tract 311.01  G5020        S   65007930   343974  +35.7832131
# 1659  Census Tract 308.05  G5020        S   62598836   119433  +35.6904263
# 1660  Census Tract 308.06  G5020        S   29822641    35592  +35.6881089
# 1661  Census Tract 308.04  G5020        S   60213762   131706  +35.6209839
# 1662  Census Tract 311.02  G5020        S   31418943   475511  +35.7597542
# 2417  Census Tract 303.01  G5020        S   12765634        0  +35.7438692
# 2437  Census Tract 303.02  G5020        S   10897951        0  +35.7202203
# 2438  Census Tract 305.02  G5020        S   33929321   674432  +35.7250666
# 2439  Census Tract 315.03  G5020        S    3587723    10797  +35.9045403
# 2488  Census Tract 316.01  G5020        S   24466382   236875  +35.8953949
# 2489  Census Tract 316.02  G5020        S    2569999        0  +35.9133497
# 2507  Census Tract 305.04  G5020        S  136780034  2381688  +35.7514106
# 2508  Census Tract 313.05  G5020        S   39547143  2924017  +35.8717915
# 2510  Census Tract 305.03  G5020        S  107108940  2448942  +35.7774144
# 2511  Census Tract 315.05  G5020        S   30607456   152923  +35.8570492
# 2512  Census Tract 315.04  G5020        S   11606170    21273  +35.8980899
# 2513  Census Tract 313.04  G5020        S   63843300  4479043  +35.8666648
#
#           INTPTLON                                           geometry
# 197   -079.9215538  POLYGON ((-79.94049 35.83071, -79.94028 35.832...
# 552   -079.8192445  POLYGON ((-79.82848 35.70896, -79.82811 35.709...
# 553   -080.0213606  POLYGON ((-80.05254 35.81706, -80.05252 35.817...
# 554   -079.8021698  POLYGON ((-79.82665 35.63805, -79.82665 35.638...
# 555   -079.8912509  POLYGON ((-79.96723 35.64572, -79.96683 35.645...
# 556   -079.8026262  POLYGON ((-79.81614 35.68889, -79.81605 35.689...
# 557   -079.6000548  POLYGON ((-79.66874 35.87495, -79.66705 35.874...
# 558   -079.8252884  POLYGON ((-79.83613 35.66090, -79.83597 35.662...
# 559   -079.6129038  POLYGON ((-79.69339 35.57266, -79.69329 35.572...
# 560   -079.9461150  POLYGON ((-80.06683 35.50588, -80.06682 35.506...
# 1564  -079.6116284  POLYGON ((-79.68544 35.71840, -79.68540 35.718...
# 1566  -079.7958262  POLYGON ((-79.82703 35.83105, -79.82703 35.831...
# 1567  -079.7391965  POLYGON ((-79.79388 35.90655, -79.79359 35.907...
# 1653  -079.7968141  POLYGON ((-79.82945 35.78376, -79.82929 35.784...
# 1654  -079.6126489  POLYGON ((-79.68012 35.74297, -79.67995 35.743...
# 1655  -079.6860767  POLYGON ((-79.77271 35.84143, -79.77251 35.841...
# 1657  -079.7357525  POLYGON ((-79.83223 35.51078, -79.83217 35.514...
# 1658  -079.7372439  POLYGON ((-79.78437 35.78710, -79.78421 35.787...
# 1659  -079.7188735  POLYGON ((-79.76513 35.65277, -79.76417 35.654...
# 1660  -079.7614051  POLYGON ((-79.79620 35.68195, -79.79539 35.682...
# 1661  -079.7778424  POLYGON ((-79.82856 35.56285, -79.82835 35.563...
# 1662  -079.6997148  POLYGON ((-79.74170 35.73096, -79.74141 35.732...
# 2417  -079.7923373  POLYGON ((-79.81068 35.71745, -79.81045 35.718...
# 2437  -079.7831307  POLYGON ((-79.81322 35.70943, -79.81308 35.709...
# 2438  -079.8518045  POLYGON ((-79.90068 35.71265, -79.90040 35.713...
# 2439  -079.9656115  POLYGON ((-79.98248 35.90769, -79.98169 35.908...
# 2488  -080.0181477  POLYGON ((-80.04955 35.86756, -80.04951 35.868...
# 2489  -079.9855017  POLYGON ((-79.99957 35.91876, -79.99920 35.918...
# 2507  -079.9928918  POLYGON ((-80.05867 35.70434, -80.05866 35.704...
# 2508  -079.8075195  POLYGON ((-79.85664 35.90730, -79.85636 35.908...
# 2510  -079.8814138  POLYGON ((-79.99262 35.76543, -79.99168 35.765...
# 2511  -079.9581482  POLYGON ((-80.00188 35.88235, -79.99631 35.887...
# 2512  -079.9504024  POLYGON ((-79.98623 35.90312, -79.98610 35.903...
# 2513  -079.8786900  POLYGON ((-79.93428 35.91630, -79.93207 35.916...
