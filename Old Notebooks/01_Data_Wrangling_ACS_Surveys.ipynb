# %% [markdown]
# # Data Wrangling for ACS Congressional District Profiles

# %% [markdown]
# This Jupyter notebook details the data wrangling process using the four characteristic profile datasets of the American Community Survey (ACS)—demographic, housing, social, and economic profiles—across all U.S. Congressional Districts. The goal is to create a unified dataframe where each row represents a Congressional District, and each column captures a unique feature from the profile products, after processing each profile for all states.
#
# ## Process Overview:
#
# **1) Demographic Profile Processing**: The process begins with the Demographic Profile for one state (Alabama) to establish the feature space and define the functions for data processing. This methodology is then applied to the remaining 49 states, resulting in a comprehensive dataset covering all 435 U.S. Congressional Districts.
#
# **2 - 4) Housing, Social, and Economic Profile Processing**: With the Demographic Profile complete, this process is repeated on the Housing, Social, and Economic Profiles.
#
# **5) Integration of Profiles into Megaframe**: The datasets from the Demographic, Housing, Social, and Economic Profiles are merged into a single 'mega' dataframe. This step involves the removal of duplicated information across profiles (e.g., "Total Households" which appears in all profiles). The final merger yields a dataset with **459 unique features** for each congressional district, encapsulating the comprehensive data from all four profiles.
#
# **6) Merging Targets for Prediction**: This step involves merging key targets for analysis—Partisan Voter Index scores and 2022 midterm election voter behavior—into the comprehensive ACS Megaframe.
#
# **7) Clean up**: Here I performed some final checks for duplicated data and also merged state-level PVI scores onto the dataframe for possible analytical use.
#
# The final products results in a detailed and comprehensive representation of each Congressional District, ready for advanced analysis.

# %%
import pandas as pd
import numpy as np
import re

# %%
# Set pandas display options to show up to 100 rows
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # ___________________________________________________________________________________________________________

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1.a - State-Level Demographic Data Transformation (Alabama)
# Starting with Alabama, we'll standardize the Demographic Data Profile for analytical use. Once this approach is established, it will be replicated across the remaining states, resulting in a comprehensive demographic dataset. The same methodology will be applied for the integration of social, housing, and economic data profiles.

# %%
# Load in Alabama DEMOGRAPHIC file for all districts
data = pd.read_csv('data/ALLCD_DP05_AL.csv', dtype={'PROFLN': str})
data.rename(columns = {'GEONAME' :'District'}, inplace=True)

# make a dictionary of PROFLN keys to TITLE values
title_dict = dict(zip(data['PROFLN'], data['TITLE']))

# convert the dictionary to dataframe and observe 
title_df = pd.DataFrame(list(title_dict.items()), columns=['PROFLN', 'TITLE'])
title_df.head(10)
# Out:
#   PROFLN                                  TITLE
# 0      0  ACS DEMOGRAPHIC AND HOUSING ESTIMATES
# 1    0.5                                    NaN
# 2    0.8                            SEX AND AGE
# 3      1                       Total population
# 4      2                                   Male
# 5      3                                 Female
# 6      4      Sex ratio (males per 100 females)
# 7    4.3                                    NaN
# 8      5                          Under 5 years
# 9      6                           5 to 9 years

# %%
title_dict.values()
# Out:
# dict_values(['ACS DEMOGRAPHIC AND HOUSING ESTIMATES', nan, 'SEX AND AGE', 'Total population', 'Male', 'Female', 'Sex ratio (males per 100 females)', nan, 'Under 5 years', '5 to 9 years', '10 to 14 years', '15 to 19 years', '20 to 24 years', '25 to 34 years', '35 to 44 years', '45 to 54 years', '55 to 59 years', '60 to 64 years', '65 to 74 years', '75 to 84 years', '85 years and over', nan, 'Median age (years)', nan, 'Under 18 years', '16 years and over', '18 years and over', '21 years and over', '62 years and over', '65 years and over', nan, '18 years and over', 'Male', 'Female', 'Sex ratio (males per 100 females)', nan, '65 years and over', 'Male', 'Female', 'Sex ratio (males per 100 females)', nan, 'RACE', 'Total population', 'One race', 'Two or more races', nan, 'One race', 'White', 'Black or African American', 'American Indian and Alaska Native', 'Cherokee tribal grouping', 'Chippewa tribal grouping', 'Navajo tribal grouping', 'Sioux tribal grouping', 'Asian', 'Asian Indian', 'Chinese', 'Filipino', 'Japanese', 'Korean', 'Vietnamese', 'Other Asian', 'Native Hawaiian and Other Pacific Islander', 'Native Hawaiian', 'Chamorro', 'Samoan', 'Other Pacific Islander', 'Some other race', 'Two or more races', 'White and Black or African American', 'White and American Indian and Alaska Native', 'White and Asian', 'Black or African American and American Indian and Alaska Native', nan, 'Race alone or in combination with one or more other races', 'Total population', 'White', 'Black or African American', 'American Indian and Alaska Native', 'Asian', 'Native Hawaiian and Other Pacific Islander', 'Some other race', nan, 'HISPANIC OR LATINO AND RACE', 'Total population', 'Hispanic or Latino (of any race)', 'Mexican', 'Puerto Rican', 'Cuban', 'Other Hispanic or Latino', 'Not Hispanic or Latino', 'White alone', 'Black or African American alone', 'American Indian and Alaska Native alone', 'Asian alone', 'Native Hawaiian and Other Pacific Islander alone', 'Some other race alone', 'Two or more races', 'Two races including Some other race', 'Two races excluding Some other race, and Three or more races', nan, 'Total housing units', nan, 'CITIZEN, VOTING AGE POPULATION', 'Citizen, 18 and over population', 'Male', 'Female'])

# %% [markdown]
#  In the above table, you can see that the PROFLN number is associated with a Title which will eventually become our columns headers.
#
# By combining titles we get more accurate information (i.e. index 4 will become a combination of PROFLN 1&2 to create the title "Total Population - Male"

# %%
title_dict
# Out:
# {'0': 'ACS DEMOGRAPHIC AND HOUSING ESTIMATES',
#  '0.5': nan,
#  '0.8': 'SEX AND AGE',
#  '1': 'Total population',
#  '2': 'Male',
#  '3': 'Female',
#  '4': 'Sex ratio (males per 100 females)',
#  '4.3': nan,
#  '5': 'Under 5 years',
#  '6': '5 to 9 years',
#  '7': '10 to 14 years',
#  '8': '15 to 19 years',
#  '9': '20 to 24 years',
#  '10': '25 to 34 years',
#  '11': '35 to 44 years',
#  '12': '45 to 54 years',
#  '13': '55 to 59 years',
#  '14': '60 to 64 years',
#  '15': '65 to 74 years',
#  '16': '75 to 84 years',
#  '17': '85 years and over',
#  '17.3': nan,
#  '18': 'Median age (years)',
#  '18.3': nan,
#  '19': 'Under 18 years',
#  '20': '16 years and over',
#  '21': '18 years and over',
#  '22': '21 years and over',
#  '23': '62 years and over',
#  '24': '65 years and over',
#  '24.3': nan,
#  '25': '18 years and over',
#  '26': 'Male',
#  '27': 'Female',
#  '28': 'Sex ratio (males per 100 females)',
#  '28.3': nan,
#  '29': '65 years and over',
#  '30': 'Male',
#  '31': 'Female',
#  '32': 'Sex ratio (males per 100 females)',
#  '32.3': nan,
#  '32.5': 'RACE',
#  '33': 'Total population',
#  '34': 'One race',
#  '35': 'Two or more races',
#  '35.3': nan,
#  '36': 'One race',
#  '37': 'White',
#  '38': 'Black or African American',
#  '39': 'American Indian and Alaska Native',
#  '40': 'Cherokee tribal grouping',
#  '41': 'Chippewa tribal grouping',
#  '42': 'Navajo tribal grouping',
#  '43': 'Sioux tribal grouping',
#  '44': 'Asian',
#  '45': 'Asian Indian',
#  '46': 'Chinese',
#  '47': 'Filipino',
#  '48': 'Japanese',
#  '49': 'Korean',
#  '50': 'Vietnamese',
#  '51': 'Other Asian',
#  '52': 'Native Hawaiian and Other Pacific Islander',
#  '53': 'Native Hawaiian',
#  '54': 'Chamorro',
#  '55': 'Samoan',
#  '56': 'Other Pacific Islander',
#  '57': 'Some other race',
#  '58': 'Two or more races',
#  '59': 'White and Black or African American',
#  '60': 'White and American Indian and Alaska Native',
#  '61': 'White and Asian',
#  '62': 'Black or African American and American Indian and Alaska Native',
#  '62.3': nan,
#  '62.5': 'Race alone or in combination with one or more other races',
#  '63': 'Total population',
#  '64': 'White',
#  '65': 'Black or African American',
#  '66': 'American Indian and Alaska Native',
#  '67': 'Asian',
#  '68': 'Native Hawaiian and Other Pacific Islander',
#  '69': 'Some other race',
#  '69.3': nan,
#  '69.5': 'HISPANIC OR LATINO AND RACE',
#  '70': 'Total population',
#  '71': 'Hispanic or Latino (of any race)',
#  '72': 'Mexican',
#  '73': 'Puerto Rican',
#  '74': 'Cuban',
#  '75': 'Other Hispanic or Latino',
#  '76': 'Not Hispanic or Latino',
#  '77': 'White alone',
#  '78': 'Black or African American alone',
#  '79': 'American Indian and Alaska Native alone',
#  '80': 'Asian alone',
#  '81': 'Native Hawaiian and Other Pacific Islander alone',
#  '82': 'Some other race alone',
#  '83': 'Two or more races',
#  '84': 'Two races including Some other race',
#  '85': 'Two races excluding Some other race, and Three or more races',
#  '85.3': nan,
#  '86': 'Total housing units',
#  '86.3': nan,
#  '86.5': 'CITIZEN, VOTING AGE POPULATION',
#  '87': 'Citizen, 18 and over population',
#  '88': 'Male',
#  '89': 'Female'}

# %%
## Combining PROFLN numbers which will become new TITLEs

# "Total Population-" Category
for i in range(2, 25):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '1-' + str(i)

# "Total Population- 18 years and over-" Category
for i in range(25, 29):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '1-25' + ('' if i == 25 else '-' + str(i))

#"Total Population- 65 years and over-" Category
for i in range(29, 33):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '1-29' + ('' if i == 29 else '-' + str(i))

# "RACE-" Category
for i in range(33, 37):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-' + str(i)

# "RACE- One race-" Category
for i in range(37, 58):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-36-' + str(i)

# "RACE- Two or more races-" Category
for i in range(58, 63):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-58' + ('' if i == 58 else '-' + str(i))

#"RACE- Race alone or in combination with one or more other races-" Category
for i in range(63, 70):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-62.5-' + str(i)

# 'HISPANIC OR LATINO AND RACE-" Category
for i in range(70, 86):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '69.5-' + str(i)

# 'CITIZEN, VOTING AGE POPULATION' Category
for i in range(87, 90):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '86.5-' + str(i)

# %%
# Translate new profln numbers to combo titles
def translate_profln(profln):
    # split the PROFLN value into individual keys
    keys = profln.split('-')

    # translate each key from the title_dict
    titles = [str(title_dict.get(key, '')) for key in keys]

    # concat translated title strings
    translated_title = ' - '.join(title for title in titles if title)

    return translated_title

# replace TITLE values with their new names using function
data['TITLE'] = data['PROFLN'].apply(translate_profln)
data['TITLE'].value_counts()
# Out:
# TITLE
# nan                                                                                                              84
# RACE - Two or more races                                                                                         14
# RACE - One race                                                                                                  14
# Total population - 65 years and over                                                                             14
# Total population - 18 years and over                                                                             14
# RACE - One race - Native Hawaiian                                                                                 7
# RACE - Two or more races - Black or African American and American Indian and Alaska Native                        7
# RACE - One race - Other Asian                                                                                     7
# RACE - Race alone or in combination with one or more other races - Asian                                          7
# RACE - Race alone or in combination with one or more other races - American Indian and Alaska Native              7
# RACE - Race alone or in combination with one or more other races - Black or African American                      7
# RACE - Race alone or in combination with one or more other races - White                                          7
# RACE - Race alone or in combination with one or more other races - Total population                               7
# Race alone or in combination with one or more other races                                                         7
# RACE - Two or more races - White and Asian                                                                        7
# RACE - One race - Chamorro                                                                                        7
# RACE - One race - Native Hawaiian and Other Pacific Islander                                                      7
# RACE - Race alone or in combination with one or more other races - Native Hawaiian and Other Pacific Islander     7
# RACE - Two or more races - White and American Indian and Alaska Native                                            7
# RACE - Two or more races - White and Black or African American                                                    7
# RACE - One race - Some other race                                                                                 7
# RACE - One race - Other Pacific Islander                                                                          7
# RACE - One race - Samoan                                                                                          7
# ACS DEMOGRAPHIC AND HOUSING ESTIMATES                                                                             7
# RACE - Race alone or in combination with one or more other races - Some other race                                7
# RACE - One race - Korean                                                                                          7
# HISPANIC OR LATINO AND RACE - Asian alone                                                                         7
# CITIZEN, VOTING AGE POPULATION - Male                                                                             7
# CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population                                                  7
# CITIZEN, VOTING AGE POPULATION                                                                                    7
# Total housing units                                                                                               7
# HISPANIC OR LATINO AND RACE - Two races excluding Some other race, and Three or more races                        7
# HISPANIC OR LATINO AND RACE - Two races including Some other race                                                 7
# HISPANIC OR LATINO AND RACE - Two or more races                                                                   7
# HISPANIC OR LATINO AND RACE - Some other race alone                                                               7
# HISPANIC OR LATINO AND RACE - Native Hawaiian and Other Pacific Islander alone                                    7
# HISPANIC OR LATINO AND RACE - American Indian and Alaska Native alone                                             7
# HISPANIC OR LATINO AND RACE                                                                                       7
# HISPANIC OR LATINO AND RACE - Black or African American alone                                                     7
# HISPANIC OR LATINO AND RACE - White alone                                                                         7
# HISPANIC OR LATINO AND RACE - Not Hispanic or Latino                                                              7
# HISPANIC OR LATINO AND RACE - Other Hispanic or Latino                                                            7
# HISPANIC OR LATINO AND RACE - Cuban                                                                               7
# HISPANIC OR LATINO AND RACE - Puerto Rican                                                                        7
# HISPANIC OR LATINO AND RACE - Mexican                                                                             7
# HISPANIC OR LATINO AND RACE - Hispanic or Latino (of any race)                                                    7
# HISPANIC OR LATINO AND RACE - Total population                                                                    7
# RACE - One race - Vietnamese                                                                                      7
# RACE - One race - Chinese                                                                                         7
# RACE - One race - Japanese                                                                                        7
# Total population - 20 to 24 years                                                                                 7
# Total population - 85 years and over                                                                              7
# Total population - 75 to 84 years                                                                                 7
# Total population - 65 to 74 years                                                                                 7
# Total population - 60 to 64 years                                                                                 7
# Total population - 55 to 59 years                                                                                 7
# Total population - 45 to 54 years                                                                                 7
# Total population - 35 to 44 years                                                                                 7
# Total population - 25 to 34 years                                                                                 7
# Total population - 15 to 19 years                                                                                 7
# Total population - Under 18 years                                                                                 7
# Total population - 10 to 14 years                                                                                 7
# Total population - 5 to 9 years                                                                                   7
# Total population - Under 5 years                                                                                  7
# Total population - Sex ratio (males per 100 females)                                                              7
# Total population - Female                                                                                         7
# Total population - Male                                                                                           7
# Total population                                                                                                  7
# SEX AND AGE                                                                                                       7
# Total population - Median age (years)                                                                             7
# Total population - 16 years and over                                                                              7
# RACE - One race - Filipino                                                                                        7
# RACE - One race - White                                                                                           7
# RACE - One race - Asian Indian                                                                                    7
# RACE - One race - Asian                                                                                           7
# RACE - One race - Sioux tribal grouping                                                                           7
# RACE - One race - Navajo tribal grouping                                                                          7
# RACE - One race - Chippewa tribal grouping                                                                        7
# RACE - One race - Cherokee tribal grouping                                                                        7
# RACE - One race - American Indian and Alaska Native                                                               7
# RACE - One race - Black or African American                                                                       7
# RACE - Total population                                                                                           7
# Total population - 21 years and over                                                                              7
# RACE                                                                                                              7
# Total population - 65 years and over - Sex ratio (males per 100 females)                                          7
# Total population - 65 years and over - Female                                                                     7
# Total population - 65 years and over - Male                                                                       7
# Total population - 18 years and over - Sex ratio (males per 100 females)                                          7
# Total population - 18 years and over - Female                                                                     7
# Total population - 18 years and over - Male                                                                       7
# Total population - 62 years and over                                                                              7
# CITIZEN, VOTING AGE POPULATION - Female                                                                           7
# Name: count, dtype: int64

# %%
# remove rows with NaN's, placeholder 'N' for 'Not Large Enough Sample Size', and placeholder '(X)'' rows
invalid_rows = data['PRF_ESTIMATE'].isin(['N', '(X)']) | data['PRF_ESTIMATE'].isna()

# filter out these rows from the Dataframe
data = data[~invalid_rows]

# %%
# remove rows of duplicate information or strong overlap

# List of PROFLN values to remove (many values are repeats from other categories and subcategories)
profln_to_remove = ['1-29', '1-25', '32.5-33', '32.5-36', '32.5-58', 
                    '32.5-62.5-63', '32.5-62.5-64', '32.5-62.5-65', 
                    '32.5-62.5-66', '32.5-62.5-67', '32.5-62.5-68', 
                    '32.5-62.5-69', '69.5-70', '69.5-76', '69.5-77', 
                    '69.5-78', '69.5-79', '69.5-80', '69.5-81', '69.5-82']

# filter the data to observe which rows we are removing
rows_to_remove = data[data['PROFLN'].isin(profln_to_remove)]
print(rows_to_remove['TITLE'])

# Remove these rows from the DataFrame
data = data[~data['PROFLN'].isin(profln_to_remove)]
# Out:
# 31                                               Total population - 18 years and over
# 36                                               Total population - 65 years and over
# 42                                                            RACE - Total population
# 46                                                                    RACE - One race
# 68                                                           RACE - Two or more races
#                                             ...
# 734                     HISPANIC OR LATINO AND RACE - Black or African American alone
# 735             HISPANIC OR LATINO AND RACE - American Indian and Alaska Native alone
# 736                                         HISPANIC OR LATINO AND RACE - Asian alone
# 737    HISPANIC OR LATINO AND RACE - Native Hawaiian and Other Pacific Islander alone
# 738                               HISPANIC OR LATINO AND RACE - Some other race alone
# Name: TITLE, Length: 138, dtype: object

# %%
# Delete margin of error columns
data = data.drop(columns=['PRF_MG_ERROR', 'PCT_MG_ERROR'])

# Some MEDIAN and MEAN values are not listed in PCT_ESTIMATE column, but are relevant
data.loc[data['PCT_ESTIMATE'] == '(X)', 'PCT_ESTIMATE'] = data['PRF_ESTIMATE']

# Convert all the values to numeric
data['PCT_ESTIMATE'] = data['PCT_ESTIMATE'].str.replace(',', '').astype(float)
data['PRF_ESTIMATE'] = data['PRF_ESTIMATE'].str.replace(',', '').astype(float)

data
# Out:
#     TBLID          GEOID                                            District  \
# 3    DP05  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 4    DP05  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 5    DP05  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 6    DP05  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 8    DP05  5001800US0101  Congressional District 1 (118th Congress), Alabama
# ..    ...            ...                                                 ...
# 741  DP05  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 743  DP05  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 746  DP05  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 747  DP05  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 748  DP05  5001800US0107  Congressional District 7 (118th Congress), Alabama
#
#       PROFLN  \
# 3          1
# 4        1-2
# 5        1-3
# 6        1-4
# 8        1-5
# ..       ...
# 741  69.5-85
# 743       86
# 746  86.5-87
# 747  86.5-88
# 748  86.5-89
#
#                                                                                           TITLE  \
# 3                                                                              Total population
# 4                                                                       Total population - Male
# 5                                                                     Total population - Female
# 6                                          Total population - Sex ratio (males per 100 females)
# 8                                                              Total population - Under 5 years
# ..                                                                                          ...
# 741  HISPANIC OR LATINO AND RACE - Two races excluding Some other race, and Three or more races
# 743                                                                         Total housing units
# 746                            CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population
# 747                                                       CITIZEN, VOTING AGE POPULATION - Male
# 748                                                     CITIZEN, VOTING AGE POPULATION - Female
#
#      PRF_ESTIMATE  PCT_ESTIMATE
# 3        727212.0      727212.0
# 4        353457.0          48.6
# 5        373755.0          51.4
# 6            94.6          94.6
# 8         41746.0           5.7
# ..            ...           ...
# 741       14020.0           2.0
# 743      344719.0      344719.0
# 746      546972.0      546972.0
# 747      252332.0          46.1
# 748      294640.0          53.9
#
# [427 rows x 7 columns]

# %%
## Converting the long district titles to their state and district codes ('AL-01' = 'Alabama District 1')
# State Mapping
states = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
    'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
    'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
    'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
    'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS',
    'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH',
    'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC',
    'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA',
    'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN',
    'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA',
    'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
}

def format_district(district):
    # Extract the state name and district number from the district string
    match = re.search(r'Congressional District (\d+|\(at Large\)) \(118th Congress\), ([A-Za-z\s]+)', district)
    if match:
        district_num, state_name = match.groups()
        # Convert the district number to 'AL' for 'at large' districts
        if district_num == '(at Large)':
            district_num = 'AL'
        else:
            district_num = district_num.zfill(2)  # Pad single digit numbers with a leading zero
        # Convert state name to its abbreviation
        state_abbr = states.get(state_name.strip(), state_name)
        # Return the formatted district name
        return f'{state_abbr}-{district_num}'
    
# Apply the function to the 'District' column in both dataframes to replace values with their short-hand
data['Formatted_District'] = data['District'].apply(format_district)

# %%
#ensure all districts have the same number of values
data['Formatted_District'].value_counts()
# Out:
# Formatted_District
# AL-01    61
# AL-02    61
# AL-03    61
# AL-04    61
# AL-05    61
# AL-06    61
# AL-07    61
# Name: count, dtype: int64

# %%
# Pivot the dataframe separately into two dataframes with 'PRF_ESTIMATE' (raw numbers) and 'PCT_ESTIMATE' (%'s)
prf_estimate_df = data.pivot_table(index=['Formatted_District', 'GEOID'], columns='TITLE', values='PRF_ESTIMATE')
pct_estimate_df = data.pivot_table(index=['Formatted_District', 'GEOID'], columns='TITLE', values='PCT_ESTIMATE')

# Reset the column names after pivot
prf_estimate_df.columns = [f'{col}' for col in prf_estimate_df.columns]
pct_estimate_df.columns = [f'{col}' for col in pct_estimate_df.columns]

# Reset the index
prf_estimate_df.reset_index(inplace=True)
pct_estimate_df.reset_index(inplace=True)

prf_estimate_df
# Out:
#   Formatted_District          GEOID  \
# 0              AL-01  5001800US0101
# 1              AL-02  5001800US0102
# 2              AL-03  5001800US0103
# 3              AL-04  5001800US0104
# 4              AL-05  5001800US0105
# 5              AL-06  5001800US0106
# 6              AL-07  5001800US0107
#
#    CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population  \
# 0                                                          555123.0
# 1                                                          539010.0
# 2                                                          558552.0
# 3                                                          541258.0
# 4                                                          557827.0
# 5                                                          531046.0
# 6                                                          546972.0
#
#    CITIZEN, VOTING AGE POPULATION - Female  \
# 0                                 289663.0
# 1                                 284652.0
# 2                                 289423.0
# 3                                 280884.0
# 4                                 285421.0
# 5                                 277760.0
# 6                                 294640.0
#
#    CITIZEN, VOTING AGE POPULATION - Male  HISPANIC OR LATINO AND RACE - Cuban  \
# 0                               265460.0                               1480.0
# 1                               254358.0                                479.0
# 2                               269129.0                                766.0
# 3                               260374.0                               1322.0
# 4                               272406.0                               1481.0
# 5                               253286.0                               1180.0
# 6                               252332.0                               1024.0
#
#    HISPANIC OR LATINO AND RACE - Hispanic or Latino (of any race)  \
# 0                                                         25346.0
# 1                                                         29072.0
# 2                                                         22960.0
# 3                                                         52766.0
# 4                                                         41789.0
# 5                                                         36253.0
# 6                                                         29248.0
#
#    HISPANIC OR LATINO AND RACE - Mexican  \
# 0                                14082.0
# 1                                18554.0
# 2                                11728.0
# 3                                37454.0
# 4                                20557.0
# 5                                24216.0
# 6                                18521.0
#
#    HISPANIC OR LATINO AND RACE - Other Hispanic or Latino  \
# 0                                                  6571.0
# 1                                                  5484.0
# 2                                                  6468.0
# 3                                                 11988.0
# 4                                                 13835.0
# 5                                                  9624.0
# 6                                                  8699.0
#
#    HISPANIC OR LATINO AND RACE - Puerto Rican  ...  \
# 0                                      3213.0  ...
# 1                                      4555.0  ...
# 2                                      3998.0  ...
# 3                                      2002.0  ...
# 4                                      5916.0  ...
# 5                                      1233.0  ...
# 6                                      1004.0  ...
#
#    Total population - 65 years and over - Male  \
# 0                                      61808.0
# 1                                      54456.0
# 2                                      55915.0
# 3                                      59392.0
# 4                                      54646.0
# 5                                      52246.0
# 6                                      50770.0
#
#    Total population - 65 years and over - Sex ratio (males per 100 females)  \
# 0                                                                      82.8
# 1                                                                      76.9
# 2                                                                      79.6
# 3                                                                      79.6
# 4                                                                      78.2
# 5                                                                      79.7
# 6                                                                      71.7
#
#    Total population - 75 to 84 years  Total population - 85 years and over  \
# 0                            40508.0                               12282.0
# 1                            38134.0                               12806.0
# 2                            39234.0                                8784.0
# 3                            40315.0                               12003.0
# 4                            37413.0                               12440.0
# 5                            35741.0                               11321.0
# 6                            32485.0                               12120.0
#
#    Total population - Female  Total population - Male  \
# 0                   373755.0                 353457.0
# 1                   370483.0                 345729.0
# 2                   368853.0                 352436.0
# 3                   369637.0                 353433.0
# 4                   370374.0                 359010.0
# 5                   363521.0                 342976.0
# 6                   377358.0                 338855.0
#
#    Total population - Median age (years)  \
# 0                                   41.0
# 1                                   39.0
# 2                                   40.0
# 3                                   40.5
# 4                                   40.5
# 5                                   39.6
# 6                                   37.5
#
#    Total population - Sex ratio (males per 100 females)  \
# 0                                                  94.6
# 1                                                  93.3
# 2                                                  95.5
# 3                                                  95.6
# 4                                                  96.9
# 5                                                  94.3
# 6                                                  89.8
#
#    Total population - Under 18 years  Total population - Under 5 years
# 0                           162658.0                           41746.0
# 1                           165222.0                           41997.0
# 2                           152113.0                           39510.0
# 3                           165303.0                           45914.0
# 4                           157595.0                           37683.0
# 5                           161580.0                           41408.0
# 6                           155471.0                           41833.0
#
# [7 rows x 63 columns]

# %% [markdown]
# # 1.b - Convert previous steps into functions to apply and join all 50 state files

# %%
#LOAD FUNCTION

def load_and_rename_data(csv):
    data = pd.read_csv(csv, dtype={'PROFLN': str})
    data.rename(columns = {'GEONAME' :'District'}, inplace=True)
    return data

# %%
## translate PROFLN number into associated title
def translate_profln(profln, title_dict):
    # split the PROFLN value into keys by '-' for multi-labeled categories
    keys = profln.split('-')
    # translate each key using the title_dict
    titles = [str(title_dict.get(key, '')) for key in keys]
    # concatenate the translated titles
    translated_title = ' - '.join(title for title in titles if title)

    return translated_title

# %%
def update_titles_demo(data):
    # Create the title_dict
    title_dict = dict(zip(data['PROFLN'], data['TITLE']))
    # Update PROFLN values
    for i in range(2, 25):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '1-' + str(i)
    for i in range(25, 29):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '1-25' + ('' if i == 25 else '-' + str(i))
    for i in range(29, 33):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '1-29' + ('' if i == 29 else '-' + str(i))
    for i in range(33, 37):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-' + str(i)
    for i in range(37, 58):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-36-' + str(i)
    for i in range(58, 63):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-58' + ('' if i == 58 else '-' + str(i))
    for i in range(63, 70):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-62.5-' + str(i)
    for i in range(70, 86):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '69.5-' + str(i)
    for i in range(87, 90):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '86.5-' + str(i)

    # Update TITLE values
    data['TITLE'] = data['PROFLN'].apply(lambda x: translate_profln(x, title_dict)) #using translate_profln function

    return data

# %%
# CLEAN UP DATA AND DROP REDUNDANT INFO FUNCTION

def clean_up_data_demo(data):
    # drop unneccessary rows and rows with placeholders
    invalid_rows = data['PRF_ESTIMATE'].isin(['N', '(X)']) | data['PRF_ESTIMATE'].isna()
    data = data[~invalid_rows]

    # The rows associated with these index markers (profln) contain duplicated data
    profln_to_remove = ['1-29', '1-25', '32.5-33', '32.5-36', '32.5-58', 
                        '32.5-62.5-63', '32.5-62.5-64', '32.5-62.5-65', 
                        '32.5-62.5-66', '32.5-62.5-67', '32.5-62.5-68', 
                        '32.5-62.5-69', '69.5-70', '69.5-76', '69.5-77', 
                        '69.5-78', '69.5-79', '69.5-80', '69.5-81', '69.5-82']
    data = data[~data['PROFLN'].isin(profln_to_remove)]

    # Delete the margin of error columns
    data = data.drop(columns=['PRF_MG_ERROR', 'PCT_MG_ERROR'])

    # Replace '(X)' values in PCT_ESTIMATE with their PRF_ESTIMATE values (usually, average and median values)
    data.loc[data['PCT_ESTIMATE'] == '(X)', 'PCT_ESTIMATE'] = data['PRF_ESTIMATE']

    # convert to numeric
    data['PCT_ESTIMATE'] = data['PCT_ESTIMATE'].str.replace(',', '').astype(float)
    data['PRF_ESTIMATE'] = data['PRF_ESTIMATE'].str.replace(',', '').astype(float)
    
    return data

# %%
# SHORTHAND STATE-DISTRICT FUNCTION

def format_districts(data):
    # dictionary of state names to abbreviations
    states = {
        'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
        'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
        'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
        'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
        'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS',
        'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH',
        'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC',
        'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA',
        'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN',
        'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA',
        'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
    }

    # function to format a single district
    def format_district(district):
        # extract the state name and district number from the district string
        match = re.search(r'Congressional District (\d+|\(at Large\)) \(118th Congress\), ([A-Za-z\s]+)', district)
        if match:
            district_num, state_name = match.groups()
            # convert the district number to 'AL' for 'at large' districts
            if district_num == '(at Large)':
                district_num = 'AL'
            else:
                district_num = district_num.zfill(2)  # pad single digit numbers with a leading zero
            # convert the state name to its abbreviation
            state_abbr = states.get(state_name.strip(), state_name)
            # return the formatted district name
            return f'{state_abbr}-{district_num}'
        else:
            return district

    # Apply the function to the District column
    data['Formatted_District'] = data['District'].apply(format_district)

    return data

# %%
## TRANSPOSE DATAFRAME FUNCTION
def reorient_dfs(data):
    # Pivot the dataframe separately for 'PRF_ESTIMATE' and 'PCT_ESTIMATE'
    prf_estimate_df = data.pivot_table(index=['Formatted_District', 'GEOID'], columns='TITLE', values='PRF_ESTIMATE')
    pct_estimate_df = data.pivot_table(index=['Formatted_District', 'GEOID'], columns='TITLE', values='PCT_ESTIMATE')

    # Reset the column names after pivot
    prf_estimate_df.columns = [f'{col}' for col in prf_estimate_df.columns]
    pct_estimate_df.columns = [f'{col}' for col in pct_estimate_df.columns]

    # Reset the index
    prf_estimate_df.reset_index(inplace=True)
    pct_estimate_df.reset_index(inplace=True)

    return prf_estimate_df, pct_estimate_df

# %% [markdown]
# # 1.c - Process all 50 states demographic files

# %%
## PROCESS ALL 50 STATES FUNCTION
def process_demographics(file_state_list):
    prf_dfs = []
    pct_dfs = []
    
    for file_state in file_state_list:
        csv, state = file_state

        data = load_and_rename_data(csv)
        data = update_titles_demo(data)
        data = clean_up_data_demo(data)
        data = format_districts(data)

        prf_estimate_df, pct_estimate_df = reorient_dfs(data)

        prf_dfs.append(prf_estimate_df)
        pct_dfs.append(pct_estimate_df)
    
    df_prfdemo_all = pd.concat(prf_dfs, ignore_index=True)
    df_pctdemo_all = pd.concat(pct_dfs, ignore_index=True)
    
    return df_prfdemo_all, df_pctdemo_all

# %%
file_state_list = [
 ('data/ALLCD_DP05_AK.csv', 'AK'),('data/ALLCD_DP05_AL.csv', 'AL'),('data/ALLCD_DP05_AR.csv', 'AR'),
 ('data/ALLCD_DP05_AZ.csv', 'AZ'),('data/ALLCD_DP05_CA.csv', 'CA'),('data/ALLCD_DP05_CO.csv', 'CO'),
 ('data/ALLCD_DP05_CT.csv', 'CT'),('data/ALLCD_DP05_DE.csv', 'DE'),('data/ALLCD_DP05_FL.csv', 'FL'),
 ('data/ALLCD_DP05_GA.csv', 'GA'),('data/ALLCD_DP05_HI.csv', 'HI'),('data/ALLCD_DP05_IA.csv', 'IA'),
 ('data/ALLCD_DP05_ID.csv', 'ID'),('data/ALLCD_DP05_IL.csv', 'IL'),('data/ALLCD_DP05_IN.csv', 'IN'),
 ('data/ALLCD_DP05_KS.csv', 'KS'),('data/ALLCD_DP05_KY.csv', 'KY'),('data/ALLCD_DP05_LA.csv', 'LA'),
 ('data/ALLCD_DP05_MA.csv', 'MA'),('data/ALLCD_DP05_MD.csv', 'MD'),('data/ALLCD_DP05_ME.csv', 'ME'),
 ('data/ALLCD_DP05_MI.csv', 'MI'),('data/ALLCD_DP05_MN.csv', 'MN'),('data/ALLCD_DP05_MO.csv', 'MO'),
 ('data/ALLCD_DP05_MS.csv', 'MS'),('data/ALLCD_DP05_MT.csv', 'MT'),('data/ALLCD_DP05_NC.csv', 'NC'),
 ('data/ALLCD_DP05_ND.csv', 'ND'),('data/ALLCD_DP05_NE.csv', 'NE'),('data/ALLCD_DP05_NH.csv', 'NH'),
 ('data/ALLCD_DP05_NJ.csv', 'NJ'),('data/ALLCD_DP05_NM.csv', 'NM'),('data/ALLCD_DP05_NV.csv', 'NV'),
 ('data/ALLCD_DP05_NY.csv', 'NY'),('data/ALLCD_DP05_OH.csv', 'OH'),('data/ALLCD_DP05_OK.csv', 'OK'),
 ('data/ALLCD_DP05_OR.csv', 'OR'),('data/ALLCD_DP05_PA.csv', 'PA'),('data/ALLCD_DP05_RI.csv', 'RI'),
 ('data/ALLCD_DP05_SC.csv', 'SC'),('data/ALLCD_DP05_SD.csv', 'SD'),('data/ALLCD_DP05_TN.csv', 'TN'),
 ('data/ALLCD_DP05_TX.csv', 'TX'),('data/ALLCD_DP05_UT.csv', 'UT'),('data/ALLCD_DP05_VA.csv', 'VA'),
 ('data/ALLCD_DP05_VT.csv', 'VT'),('data/ALLCD_DP05_WA.csv', 'WA'),('data/ALLCD_DP05_WI.csv', 'WI'),
 ('data/ALLCD_DP05_WV.csv', 'WV'),('data/ALLCD_DP05_WY.csv', 'WY')
]


df_prfdemo_all, df_pctdemo_all = process_demographics(file_state_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[65], line 22
#       1 file_state_list = [
#       2  ('data/ALLCD_DP05_AK.csv', 'AK'),('data/ALLCD_DP05_AL.csv', 'AL'),('data/ALLCD_DP05_AR.csv', 'AR'),
#       3  ('data/ALLCD_DP05_AZ.csv', 'AZ'),('data/ALLCD_DP05_CA.csv', 'CA'),('data/ALLCD_DP05_CO.csv', 'CO'),
#    (...)
#      18  ('data/ALLCD_DP05_WV.csv', 'WV'),('data/ALLCD_DP05_WY.csv', 'WY')
#      19 ]
# ---> 22 df_prfdemo_all, df_pctdemo_all = process_demographics(file_state_list)
#
# Cell In[64], line 9, in process_demographics(file_state_list)
#       6 for file_state in file_state_list:
#       7     csv, state = file_state
# ----> 9     data = load_and_rename_data(csv)
#      10     data = update_titles_demo(data)
#      11     data = clean_up_data_demo(data)
#
# Cell In[58], line 4, in load_and_rename_data(csv)
#       3 def load_and_rename_data(csv):
# ----> 4     data = pd.read_csv(csv, dtype={'PROFLN': str})
#       5     data.rename(columns = {'GEONAME' :'District'}, inplace=True)
#       6     return data
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/WheeleyDope/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/WheeleyDope/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/WheeleyDope/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/WheeleyDope/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/WheeleyDope/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/ALLCD_DP05_AK.csv'

# %%
df_prfdemo_all.columns

# %% [markdown]
# ## There we have it, all Congressional Districts for the Demographic Characteristics profile have been consolidated into two separate dataframes; one representing raw numbers and one representing percent compositions.
#
# ## From here, we proceed to the next profile

# %% [markdown]
# # _______________________________________________________________________________________________________________

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 2.a- State-Level Housing Data Transformation (Alabama)

# %%
## LOAD_AND_RENAME_DATA FUNCTION REMAINS THE SAME
AL_housing_df = load_and_rename_data('data/ALLCD_DP04_AL.csv')

# %%
#Profln values and their corresponding TITLE/associations have changed. Revamping title formatting
def update_titles_housing(data):
    # Create the title_dict
    title_dict = dict(zip(data['PROFLN'], data['TITLE']))
    
    #Update PROFLN numbers by category
    for i in range(1, 6): 
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '0.8-' + str(i) # "HOUSING OCCUPANCY-" Category
    for i in range(6, 16): 
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '5.5-' + str(i) # "UNITS IN STRUCTURE-" Category
    for i in range(16, 27): 
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '15.5-' + str(i) # "YEAR STRUCTURE BUILT-" Category
    for i in range(27, 38): 
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '26.5-' + str(i) # "ROOMS-" Category
    for i in range(39, 45): 
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '37.5-' + str(i) # "BEDROOMS-" Category
    for i in range(45, 57): 
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '44.5-' + str(i) # "HOUSING TENURE-" Category
    for i in range(57, 62): 
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '56.5-' + str(i) # "VEHICLES AVAILABLE-" Category
    for i in range(62, 72): 
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '61.5-' + str(i) # "HOUSE HEATING FUEL-" Category
    for i in range(72, 76): 
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '71.5-' + str(i) # "SELECTED CHARACTERISTICS-" Category
    for i in range(76, 80): 
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '75.5-' + str(i) # "OCCUPANTS PER ROOM-" Category
    for i in range(80, 90): 
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '79.5-' + str(i)  # "VALUE-" Category
    for i in range(90, 93): 
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '89.5-' + str(i)   # "MORTGAGE STATUS-" Category
    for i in range(126, 136):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '125.5-' + str(i) # "GROSS RENT-" Category
        
    ###LONG TITLES BELOW###
    
    # "SELECTED MONTHLY OWNER COSTS (SMOC)- Housing units with a mortgage- " Category
    for i in range(93, 102):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '92.5-93' + ('' if i == 93 else '-' + str(i))
    # "SELECTED MONTHLY OWNER COSTS (SMOC)- Housing units without a mortgage- " Category
    for i in range(102, 110):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '92.5-102' + ('' if i == 102 else '-' + str(i))  
    # "SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)- 
    # Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)-" Category
    for i in range(110, 116):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '109.5-110' + ('' if i == 110 else '-' + str(i))  
    # "SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)-
    # Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)-" Category
    for i in range(117, 125):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '109.5-117' + ('' if i == 117 else '-' + str(i))
    #"GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)-" Category
    for i in range(136, 143):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '135.5-' + str(i)
        
    # Translate TITLE values using previously defined 'translate_profln' function
    data['TITLE'] = data['PROFLN'].apply(lambda x: translate_profln(x, title_dict))

    return data

# %%
AL_housing_df = update_titles_housing(AL_housing_df)

# %%
AL_housing_df['TITLE']
# Out:
# 0                                                    SELECTED HOUSING CHARACTERISTICS
# 1                                                                                 nan
# 2                                                                   HOUSING OCCUPANCY
# 3                                             HOUSING OCCUPANCY - Total housing units
# 4                                          HOUSING OCCUPANCY - Occupied housing units
#                                             ...
# 1297    GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 25.0 to 29.9 percent
# 1298    GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 30.0 to 34.9 percent
# 1299    GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 35.0 percent or more
# 1300                                                                              nan
# 1301                                                                     Not computed
# Name: TITLE, Length: 1302, dtype: object

# %%
import pandas as pd

# Temporary settings to display more data
with pd.option_context('display.max_rows', None):
    print(AL_housing_df['TITLE'].unique())
# Out:
# ['SELECTED HOUSING CHARACTERISTICS' 'nan' 'HOUSING OCCUPANCY'
#  'HOUSING OCCUPANCY - Total housing units'
#  'HOUSING OCCUPANCY - Occupied housing units'
#  'HOUSING OCCUPANCY - Vacant housing units'
#  'HOUSING OCCUPANCY - Homeowner vacancy rate'
#  'HOUSING OCCUPANCY - Rental vacancy rate' 'UNITS IN STRUCTURE'
#  'UNITS IN STRUCTURE - Total housing units'
#  'UNITS IN STRUCTURE - 1-unit, detached'
#  'UNITS IN STRUCTURE - 1-unit, attached' 'UNITS IN STRUCTURE - 2 units'
#  'UNITS IN STRUCTURE - 3 or 4 units' 'UNITS IN STRUCTURE - 5 to 9 units'
#  'UNITS IN STRUCTURE - 10 to 19 units'
#  'UNITS IN STRUCTURE - 20 or more units'
#  'UNITS IN STRUCTURE - Mobile home'
#  'UNITS IN STRUCTURE - Boat, RV, van, etc.' 'YEAR STRUCTURE BUILT'
#  'YEAR STRUCTURE BUILT - Total housing units'
#  'YEAR STRUCTURE BUILT - Built 2020 or later'
#  'YEAR STRUCTURE BUILT - Built 2010 to 2019'
#  'YEAR STRUCTURE BUILT - Built 2000 to 2009'
#  'YEAR STRUCTURE BUILT - Built 1990 to 1999'
#  'YEAR STRUCTURE BUILT - Built 1980 to 1989'
#  'YEAR STRUCTURE BUILT - Built 1970 to 1979'
#  'YEAR STRUCTURE BUILT - Built 1960 to 1969'
#  'YEAR STRUCTURE BUILT - Built 1950 to 1959'
#  'YEAR STRUCTURE BUILT - Built 1940 to 1949'
#  'YEAR STRUCTURE BUILT - Built 1939 or earlier' 'ROOMS'
#  'ROOMS - Total housing units' 'ROOMS - 1 room' 'ROOMS - 2 rooms'
#  'ROOMS - 3 rooms' 'ROOMS - 4 rooms' 'ROOMS - 5 rooms' 'ROOMS - 6 rooms'
#  'ROOMS - 7 rooms' 'ROOMS - 8 rooms' 'ROOMS - 9 rooms or more'
#  'ROOMS - Median rooms' 'BEDROOMS' 'Total housing units'
#  'BEDROOMS - No bedroom' 'BEDROOMS - 1 bedroom' 'BEDROOMS - 2 bedrooms'
#  'BEDROOMS - 3 bedrooms' 'BEDROOMS - 4 bedrooms'
#  'BEDROOMS - 5 or more bedrooms' 'HOUSING TENURE'
#  'HOUSING TENURE - Occupied housing units'
#  'HOUSING TENURE - Owner-occupied' 'HOUSING TENURE - Renter-occupied'
#  'HOUSING TENURE - Average household size of owner-occupied unit'
#  'HOUSING TENURE - Average household size of renter-occupied unit'
#  'YEAR HOUSEHOLDER MOVED INTO UNIT'
#  'HOUSING TENURE - Moved in 2019 or later'
#  'HOUSING TENURE - Moved in 2015 to 2018'
#  'HOUSING TENURE - Moved in 2010 to 2014'
#  'HOUSING TENURE - Moved in 2000 to 2009'
#  'HOUSING TENURE - Moved in 1990 to 1999'
#  'HOUSING TENURE - Moved in 1989 and earlier' 'VEHICLES AVAILABLE'
#  'VEHICLES AVAILABLE - Occupied housing units'
#  'VEHICLES AVAILABLE - No vehicles available'
#  'VEHICLES AVAILABLE - 1 vehicle available'
#  'VEHICLES AVAILABLE - 2 vehicles available'
#  'VEHICLES AVAILABLE - 3 or more vehicles available' 'HOUSE HEATING FUEL'
#  'HOUSE HEATING FUEL - Occupied housing units'
#  'HOUSE HEATING FUEL - Utility gas'
#  'HOUSE HEATING FUEL - Bottled, tank, or LP gas'
#  'HOUSE HEATING FUEL - Electricity'
#  'HOUSE HEATING FUEL - Fuel oil, kerosene, etc.'
#  'HOUSE HEATING FUEL - Coal or coke' 'HOUSE HEATING FUEL - Wood'
#  'HOUSE HEATING FUEL - Solar energy' 'HOUSE HEATING FUEL - Other fuel'
#  'HOUSE HEATING FUEL - No fuel used' 'SELECTED CHARACTERISTICS'
#  'SELECTED CHARACTERISTICS - Occupied housing units'
#  'SELECTED CHARACTERISTICS - Lacking complete plumbing facilities'
#  'SELECTED CHARACTERISTICS - Lacking complete kitchen facilities'
#  'SELECTED CHARACTERISTICS - No telephone service available'
#  'OCCUPANTS PER ROOM' 'OCCUPANTS PER ROOM - Occupied housing units'
#  'OCCUPANTS PER ROOM - 1.00 or less' 'OCCUPANTS PER ROOM - 1.01 to 1.50'
#  'OCCUPANTS PER ROOM - 1.51 or more' 'VALUE'
#  'VALUE - Owner-occupied units' 'VALUE - Less than $50,000'
#  'VALUE - $50,000 to $99,999' 'VALUE - $100,000 to $149,999'
#  'VALUE - $150,000 to $199,999' 'VALUE - $200,000 to $299,999'
#  'VALUE - $300,000 to $499,999' 'VALUE - $500,000 to $999,999'
#  'VALUE - $1,000,000 or more' 'VALUE - Median (dollars)' 'MORTGAGE STATUS'
#  'MORTGAGE STATUS - Owner-occupied units'
#  'MORTGAGE STATUS - Housing units with a mortgage'
#  'MORTGAGE STATUS - Housing units without a mortgage'
#  'SELECTED MONTHLY OWNER COSTS (SMOC)'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units with a mortgage'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units with a mortgage - Less than $500'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units with a mortgage - $500 to $999'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units with a mortgage - $1,000 to $1,499'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units with a mortgage - $1,500 to $1,999'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units with a mortgage - $2,000 to $2,499'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units with a mortgage - $2,500 to $2,999'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units with a mortgage - $3,000 or more'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units with a mortgage - Median (dollars)'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units without a mortgage'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units without a mortgage - Less than $250'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units without a mortgage - $250 to $399'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units without a mortgage - $400 to $599'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units without a mortgage - $600 to $799'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units without a mortgage - $800 to $999'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units without a mortgage - $1,000 or more'
#  'SELECTED MONTHLY OWNER COSTS (SMOC) - Housing units without a mortgage - Median (dollars)'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing units with a mortgage (excluding units where SMOCAPI cannot be computed) - Less than 20.0 percent'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing units with a mortgage (excluding units where SMOCAPI cannot be computed) - 20.0 to 24.9 percent'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing units with a mortgage (excluding units where SMOCAPI cannot be computed) - 25.0 to 29.9 percent'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing units with a mortgage (excluding units where SMOCAPI cannot be computed) - 30.0 to 34.9 percent'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing units with a mortgage (excluding units where SMOCAPI cannot be computed) - 35.0 percent or more'
#  'Not computed'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - Less than 10.0 percent'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - 10.0 to 14.9 percent'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - 15.0 to 19.9 percent'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - 20.0 to 24.9 percent'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - 25.0 to 29.9 percent'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - 30.0 to 34.9 percent'
#  'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI) - Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed) - 35.0 percent or more'
#  'GROSS RENT' 'GROSS RENT - Occupied units paying rent'
#  'GROSS RENT - Less than $500' 'GROSS RENT - $500 to $999'
#  'GROSS RENT - $1,000 to $1,499' 'GROSS RENT - $1,500 to $1,999'
#  'GROSS RENT - $2,000 to $2,499' 'GROSS RENT - $2,500 to $2,999'
#  'GROSS RENT - $3,000 or more' 'GROSS RENT - Median (dollars)'
#  'GROSS RENT - No rent paid'
#  'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)'
#  'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - Occupied units paying rent (excluding units where GRAPI cannot be computed)'
#  'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - Less than 15.0 percent'
#  'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 15.0 to 19.9 percent'
#  'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 20.0 to 24.9 percent'
#  'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 25.0 to 29.9 percent'
#  'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 30.0 to 34.9 percent'
#  'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 35.0 percent or more']

# %%
# CLEAN UP DATA AND DROP REDUNDANT INFO FROM HOUSING DATASET FUNCTION

def clean_up_data_housing(data):
    # drop unneccessary rows and rows with placeholders
    invalid_rows = data['PRF_ESTIMATE'].isin(['N', '(X)']) | data['PRF_ESTIMATE'].isna()
    data = data[~invalid_rows]

    # Drop rows where 'TITLE' contains 'Not computed'
    data = data[~data['TITLE'].str.contains('Not computed', na=False)]

    # The rows associated with these (profln) contain duplicated data
    profln_to_remove = ['5.5-6','15.5-16', '26.5-27', '38',                        # Duplicated Total Housing Units
                        '44.5-45','44.5-50', '56.5-57', '61.5-62','71.5-72', '75.5-76', #Dup. Occupied HU
                        '79.5-80', '89.5-90', '92.5-93','109.5-110','92.5-102', '109.5-117', #Mortgage/No Mortgage
                        '135.5-136']                                                       #Dup. HU Renting
    
    data = data[~data['PROFLN'].isin(profln_to_remove)]

    # Delete the margin of error columns
    data = data.drop(columns=['PRF_MG_ERROR', 'PCT_MG_ERROR'])

    # Replace '(X)' values in PCT_ESTIMATE with their PRF_ESTIMATE values (usually average and median values)
    data.loc[data['PCT_ESTIMATE'] == '(X)', 'PCT_ESTIMATE'] = data['PRF_ESTIMATE']

    # Remove '+' and ',' from 'PCT_ESTIMATE' and 'PRF_ESTIMATE', then convert to float
    for col in ['PCT_ESTIMATE', 'PRF_ESTIMATE']:
        data[col] = data[col].str.replace(',', '').str.replace('+', '').astype(float)
    
    return data

# %%
AL_housing_df = clean_up_data_housing(AL_housing_df)

# %%
format_districts(AL_housing_df)
# Out:
#      TBLID          GEOID                                            District  \
# 3     DP04  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 4     DP04  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 5     DP04  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 7     DP04  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 8     DP04  5001800US0101  Congressional District 1 (118th Congress), Alabama
# ...    ...            ...                                                 ...
# 1295  DP04  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 1296  DP04  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 1297  DP04  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 1298  DP04  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 1299  DP04  5001800US0107  Congressional District 7 (118th Congress), Alabama
#
#          PROFLN  \
# 3         0.8-1
# 4         0.8-2
# 5         0.8-3
# 7         0.8-4
# 8         0.8-5
# ...         ...
# 1295  135.5-138
# 1296  135.5-139
# 1297  135.5-140
# 1298  135.5-141
# 1299  135.5-142
#
#                                                                               TITLE  \
# 3                                           HOUSING OCCUPANCY - Total housing units
# 4                                        HOUSING OCCUPANCY - Occupied housing units
# 5                                          HOUSING OCCUPANCY - Vacant housing units
# 7                                        HOUSING OCCUPANCY - Homeowner vacancy rate
# 8                                           HOUSING OCCUPANCY - Rental vacancy rate
# ...                                                                             ...
# 1295  GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 15.0 to 19.9 percent
# 1296  GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 20.0 to 24.9 percent
# 1297  GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 25.0 to 29.9 percent
# 1298  GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 30.0 to 34.9 percent
# 1299  GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI) - 35.0 percent or more
#
#       PRF_ESTIMATE  PCT_ESTIMATE Formatted_District
# 3         349120.0      349120.0              AL-01
# 4         284318.0          81.4              AL-01
# 5          64802.0          18.6              AL-01
# 7              1.2           1.2              AL-01
# 8             13.5          13.5              AL-01
# ...            ...           ...                ...
# 1295       11550.0          11.7              AL-07
# 1296       10283.0          10.5              AL-07
# 1297        8622.0           8.8              AL-07
# 1298        9195.0           9.3              AL-07
# 1299       47758.0          48.5              AL-07
#
# [861 rows x 8 columns]

# %%
AL_housing_prf, AL_housing_pct = reorient_dfs(AL_housing_df)

# %%
AL_housing_pct
# Out:
#   Formatted_District          GEOID  BEDROOMS - 1 bedroom  \
# 0              AL-01  5001800US0101                   6.4
# 1              AL-02  5001800US0102                   5.3
# 2              AL-03  5001800US0103                   5.2
# 3              AL-04  5001800US0104                   4.7
# 4              AL-05  5001800US0105                   6.2
# 5              AL-06  5001800US0106                   5.3
# 6              AL-07  5001800US0107                   8.6
#
#    BEDROOMS - 2 bedrooms  BEDROOMS - 3 bedrooms  BEDROOMS - 4 bedrooms  \
# 0                   21.6                   49.9                   17.8
# 1                   20.5                   51.4                   18.4
# 2                   24.9                   48.4                   16.9
# 3                   23.0                   52.6                   14.9
# 4                   19.0                   46.8                   21.7
# 5                   19.8                   46.8                   20.2
# 6                   25.1                   48.3                   13.5
#
#    BEDROOMS - 5 or more bedrooms  BEDROOMS - No bedroom  \
# 0                            3.0                    1.5
# 1                            3.4                    1.1
# 2                            3.6                    1.0
# 3                            3.3                    1.6
# 4                            5.1                    1.2
# 5                            6.9                    1.0
# 6                            2.9                    1.6
#
#    GROSS RENT - $1,000 to $1,499  GROSS RENT - $1,500 to $1,999  ...  \
# 0                           35.0                            5.3  ...
# 1                           25.0                            4.4  ...
# 2                           20.2                            5.1  ...
# 3                           11.9                            1.9  ...
# 4                           28.1                            8.8  ...
# 5                           40.0                           13.9  ...
# 6                           22.9                            6.4  ...
#
#    YEAR STRUCTURE BUILT - Built 1939 or earlier  \
# 0                                           2.9
# 1                                           4.1
# 2                                           4.7
# 3                                           5.2
# 4                                           3.3
# 5                                           4.1
# 6                                           8.3
#
#    YEAR STRUCTURE BUILT - Built 1940 to 1949  \
# 0                                        3.0
# 1                                        2.6
# 2                                        4.1
# 3                                        4.4
# 4                                        2.3
# 5                                        3.5
# 6                                        6.0
#
#    YEAR STRUCTURE BUILT - Built 1950 to 1959  \
# 0                                        6.2
# 1                                        7.3
# 2                                        6.9
# 3                                        8.6
# 4                                        5.6
# 5                                        6.6
# 6                                       13.1
#
#    YEAR STRUCTURE BUILT - Built 1960 to 1969  \
# 0                                       10.0
# 1                                       10.5
# 2                                        8.9
# 3                                       11.2
# 4                                       12.8
# 5                                        8.9
# 6                                       12.5
#
#    YEAR STRUCTURE BUILT - Built 1970 to 1979  \
# 0                                       16.5
# 1                                       17.1
# 2                                       14.0
# 3                                       15.9
# 4                                       13.2
# 5                                       16.1
# 6                                       16.4
#
#    YEAR STRUCTURE BUILT - Built 1980 to 1989  \
# 0                                       13.4
# 1                                       13.8
# 2                                       14.5
# 3                                       13.6
# 4                                       13.2
# 5                                       14.7
# 6                                       12.0
#
#    YEAR STRUCTURE BUILT - Built 1990 to 1999  \
# 0                                       16.4
# 1                                       16.7
# 2                                       16.2
# 3                                       16.9
# 4                                       14.2
# 5                                       17.4
# 6                                       10.5
#
#    YEAR STRUCTURE BUILT - Built 2000 to 2009  \
# 0                                       20.1
# 1                                       15.6
# 2                                       16.5
# 3                                       13.7
# 4                                       19.7
# 5                                       18.0
# 6                                       11.2
#
#    YEAR STRUCTURE BUILT - Built 2010 to 2019  \
# 0                                       10.7
# 1                                       11.4
# 2                                       13.2
# 3                                        9.6
# 4                                       14.9
# 5                                       10.2
# 6                                        9.4
#
#    YEAR STRUCTURE BUILT - Built 2020 or later
# 0                                         0.8
# 1                                         0.9
# 2                                         1.0
# 3                                         0.8
# 4                                         0.8
# 5                                         0.6
# 6                                         0.4
#
# [7 rows x 125 columns]

# %% [markdown]
# # 2.b - Apply housing data transformation to all 50 states

# %%
## PROCESS ALL 50 STATES HOUSING FUNCTION
def process_housing(file_state_list):
    prf_dfs = []
    pct_dfs = []
    
    for file_state in file_state_list:
        csv, state = file_state

        data = load_and_rename_data(csv)
        data = update_titles_housing(data)
        data = clean_up_data_housing(data)
        data = format_districts(data)

        prf_estimate_df, pct_estimate_df = reorient_dfs(data)

        prf_dfs.append(prf_estimate_df)
        pct_dfs.append(pct_estimate_df)
    
    df_prfhousing_all = pd.concat(prf_dfs, ignore_index=True)
    df_pcthousing_all = pd.concat(pct_dfs, ignore_index=True)
    
    return df_prfhousing_all, df_pcthousing_all

# %%
file_state_list = [
 ('data/ALLCD_DP04_AK.csv', 'AK'),('data/ALLCD_DP04_AL.csv', 'AL'),('data/ALLCD_DP04_AR.csv', 'AR'),
 ('data/ALLCD_DP04_AZ.csv', 'AZ'),('data/ALLCD_DP04_CA.csv', 'CA'),('data/ALLCD_DP04_CO.csv', 'CO'),
 ('data/ALLCD_DP04_CT.csv', 'CT'),('data/ALLCD_DP04_DE.csv', 'DE'),('data/ALLCD_DP04_FL.csv', 'FL'),
 ('data/ALLCD_DP04_GA.csv', 'GA'),('data/ALLCD_DP04_HI.csv', 'HI'),('data/ALLCD_DP04_IA.csv', 'IA'),
 ('data/ALLCD_DP04_ID.csv', 'ID'),('data/ALLCD_DP04_IL.csv', 'IL'),('data/ALLCD_DP04_IN.csv', 'IN'),
 ('data/ALLCD_DP04_KS.csv', 'KS'),('data/ALLCD_DP04_KY.csv', 'KY'),('data/ALLCD_DP04_LA.csv', 'LA'),
 ('data/ALLCD_DP04_MA.csv', 'MA'),('data/ALLCD_DP04_MD.csv', 'MD'),('data/ALLCD_DP04_ME.csv', 'ME'),
 ('data/ALLCD_DP04_MI.csv', 'MI'),('data/ALLCD_DP04_MN.csv', 'MN'),('data/ALLCD_DP04_MO.csv', 'MO'),
 ('data/ALLCD_DP04_MS.csv', 'MS'),('data/ALLCD_DP04_MT.csv', 'MT'),('data/ALLCD_DP04_NC.csv', 'NC'),
 ('data/ALLCD_DP04_ND.csv', 'ND'),('data/ALLCD_DP04_NE.csv', 'NE'),('data/ALLCD_DP04_NH.csv', 'NH'),
 ('data/ALLCD_DP04_NJ.csv', 'NJ'),('data/ALLCD_DP04_NM.csv', 'NM'),('data/ALLCD_DP04_NV.csv', 'NV'),
 ('data/ALLCD_DP04_NY.csv', 'NY'),('data/ALLCD_DP04_OH.csv', 'OH'),('data/ALLCD_DP04_OK.csv', 'OK'),
 ('data/ALLCD_DP04_OR.csv', 'OR'),('data/ALLCD_DP04_PA.csv', 'PA'),('data/ALLCD_DP04_RI.csv', 'RI'),
 ('data/ALLCD_DP04_SC.csv', 'SC'),('data/ALLCD_DP04_SD.csv', 'SD'),('data/ALLCD_DP04_TN.csv', 'TN'),
 ('data/ALLCD_DP04_TX.csv', 'TX'),('data/ALLCD_DP04_UT.csv', 'UT'),('data/ALLCD_DP04_VA.csv', 'VA'),
 ('data/ALLCD_DP04_VT.csv', 'VT'),('data/ALLCD_DP04_WA.csv', 'WA'),('data/ALLCD_DP04_WI.csv', 'WI'),
 ('data/ALLCD_DP04_WV.csv', 'WV'),('data/ALLCD_DP04_WY.csv', 'WY')
]


df_prfhousing_all, df_pcthousing_all = process_housing(file_state_list)

# %%
df_prfhousing_all.columns
# Out:
# Index(['Formatted_District', 'GEOID', 'BEDROOMS - 1 bedroom',
#        'BEDROOMS - 2 bedrooms', 'BEDROOMS - 3 bedrooms',
#        'BEDROOMS - 4 bedrooms', 'BEDROOMS - 5 or more bedrooms',
#        'BEDROOMS - No bedroom', 'GROSS RENT - $1,000 to $1,499',
#        'GROSS RENT - $1,500 to $1,999',
#        ...
#        'YEAR STRUCTURE BUILT - Built 1939 or earlier',
#        'YEAR STRUCTURE BUILT - Built 1940 to 1949',
#        'YEAR STRUCTURE BUILT - Built 1950 to 1959',
#        'YEAR STRUCTURE BUILT - Built 1960 to 1969',
#        'YEAR STRUCTURE BUILT - Built 1970 to 1979',
#        'YEAR STRUCTURE BUILT - Built 1980 to 1989',
#        'YEAR STRUCTURE BUILT - Built 1990 to 1999',
#        'YEAR STRUCTURE BUILT - Built 2000 to 2009',
#        'YEAR STRUCTURE BUILT - Built 2010 to 2019',
#        'YEAR STRUCTURE BUILT - Built 2020 or later'],
#       dtype='object', length=125)

# %% [markdown]
# # _______________________________________________________________________________________________________________

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 3.a- State-Level Social Data Transformation (Alabama)

# %%
## LOAD_AND_RENAME_DATA FUNCTION REMAINS THE SAME
AL_social_df = load_and_rename_data('data/ALLCD_DP02_AL.csv')

# %%
def update_titles_social(data):
    # Create the title_dict
    title_dict = dict(zip(data['PROFLN'], data['TITLE']))

    ####### DICTIONARIES FOR PROFLN NUMBERS THAT NEED A DIRECT MAPPING#######
    # "HOUSEHOLDS BY TYPE" category
    households_by_type_dict = {
        '2': '1-2', '3': '1-2-3', '4': '1-4', '5': '1-4-5',
        '6': '1-6', '7': '1-6-7', '8': '1-6-8', '9': '1-6-9',
        '10': '1-10', '11': '1-10-11', '12': '1-10-12', '13': '1-10-13'
    }
    # "FERTILITY" category
    fertility_dict = {
        '37': '36.5-37', '38': '36.5-38', '39': '36.5-37-39', 
        '40': '36.5-37-40', '41': '36.5-37-41', '42': '36.5-37-42', 
        '43': '36.5-37-43'
    }
    # "GRANDPARENTS" category
    grandparents_dict = {
        '44': '43.5-44', '45': '43.5-44-45', '45.9': '45-45.9',
        '46': '45-45.9-46', '47': '45-45.9-47', '48': '45-45.9-48',
        '49': '45-45.9-49', '51': '50-51', '52': '50-52'
    }
    # "VETERAN STATUS" category
    veteran_status_dict = {
        '69': '68.5-69', '70': '68.5-70'
    }
    # "PLACE OF BIRTH" category
    place_of_birth_dict = {
        '88': '87.5-88', '89': '87.5-89', '90': '87.5-89-90', 
        '91': '87.5-89-91', '92': '87.5-89-92', '93': '87.5-89-93', 
        '94': '87.5-94'
    }
    # "U.S. CITIZENSHIP STATUS" category
    citizenship_status_dict = {
        '96': '95-96', '97': '95-97'
    }
    # "YEAR OF ENTRY" category
    year_of_entry_dict = {
        '99': '98-99', '100': '98-99-100', '101': '98-99-101',
        '102': '98-102', '103': '98-102-103', '104': '98-102-104'
    }
    # "LANGUAGE SPOKEN AT HOME" category
    language_spoken_dict = {
        '112': '111.5-112', '113': '111.5-113', '114': '111.5-114',
        '115': '111.5-114-115', '116': '111.5-116', '117': '111.5-114-117',
        '118': '111.5-118', '119': '111.5-118-119', '120': '111.5-120',
        '121': '111.5-120-121', '122': '111.5-114-122', '123': '111.5-114-122-123'
    }
    # "COMPUTERS AND INTERNET USE" category
    computers_and_internet_use_dict = {
        '152': '151.5-152', 
        '153': '151.5-152-153', 
        '154': '151.5-152-154'
    }
    

    ###### PROFLN NUMBERS THAT FOLLOW A SIMPLE PATTERN OVER A LONG RANGE######
    # "RELATIONSHIP" category
    for i in range(19, 25):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '18-' + str(i)
    # "MARITAL STATUS" category
    for i in range(26, 31):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '25-' + str(i)
    for i in range(32, 37):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '31-' + str(i)
    # "SCHOOL ENROLLMENT" category
    for i in range(54, 59):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '53-' + str(i)
    # "EDUCATIONAL ATTAINMENT" category
    for i in range(59, 69):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '58.5-59' + ('' if i == 59 else '-' + str(i))
    # "DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION" category
    for i in range(72, 79):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '71-' + str(i)
    # "RESIDENCE 1 YEAR AGO" category
    for i in range(80, 88):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '78.5-' + str(i)
    # "WORLD REGION OF BIRTH OF FOREIGN BORN" category
    for i in range(105, 112):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '104.5-' + str(i)
    # "ANCESTRY" category
    for i in range(125, 152):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '123.5-' + str(i)



    ###### DIRECT MAPPING #####
    for old, new in households_by_type_dict.items():
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new
    for old, new in fertility_dict.items():
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new
    for old, new in grandparents_dict.items():
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new
    for old, new in veteran_status_dict.items():
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new
    for old, new in place_of_birth_dict.items():
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new
    for old, new in citizenship_status_dict.items():
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new
    for old, new in year_of_entry_dict.items():
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new
    for old, new in language_spoken_dict.items():
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new
    for old, new in computers_and_internet_use_dict.items():
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new

    # Translate TITLE values using previously defined 'translate_profln' function
    data['PROFLN'] = data['PROFLN'].astype(str)
    data['TITLE'] = data['PROFLN'].apply(lambda x: translate_profln(x, title_dict))



    return data

# %%
AL_social_df = update_titles_social(AL_social_df)

# %%
AL_social_df['TITLE'].unique()
# Out:
# array(['SELECTED SOCIAL CHARACTERISTICS IN THE UNITED STATES', 'nan',
#        'HOUSEHOLDS BY TYPE', 'Total households',
#        'Total households - Married-couple household',
#        'Total households - Married-couple household - With children of the householder under 18 years',
#        'Total households - Cohabiting couple household',
#        'Total households - Cohabiting couple household - With children of the householder under 18 years',
#        'Total households - Male householder, no spouse/partner present',
#        'Total households - Male householder, no spouse/partner present - With children of the householder under 18 years',
#        'Total households - Male householder, no spouse/partner present - Householder living alone',
#        'Total households - Male householder, no spouse/partner present - 65 years and over',
#        'Total households - Female householder, no spouse/partner present',
#        'Total households - Female householder, no spouse/partner present - With children of the householder under 18 years',
#        'Total households - Female householder, no spouse/partner present - Householder living alone',
#        'Total households - Female householder, no spouse/partner present - 65 years and over',
#        'Households with one or more people under 18 years',
#        'Households with one or more people 65 years and over',
#        'Average household size', 'Average family size', 'RELATIONSHIP',
#        'Population in households',
#        'Population in households - Householder',
#        'Population in households - Spouse',
#        'Population in households - Unmarried partner',
#        'Population in households - Child',
#        'Population in households - Other relatives',
#        'Population in households - Other nonrelatives', 'MARITAL STATUS',
#        'Males 15 years and over',
#        'Males 15 years and over - Never married',
#        'Males 15 years and over - Now married, except separated',
#        'Males 15 years and over - Separated',
#        'Males 15 years and over - Widowed',
#        'Males 15 years and over - Divorced', 'Females 15 years and over',
#        'Females 15 years and over - Never married',
#        'Females 15 years and over - Now married, except separated',
#        'Females 15 years and over - Separated',
#        'Females 15 years and over - Widowed',
#        'Females 15 years and over - Divorced', 'FERTILITY',
#        'FERTILITY - Number of women 15 to 50 years old who had a birth in the past 12 months',
#        'FERTILITY - Unmarried women (widowed, divorced, and never married)',
#        'FERTILITY - Number of women 15 to 50 years old who had a birth in the past 12 months - Per 1,000 unmarried women',
#        'FERTILITY - Number of women 15 to 50 years old who had a birth in the past 12 months - Per 1,000 women 15 to 50 years old',
#        'FERTILITY - Number of women 15 to 50 years old who had a birth in the past 12 months - Per 1,000 women 15 to 19 years old',
#        'FERTILITY - Number of women 15 to 50 years old who had a birth in the past 12 months - Per 1,000 women 20 to 34 years old',
#        'FERTILITY - Number of women 15 to 50 years old who had a birth in the past 12 months - Per 1,000 women 35 to 50 years old',
#        'GRANDPARENTS',
#        'GRANDPARENTS - Number of grandparents living with own grandchildren under 18 years',
#        'GRANDPARENTS - Number of grandparents living with own grandchildren under 18 years - Grandparents responsible for grandchildren',
#        'Grandparents responsible for grandchildren - Years responsible for grandchildren',
#        'Grandparents responsible for grandchildren - Years responsible for grandchildren - Less than 1 year',
#        'Grandparents responsible for grandchildren - Years responsible for grandchildren - 1 or 2 years',
#        'Grandparents responsible for grandchildren - Years responsible for grandchildren - 3 or 4 years',
#        'Grandparents responsible for grandchildren - Years responsible for grandchildren - 5 or more years',
#        'Number of grandparents responsible for own grandchildren under 18 years',
#        'Number of grandparents responsible for own grandchildren under 18 years - Who are female',
#        'Number of grandparents responsible for own grandchildren under 18 years - Who are married',
#        'SCHOOL ENROLLMENT',
#        'Population 3 years and over enrolled in school',
#        'Population 3 years and over enrolled in school - Nursery school, preschool',
#        'Population 3 years and over enrolled in school - Kindergarten',
#        'Population 3 years and over enrolled in school - Elementary school (grades 1-8)',
#        'Population 3 years and over enrolled in school - High school (grades 9-12)',
#        'Population 3 years and over enrolled in school - College or graduate school',
#        'EDUCATIONAL ATTAINMENT',
#        'EDUCATIONAL ATTAINMENT - Population 25 years and over',
#        'EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than 9th grade',
#        'EDUCATIONAL ATTAINMENT - Population 25 years and over - 9th to 12th grade, no diploma',
#        'EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate (includes equivalency)',
#        'EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college, no degree',
#        "EDUCATIONAL ATTAINMENT - Population 25 years and over - Associate's degree",
#        "EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree",
#        'EDUCATIONAL ATTAINMENT - Population 25 years and over - Graduate or professional degree',
#        'EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate or higher',
#        "EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher",
#        'VETERAN STATUS',
#        'VETERAN STATUS - Civilian population 18 years and over',
#        'VETERAN STATUS - Civilian veterans',
#        'DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION',
#        'Total Civilian Noninstitutionalized Population',
#        'Total Civilian Noninstitutionalized Population - With a disability',
#        'Total Civilian Noninstitutionalized Population - Under 18 years',
#        'Total Civilian Noninstitutionalized Population - 18 to 64 years',
#        'Total Civilian Noninstitutionalized Population - 65 years and over',
#        'RESIDENCE 1 YEAR AGO', 'Population 1 year and over',
#        'RESIDENCE 1 YEAR AGO - Same house',
#        'RESIDENCE 1 YEAR AGO - Different house (in the U.S. or abroad)',
#        'RESIDENCE 1 YEAR AGO - Different house in the U.S.',
#        'RESIDENCE 1 YEAR AGO - Same county',
#        'RESIDENCE 1 YEAR AGO - Different county',
#        'RESIDENCE 1 YEAR AGO - Same state',
#        'RESIDENCE 1 YEAR AGO - Different state',
#        'RESIDENCE 1 YEAR AGO - Abroad', 'PLACE OF BIRTH',
#        'PLACE OF BIRTH - Total population', 'PLACE OF BIRTH - Native',
#        'PLACE OF BIRTH - Native - Born in United States',
#        'PLACE OF BIRTH - Native - State of residence',
#        'PLACE OF BIRTH - Native - Different state',
#        'PLACE OF BIRTH - Native - Born in Puerto Rico, U.S. Island areas, or born abroad to American parent(s)',
#        'PLACE OF BIRTH - Foreign born', 'U.S. CITIZENSHIP STATUS',
#        'Foreign-born population',
#        'Foreign-born population - Naturalized U.S. citizen',
#        'Foreign-born population - Not a U.S. citizen', 'YEAR OF ENTRY',
#        'Population born outside the United States',
#        'Population born outside the United States - Native',
#        'Population born outside the United States - Native - Entered 2010 or later',
#        'Population born outside the United States - Native - Entered before 2010',
#        'Population born outside the United States - Foreign born',
#        'Population born outside the United States - Foreign born - Entered 2010 or later',
#        'Population born outside the United States - Foreign born - Entered before 2010',
#        'WORLD REGION OF BIRTH OF FOREIGN BORN',
#        'WORLD REGION OF BIRTH OF FOREIGN BORN - Foreign-born population, excluding population born at sea',
#        'WORLD REGION OF BIRTH OF FOREIGN BORN - Europe',
#        'WORLD REGION OF BIRTH OF FOREIGN BORN - Asia',
#        'WORLD REGION OF BIRTH OF FOREIGN BORN - Africa',
#        'WORLD REGION OF BIRTH OF FOREIGN BORN - Oceania',
#        'WORLD REGION OF BIRTH OF FOREIGN BORN - Latin America',
#        'WORLD REGION OF BIRTH OF FOREIGN BORN - Northern America',
#        'LANGUAGE SPOKEN AT HOME',
#        'LANGUAGE SPOKEN AT HOME - Population 5 years and over',
#        'LANGUAGE SPOKEN AT HOME - English only',
#        'LANGUAGE SPOKEN AT HOME - Language other than English',
#        'LANGUAGE SPOKEN AT HOME - Language other than English - Speak English less than "very well"',
#        'LANGUAGE SPOKEN AT HOME - Spanish',
#        'LANGUAGE SPOKEN AT HOME - Other Indo-European languages',
#        'LANGUAGE SPOKEN AT HOME - Other Indo-European languages - Speak English less than "very well"',
#        'LANGUAGE SPOKEN AT HOME - Asian and Pacific Islander languages',
#        'LANGUAGE SPOKEN AT HOME - Asian and Pacific Islander languages - Speak English less than "very well"',
#        'LANGUAGE SPOKEN AT HOME - Language other than English - Other languages',
#        'LANGUAGE SPOKEN AT HOME - Language other than English - Other languages - Speak English less than "very well"',
#        'ANCESTRY', 'Total population', 'ANCESTRY - American',
#        'ANCESTRY - Arab', 'ANCESTRY - Czech', 'ANCESTRY - Danish',
#        'ANCESTRY - Dutch', 'ANCESTRY - English',
#        'ANCESTRY - French (except Basque)', 'ANCESTRY - French Canadian',
#        'ANCESTRY - German', 'ANCESTRY - Greek', 'ANCESTRY - Hungarian',
#        'ANCESTRY - Irish', 'ANCESTRY - Italian', 'ANCESTRY - Lithuanian',
#        'ANCESTRY - Norwegian', 'ANCESTRY - Polish',
#        'ANCESTRY - Portuguese', 'ANCESTRY - Russian',
#        'ANCESTRY - Scotch-Irish', 'ANCESTRY - Scottish',
#        'ANCESTRY - Slovak', 'ANCESTRY - Subsaharan African',
#        'ANCESTRY - Swedish', 'ANCESTRY - Swiss', 'ANCESTRY - Ukrainian',
#        'ANCESTRY - Welsh',
#        'ANCESTRY - West Indian (excluding Hispanic origin groups)',
#        'COMPUTERS AND INTERNET USE',
#        'COMPUTERS AND INTERNET USE - Total households',
#        'COMPUTERS AND INTERNET USE - Total households - With a computer',
#        'COMPUTERS AND INTERNET USE - Total households - With a broadband Internet subscription'],
#       dtype=object)

# %%
AL_social_values = AL_social_df['TITLE'].value_counts()

# %%
print(AL_social_values)
# Out:
# TITLE
# nan                                                                                            189
# Total Civilian Noninstitutionalized Population - With a disability                              28
# LANGUAGE SPOKEN AT HOME - Language other than English - Speak English less than "very well"     14
# Population born outside the United States - Foreign born - Entered before 2010                   7
# Foreign-born population - Not a U.S. citizen                                                     7
#                                                                                               ...
# Number of grandparents responsible for own grandchildren under 18 years                          7
# Number of grandparents responsible for own grandchildren under 18 years - Who are female         7
# Number of grandparents responsible for own grandchildren under 18 years - Who are married        7
# SCHOOL ENROLLMENT                                                                                7
# COMPUTERS AND INTERNET USE - Total households - With a broadband Internet subscription           7
# Name: count, Length: 170, dtype: int64

# %%
import pandas as pd

# Set options to display more rows, for example, up to 500 rows
pd.set_option('display.max_rows', 500)

# Display the value counts for the 'TITLE' column
AL_social_values = AL_social_df['TITLE'].value_counts()
print(AL_social_values)
# Out:
# TITLE
# nan                                                                                                                                189
# Total Civilian Noninstitutionalized Population - With a disability                                                                  28
# LANGUAGE SPOKEN AT HOME - Language other than English - Speak English less than "very well"                                         14
# Population born outside the United States - Foreign born - Entered before 2010                                                       7
# Foreign-born population - Not a U.S. citizen                                                                                         7
# YEAR OF ENTRY                                                                                                                        7
# Population born outside the United States                                                                                            7
# Population born outside the United States - Native                                                                                   7
# Population born outside the United States - Native - Entered 2010 or later                                                           7
# Population born outside the United States - Native - Entered before 2010                                                             7
# Population born outside the United States - Foreign born                                                                             7
# Population born outside the United States - Foreign born - Entered 2010 or later                                                     7
# WORLD REGION OF BIRTH OF FOREIGN BORN                                                                                                7
# Foreign-born population                                                                                                              7
# WORLD REGION OF BIRTH OF FOREIGN BORN - Foreign-born population, excluding population born at sea                                    7
# WORLD REGION OF BIRTH OF FOREIGN BORN - Europe                                                                                       7
# WORLD REGION OF BIRTH OF FOREIGN BORN - Asia                                                                                         7
# WORLD REGION OF BIRTH OF FOREIGN BORN - Africa                                                                                       7
# WORLD REGION OF BIRTH OF FOREIGN BORN - Oceania                                                                                      7
# WORLD REGION OF BIRTH OF FOREIGN BORN - Latin America                                                                                7
# WORLD REGION OF BIRTH OF FOREIGN BORN - Northern America                                                                             7
# Foreign-born population - Naturalized U.S. citizen                                                                                   7
# U.S. CITIZENSHIP STATUS                                                                                                              7
# LANGUAGE SPOKEN AT HOME - Population 5 years and over                                                                                7
# PLACE OF BIRTH - Foreign born                                                                                                        7
# RESIDENCE 1 YEAR AGO                                                                                                                 7
# Population 1 year and over                                                                                                           7
# RESIDENCE 1 YEAR AGO - Same house                                                                                                    7
# RESIDENCE 1 YEAR AGO - Different house (in the U.S. or abroad)                                                                       7
# RESIDENCE 1 YEAR AGO - Different house in the U.S.                                                                                   7
# RESIDENCE 1 YEAR AGO - Same county                                                                                                   7
# RESIDENCE 1 YEAR AGO - Different county                                                                                              7
# RESIDENCE 1 YEAR AGO - Same state                                                                                                    7
# RESIDENCE 1 YEAR AGO - Different state                                                                                               7
# RESIDENCE 1 YEAR AGO - Abroad                                                                                                        7
# PLACE OF BIRTH                                                                                                                       7
# PLACE OF BIRTH - Total population                                                                                                    7
# PLACE OF BIRTH - Native                                                                                                              7
# PLACE OF BIRTH - Native - Born in United States                                                                                      7
# PLACE OF BIRTH - Native - State of residence                                                                                         7
# PLACE OF BIRTH - Native - Different state                                                                                            7
# PLACE OF BIRTH - Native - Born in Puerto Rico, U.S. Island areas, or born abroad to American parent(s)                               7
# LANGUAGE SPOKEN AT HOME                                                                                                              7
# SELECTED SOCIAL CHARACTERISTICS IN THE UNITED STATES                                                                                 7
# Total Civilian Noninstitutionalized Population - 65 years and over                                                                   7
# ANCESTRY - Slovak                                                                                                                    7
# ANCESTRY - Italian                                                                                                                   7
# ANCESTRY - Lithuanian                                                                                                                7
# ANCESTRY - Norwegian                                                                                                                 7
# ANCESTRY - Polish                                                                                                                    7
# ANCESTRY - Portuguese                                                                                                                7
# ANCESTRY - Russian                                                                                                                   7
# ANCESTRY - Scotch-Irish                                                                                                              7
# ANCESTRY - Scottish                                                                                                                  7
# ANCESTRY - Subsaharan African                                                                                                        7
# LANGUAGE SPOKEN AT HOME - Language other than English                                                                                7
# ANCESTRY - Swedish                                                                                                                   7
# ANCESTRY - Swiss                                                                                                                     7
# ANCESTRY - Ukrainian                                                                                                                 7
# ANCESTRY - Welsh                                                                                                                     7
# ANCESTRY - West Indian (excluding Hispanic origin groups)                                                                            7
# COMPUTERS AND INTERNET USE                                                                                                           7
# COMPUTERS AND INTERNET USE - Total households                                                                                        7
# COMPUTERS AND INTERNET USE - Total households - With a computer                                                                      7
# ANCESTRY - Irish                                                                                                                     7
# ANCESTRY - Hungarian                                                                                                                 7
# ANCESTRY - Greek                                                                                                                     7
# ANCESTRY - German                                                                                                                    7
# LANGUAGE SPOKEN AT HOME - Spanish                                                                                                    7
# LANGUAGE SPOKEN AT HOME - Other Indo-European languages                                                                              7
# LANGUAGE SPOKEN AT HOME - Other Indo-European languages - Speak English less than "very well"                                        7
# LANGUAGE SPOKEN AT HOME - Asian and Pacific Islander languages                                                                       7
# LANGUAGE SPOKEN AT HOME - Asian and Pacific Islander languages - Speak English less than "very well"                                 7
# LANGUAGE SPOKEN AT HOME - Language other than English - Other languages                                                              7
# LANGUAGE SPOKEN AT HOME - Language other than English - Other languages - Speak English less than "very well"                        7
# ANCESTRY                                                                                                                             7
# Total population                                                                                                                     7
# ANCESTRY - American                                                                                                                  7
# ANCESTRY - Arab                                                                                                                      7
# ANCESTRY - Czech                                                                                                                     7
# ANCESTRY - Danish                                                                                                                    7
# ANCESTRY - Dutch                                                                                                                     7
# ANCESTRY - English                                                                                                                   7
# ANCESTRY - French (except Basque)                                                                                                    7
# ANCESTRY - French Canadian                                                                                                           7
# LANGUAGE SPOKEN AT HOME - English only                                                                                               7
# Total Civilian Noninstitutionalized Population - 18 to 64 years                                                                      7
# Total Civilian Noninstitutionalized Population - Under 18 years                                                                      7
# Population in households                                                                                                             7
# Population in households - Spouse                                                                                                    7
# Population in households - Unmarried partner                                                                                         7
# Population in households - Child                                                                                                     7
# Population in households - Other relatives                                                                                           7
# Population in households - Other nonrelatives                                                                                        7
# MARITAL STATUS                                                                                                                       7
# Males 15 years and over                                                                                                              7
# Males 15 years and over - Never married                                                                                              7
# Males 15 years and over - Now married, except separated                                                                              7
# Males 15 years and over - Separated                                                                                                  7
# Males 15 years and over - Widowed                                                                                                    7
# Males 15 years and over - Divorced                                                                                                   7
# Females 15 years and over                                                                                                            7
# Females 15 years and over - Never married                                                                                            7
# Females 15 years and over - Now married, except separated                                                                            7
# Females 15 years and over - Separated                                                                                                7
# Females 15 years and over - Widowed                                                                                                  7
# Population in households - Householder                                                                                               7
# RELATIONSHIP                                                                                                                         7
# FERTILITY                                                                                                                            7
# Average family size                                                                                                                  7
# HOUSEHOLDS BY TYPE                                                                                                                   7
# Total households                                                                                                                     7
# Total households - Married-couple household                                                                                          7
# Total households - Married-couple household - With children of the householder under 18 years                                        7
# Total households - Cohabiting couple household                                                                                       7
# Total households - Cohabiting couple household - With children of the householder under 18 years                                     7
# Total households - Male householder, no spouse/partner present                                                                       7
# Total households - Male householder, no spouse/partner present - With children of the householder under 18 years                     7
# Total households - Male householder, no spouse/partner present - Householder living alone                                            7
# Total households - Male householder, no spouse/partner present - 65 years and over                                                   7
# Total households - Female householder, no spouse/partner present                                                                     7
# Total households - Female householder, no spouse/partner present - With children of the householder under 18 years                   7
# Total households - Female householder, no spouse/partner present - Householder living alone                                          7
# Total households - Female householder, no spouse/partner present - 65 years and over                                                 7
# Households with one or more people under 18 years                                                                                    7
# Households with one or more people 65 years and over                                                                                 7
# Average household size                                                                                                               7
# Females 15 years and over - Divorced                                                                                                 7
# FERTILITY - Number of women 15 to 50 years old who had a birth in the past 12 months                                                 7
# Total Civilian Noninstitutionalized Population                                                                                       7
# Population 3 years and over enrolled in school - Kindergarten                                                                        7
# Population 3 years and over enrolled in school - High school (grades 9-12)                                                           7
# Population 3 years and over enrolled in school - College or graduate school                                                          7
# EDUCATIONAL ATTAINMENT                                                                                                               7
# EDUCATIONAL ATTAINMENT - Population 25 years and over                                                                                7
# EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than 9th grade                                                          7
# EDUCATIONAL ATTAINMENT - Population 25 years and over - 9th to 12th grade, no diploma                                                7
# EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate (includes equivalency)                                  7
# EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college, no degree                                                      7
# EDUCATIONAL ATTAINMENT - Population 25 years and over - Associate's degree                                                           7
# EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree                                                            7
# EDUCATIONAL ATTAINMENT - Population 25 years and over - Graduate or professional degree                                              7
# EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate or higher                                               7
# EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher                                                  7
# VETERAN STATUS                                                                                                                       7
# VETERAN STATUS - Civilian population 18 years and over                                                                               7
# VETERAN STATUS - Civilian veterans                                                                                                   7
# DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION                                                                    7
# Population 3 years and over enrolled in school - Elementary school (grades 1-8)                                                      7
# Population 3 years and over enrolled in school - Nursery school, preschool                                                           7
# FERTILITY - Unmarried women (widowed, divorced, and never married)                                                                   7
# Population 3 years and over enrolled in school                                                                                       7
# FERTILITY - Number of women 15 to 50 years old who had a birth in the past 12 months - Per 1,000 unmarried women                     7
# FERTILITY - Number of women 15 to 50 years old who had a birth in the past 12 months - Per 1,000 women 15 to 50 years old            7
# FERTILITY - Number of women 15 to 50 years old who had a birth in the past 12 months - Per 1,000 women 15 to 19 years old            7
# FERTILITY - Number of women 15 to 50 years old who had a birth in the past 12 months - Per 1,000 women 20 to 34 years old            7
# FERTILITY - Number of women 15 to 50 years old who had a birth in the past 12 months - Per 1,000 women 35 to 50 years old            7
# GRANDPARENTS                                                                                                                         7
# GRANDPARENTS - Number of grandparents living with own grandchildren under 18 years                                                   7
# GRANDPARENTS - Number of grandparents living with own grandchildren under 18 years - Grandparents responsible for grandchildren      7
# Grandparents responsible for grandchildren - Years responsible for grandchildren                                                     7
# Grandparents responsible for grandchildren - Years responsible for grandchildren - Less than 1 year                                  7
# Grandparents responsible for grandchildren - Years responsible for grandchildren - 1 or 2 years                                      7
# Grandparents responsible for grandchildren - Years responsible for grandchildren - 3 or 4 years                                      7
# Grandparents responsible for grandchildren - Years responsible for grandchildren - 5 or more years                                   7
# Number of grandparents responsible for own grandchildren under 18 years                                                              7
# Number of grandparents responsible for own grandchildren under 18 years - Who are female                                             7
# Number of grandparents responsible for own grandchildren under 18 years - Who are married                                            7
# SCHOOL ENROLLMENT                                                                                                                    7
# COMPUTERS AND INTERNET USE - Total households - With a broadband Internet subscription                                               7
# Name: count, dtype: int64

# %%
# CLEAN UP DATA AND DROP REDUNDANT INFO FROM SOCIAL DATASET FUNCTION

def clean_up_data_social(data):
    # drop unneccessary rows and rows with placeholders
    invalid_rows = (data['PRF_ESTIMATE'].isin(['N', '(X)']) | 
                data['PCT_ESTIMATE'].isin(['N', '(X)']) |
                data['PRF_ESTIMATE'].isna())
    data = data[~invalid_rows]

    # Drop rows where 'TITLE' contains 'Not computed'
    data = data[~data['TITLE'].str.contains('Not computed', na=False)]

    # The rows associated with these (profln) contain duplicated data
    profln_to_remove = ['50','95','98-102', 
                        '1','152','124']  # Duplicated Grandparents, Foreign born, Total households, total pop               
    
    data = data[~data['PROFLN'].isin(profln_to_remove)]

    # Delete the margin of error columns
    data = data.drop(columns=['PRF_MG_ERROR', 'PCT_MG_ERROR'])

    # Replace '(X)' values in PCT_ESTIMATE with their PRF_ESTIMATE values (usually average and median values)
    data.loc[data['PCT_ESTIMATE'] == '(X)', 'PCT_ESTIMATE'] = data['PRF_ESTIMATE']

    # Remove '+' and ',' from 'PCT_ESTIMATE' and 'PRF_ESTIMATE', then convert to float
    for col in ['PCT_ESTIMATE', 'PRF_ESTIMATE']:
        data[col] = data[col].str.replace(',', '').str.replace('+', '').astype(float)
    
    return data

# %%
AL_social_df = clean_up_data_social(AL_social_df)

# %%
format_districts(AL_social_df)
# Out:
#      TBLID          GEOID                                            District  \
# 4     DP02  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 5     DP02  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 6     DP02  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 7     DP02  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 8     DP02  5001800US0101  Congressional District 1 (118th Congress), Alabama
# ...    ...            ...                                                 ...
# 1393  DP02  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 1394  DP02  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 1397  DP02  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 1398  DP02  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 1399  DP02  5001800US0107  Congressional District 7 (118th Congress), Alabama
#
#              PROFLN  \
# 4               1-2
# 5             1-2-3
# 6               1-4
# 7             1-4-5
# 8               1-6
# ...             ...
# 1393      123.5-150
# 1394      123.5-151
# 1397      151.5-152
# 1398  151.5-152-153
# 1399  151.5-152-154
#
#                                                                                                  TITLE  \
# 4                                                          Total households - Married-couple household
# 5        Total households - Married-couple household - With children of the householder under 18 years
# 6                                                       Total households - Cohabiting couple household
# 7     Total households - Cohabiting couple household - With children of the householder under 18 years
# 8                                       Total households - Male householder, no spouse/partner present
# ...                                                                                                ...
# 1393                                                                                  ANCESTRY - Welsh
# 1394                                         ANCESTRY - West Indian (excluding Hispanic origin groups)
# 1397                                                     COMPUTERS AND INTERNET USE - Total households
# 1398                                   COMPUTERS AND INTERNET USE - Total households - With a computer
# 1399            COMPUTERS AND INTERNET USE - Total households - With a broadband Internet subscription
#
#       PRF_ESTIMATE  PCT_ESTIMATE Formatted_District
# 4         130334.0          45.8              AL-01
# 5          43295.0          15.2              AL-01
# 6          15486.0           5.4              AL-01
# 7           5100.0           1.8              AL-01
# 8          48843.0          17.2              AL-01
# ...            ...           ...                ...
# 1393        1085.0           0.2              AL-07
# 1394        1569.0           0.2              AL-07
# 1397      281678.0      281678.0              AL-07
# 1398      256911.0          91.2              AL-07
# 1399      230393.0          81.8              AL-07
#
# [945 rows x 8 columns]

# %%
AL_social_prf, AL_social_pct = reorient_dfs(AL_social_df)

# %%
AL_social_prf
# Out:
#   Formatted_District          GEOID  ANCESTRY - American  ANCESTRY - Arab  \
# 0              AL-01  5001800US0101              85851.0           2898.0
# 1              AL-02  5001800US0102             111963.0            428.0
# 2              AL-03  5001800US0103              89427.0            386.0
# 3              AL-04  5001800US0104             127339.0             18.0
# 4              AL-05  5001800US0105              73905.0            914.0
# 5              AL-06  5001800US0106              69237.0           3851.0
# 6              AL-07  5001800US0107              88905.0           1073.0
#
#    ANCESTRY - Czech  ANCESTRY - Danish  ANCESTRY - Dutch  ANCESTRY - English  \
# 0            3103.0             1494.0            4165.0             80842.0
# 1             576.0             1907.0            2751.0             78863.0
# 2            1364.0              266.0            3261.0             89071.0
# 3             298.0               97.0            2780.0             99468.0
# 4             824.0             1070.0            7210.0            109339.0
# 5             782.0             2132.0            3306.0            108847.0
# 6              96.0              117.0            1089.0             47126.0
#
#    ANCESTRY - French (except Basque)  ANCESTRY - French Canadian  ...  \
# 0                            17792.0                      2262.0  ...
# 1                             7619.0                       669.0  ...
# 2                             4829.0                      1280.0  ...
# 3                             5918.0                       496.0  ...
# 4                             8309.0                      1338.0  ...
# 5                             7118.0                       634.0  ...
# 6                             4058.0                       408.0  ...
#
#    Total households - Female householder, no spouse/partner present - Householder living alone  \
# 0                                                                                      51827.0
# 1                                                                                      48383.0
# 2                                                                                      45152.0
# 3                                                                                      41982.0
# 4                                                                                      46009.0
# 5                                                                                      46059.0
# 6                                                                                      55289.0
#
#    Total households - Female householder, no spouse/partner present - With children of the householder under 18 years  \
# 0                                                                                                             16909.0
# 1                                                                                                             22848.0
# 2                                                                                                             16901.0
# 3                                                                                                             12226.0
# 4                                                                                                             13644.0
# 5                                                                                                             12872.0
# 6                                                                                                             23437.0
#
#    Total households - Male householder, no spouse/partner present  \
# 0                                                         48843.0
# 1                                                         50949.0
# 2                                                         56789.0
# 3                                                         46599.0
# 4                                                         52783.0
# 5                                                         46798.0
# 6                                                         62561.0
#
#    Total households - Male householder, no spouse/partner present - 65 years and over  \
# 0                                                                             11128.0
# 1                                                                             11646.0
# 2                                                                             10755.0
# 3                                                                             11415.0
# 4                                                                             10481.0
# 5                                                                              9359.0
# 6                                                                             13149.0
#
#    Total households - Male householder, no spouse/partner present - Householder living alone  \
# 0                                                                                    37814.0
# 1                                                                                    38804.0
# 2                                                                                    40885.0
# 3                                                                                    35201.0
# 4                                                                                    38992.0
# 5                                                                                    33613.0
# 6                                                                                    47170.0
#
#    Total households - Male householder, no spouse/partner present - With children of the householder under 18 years  \
# 0                                                                                                            2255.0
# 1                                                                                                            3786.0
# 2                                                                                                            3686.0
# 3                                                                                                            2391.0
# 4                                                                                                            4165.0
# 5                                                                                                            2995.0
# 6                                                                                                            3945.0
#
#    Total households - Married-couple household  \
# 0                                     130334.0
# 1                                     121419.0
# 2                                     128714.0
# 3                                     140299.0
# 4                                     148603.0
# 5                                     142940.0
# 6                                      92083.0
#
#    Total households - Married-couple household - With children of the householder under 18 years  \
# 0                                                                                        43295.0
# 1                                                                                        41229.0
# 2                                                                                        42975.0
# 3                                                                                        50644.0
# 4                                                                                        54416.0
# 5                                                                                        54564.0
# 6                                                                                        27921.0
#
#    VETERAN STATUS - Civilian population 18 years and over  \
# 0                                                562917.0
# 1                                                541141.0
# 2                                                564164.0
# 3                                                557197.0
# 4                                                570798.0
# 5                                                544098.0
# 6                                                558857.0
#
#    VETERAN STATUS - Civilian veterans
# 0                             49759.0
# 1                             54312.0
# 2                             45780.0
# 3                             36859.0
# 4                             56560.0
# 5                             33133.0
# 6                             38739.0
#
# [7 rows x 133 columns]

# %% [markdown]
# # 3.b - Apply social data transformation to all 50 states

# %%
## PROCESS ALL 50 STATES SOCIAL FUNCTION
def process_social(file_state_list):
    prf_dfs = []
    pct_dfs = []
    
    for file_state in file_state_list:
        csv, state = file_state

        data = load_and_rename_data(csv)
        data = update_titles_social(data)
        data = clean_up_data_social(data)
        data = format_districts(data)

        prf_estimate_df, pct_estimate_df = reorient_dfs(data)

        prf_dfs.append(prf_estimate_df)
        pct_dfs.append(pct_estimate_df)
    
    df_prfsocial_all = pd.concat(prf_dfs, ignore_index=True)
    df_pctsocial_all = pd.concat(pct_dfs, ignore_index=True)
    
    return df_prfsocial_all, df_pctsocial_all

# %%
file_state_list = [
 ('data/ALLCD_DP02_AK.csv', 'AK'),('data/ALLCD_DP02_AL.csv', 'AL'),('data/ALLCD_DP02_AR.csv', 'AR'),
 ('data/ALLCD_DP02_AZ.csv', 'AZ'),('data/ALLCD_DP02_CA.csv', 'CA'),('data/ALLCD_DP02_CO.csv', 'CO'),
 ('data/ALLCD_DP02_CT.csv', 'CT'),('data/ALLCD_DP02_DE.csv', 'DE'),('data/ALLCD_DP02_FL.csv', 'FL'),
 ('data/ALLCD_DP02_GA.csv', 'GA'),('data/ALLCD_DP02_HI.csv', 'HI'),('data/ALLCD_DP02_IA.csv', 'IA'),
 ('data/ALLCD_DP02_ID.csv', 'ID'),('data/ALLCD_DP02_IL.csv', 'IL'),('data/ALLCD_DP02_IN.csv', 'IN'),
 ('data/ALLCD_DP02_KS.csv', 'KS'),('data/ALLCD_DP02_KY.csv', 'KY'),('data/ALLCD_DP02_LA.csv', 'LA'),
 ('data/ALLCD_DP02_MA.csv', 'MA'),('data/ALLCD_DP02_MD.csv', 'MD'),('data/ALLCD_DP02_ME.csv', 'ME'),
 ('data/ALLCD_DP02_MI.csv', 'MI'),('data/ALLCD_DP02_MN.csv', 'MN'),('data/ALLCD_DP02_MO.csv', 'MO'),
 ('data/ALLCD_DP02_MS.csv', 'MS'),('data/ALLCD_DP02_MT.csv', 'MT'),('data/ALLCD_DP02_NC.csv', 'NC'),
 ('data/ALLCD_DP02_ND.csv', 'ND'),('data/ALLCD_DP02_NE.csv', 'NE'),('data/ALLCD_DP02_NH.csv', 'NH'),
 ('data/ALLCD_DP02_NJ.csv', 'NJ'),('data/ALLCD_DP02_NM.csv', 'NM'),('data/ALLCD_DP02_NV.csv', 'NV'),
 ('data/ALLCD_DP02_NY.csv', 'NY'),('data/ALLCD_DP02_OH.csv', 'OH'),('data/ALLCD_DP02_OK.csv', 'OK'),
 ('data/ALLCD_DP02_OR.csv', 'OR'),('data/ALLCD_DP02_PA.csv', 'PA'),('data/ALLCD_DP02_RI.csv', 'RI'),
 ('data/ALLCD_DP02_SC.csv', 'SC'),('data/ALLCD_DP02_SD.csv', 'SD'),('data/ALLCD_DP02_TN.csv', 'TN'),
 ('data/ALLCD_DP02_TX.csv', 'TX'),('data/ALLCD_DP02_UT.csv', 'UT'),('data/ALLCD_DP02_VA.csv', 'VA'),
 ('data/ALLCD_DP02_VT.csv', 'VT'),('data/ALLCD_DP02_WA.csv', 'WA'),('data/ALLCD_DP02_WI.csv', 'WI'),
 ('data/ALLCD_DP02_WV.csv', 'WV'),('data/ALLCD_DP02_WY.csv', 'WY')
]


df_prfsocial_all, df_pctsocial_all = process_social(file_state_list)

# %%
df_pctsocial_all.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df_pctsocial_all.columns
#
# NameError: name 'df_pctsocial_all' is not defined

# %% [markdown]
# # _______________________________________________________________________________________________________________

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 4.a- State-Level Economic Data Transformation (Alabama)

# %%
AL_econ_df = load_and_rename_data('data/ALLCD_DP03_AL.csv')

# %%
def update_titles_econ(data):
   
    # Shorten two long titles--
    #INCOME AND BENEFITS (IN 2021 INFLATION-ADJUSTED DOLLARS)
    data.loc[data['PROFLN'] == '50.5', 'TITLE'] = 'INCOME AND BENEFITS' 
    #PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL
    data.loc[data['PROFLN'] == '118.5', 'TITLE'] = 'INCOME BELOW POVERTY LEVEL' 
   
    # now create the title_dict
    title_dict = dict(zip(data['PROFLN'], data['TITLE']))

    ####### DICTIONARIES FOR PROFLN NUMBERS THAT NEED A DIRECT MAPPING#######
    
    # Dictionary "MISC FEMALE EMPLOYMENT"
    misc_female_employment_dict = {
        '15': '0.8-1-14-15',
        '16': '0.8-10-16',
        '17': '0.8-10-16-17'
    }
    # Dictionary "MISC INCOME AND BENEFITS" category
    misc_income_and_benefits_dict = {
        '65': '50.5-51-64-65',
        '66': '50.5-51-66',
        '67': '50.5-51-66-67',
        '68': '50.5-51-68',
        '69': '50.5-51-68-69',
        '70': '50.5-51-70',
        '71': '50.5-51-70-71',
        '72': '50.5-51-72',
        '73': '50.5-51-72-73',
        '74': '50.5-51-74',
    }
    
    # Dictionary HEALTH INSURANCE COVERAGE category
    health_insurance_coverage_dict = {
        '95': '94.5-95',
        '96': '94.5-95-96',
        '97': '94.5-95-97',
        '98': '94.5-95-98',
        '99': '94.5-95-99',
        '100': '94.5-100',
        '101': '94.5-100-101',
        '103': '102-103',
        '104': '94.5-104',
        '105': '94.5-104-105',
        '106': '94.5-104-106',
        '107': '94.5-104-107',
        '108': '94.5-104-108',
        '109': '94.5-109',
        '110': '94.5-109-110',
        '111': '94.5-109-111',
        '112': '94.5-109-112',
        '113': '94.5-109-113',
        '114': '94.5-114',
        '115': '94.5-114-115',
        '116': '94.5-114-116',
        '117': '94.5-114-117',
        '118': '94.5-114-118'
    }
    # Dictionary FAMILY POVERTY LEVEL
    family_poverty_level_dict = {
        '119': '118.5-119',
        '120': '118.5-119-120',
        '121': '118.5-119-121',
        '122': '118.5-122',
        '123': '118.5-122-123',
        '124': '118.5-122-124',
        '125': '118.5-125',
        '126': '118.5-125-126',
        '127': '118.5-125-127'
    }


    ###### PROFLN NUMBERS THAT FOLLOW A SIMPLE PATTERN OVER A LONG RANGE######
    # EMPLOYMENT STATUS category
    for i in range(1, 10):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '0.8-1' + ('' if i == 1 else '-' + str(i))
    # "FEMALE EMPLOYMENT STATUS" category
    for i in range(10, 15):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '0.8-10' + ('' if i == 10 else '-' + str(i))
    # "COMMUTING TO WORK" category
    for i in range(18, 26):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '17.5-' + str(i)
    # "OCCUPATION" category
    for i in range(26, 32):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '25.5-' + str(i)
    # "INDUSTRY" category
    for i in range(33, 46):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '31.5-' + str(i)
    #"CLASS OF WORKER" category
    for i in range(47, 51):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '45.5-' + str(i)
    # "INCOME AND BENEFITS" category
    for i in range(52, 65):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '50.5-51-' + str(i)
    # FAMILY INCOME AND BENEFITS category
    for i in range(75, 88):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '50.5-75' + ('' if i == 75 else '-' + str(i))
    # NON-FAMILY INCOME AND BENEFITS category
    for i in range(88, 95):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '50.5-' + str(i)
    # ALL PEOPLE POVERTY LEVEL category
    for i in range (128,138):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '118.5-128'+ ('' if i == 128 else '-' + str(i))
    
    
    ###### DIRECT MAPPING #####
    for old, new in misc_female_employment_dict.items(): #Misc Female Employment
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new
    for old, new in misc_income_and_benefits_dict.items(): #Misc income and benefits
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new
    for old, new in health_insurance_coverage_dict.items(): #Health Insurance Coverage
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new
    for old, new in family_poverty_level_dict.items():     # Family poverty level
        data.loc[data['PROFLN'] == old, 'PROFLN'] = new
    

    # Translate TITLE values using previously defined 'translate_profln' function
    data['PROFLN'] = data['PROFLN'].astype(str)
    data['TITLE'] = data['PROFLN'].apply(lambda x: translate_profln(x, title_dict))

    return data

# %%
AL_econ_df = update_titles_econ(AL_econ_df)
AL_econ_df[['PROFLN','TITLE']]
# Out:
#              PROFLN  \
# 0                 0
# 1               0.5
# 2               0.8
# 3             0.8-1
# 4           0.8-1-2
# ...             ...
# 1171  118.5-128-133
# 1172  118.5-128-134
# 1173  118.5-128-135
# 1174  118.5-128-136
# 1175  118.5-128-137
#
#                                                                                   TITLE
# 0                                                     SELECTED ECONOMIC CHARACTERISTICS
# 1                                                                                   nan
# 2                                                                     EMPLOYMENT STATUS
# 3                                      EMPLOYMENT STATUS - Population 16 years and over
# 4                     EMPLOYMENT STATUS - Population 16 years and over - In labor force
# ...                                                                                 ...
# 1171                        INCOME BELOW POVERTY LEVEL - All people - 18 years and over
# 1172                           INCOME BELOW POVERTY LEVEL - All people - 18 to 64 years
# 1173                        INCOME BELOW POVERTY LEVEL - All people - 65 years and over
# 1174                       INCOME BELOW POVERTY LEVEL - All people - People in families
# 1175  INCOME BELOW POVERTY LEVEL - All people - Unrelated individuals 15 years and over
#
# [1176 rows x 2 columns]

# %%
def clean_up_data_econ(data):
    
    # Replace '(X)' values in PCT_ESTIMATE with their PRF_ESTIMATE values (and vice versa)
    data.loc[data['PCT_ESTIMATE'] == '(X)', 'PCT_ESTIMATE'] = data['PRF_ESTIMATE']
    data.loc[data['PRF_ESTIMATE'] == '(X)', 'PRF_ESTIMATE'] = data['PCT_ESTIMATE']
    
    
    # Drop unnecessary rows and rows with placeholders
    invalid_rows = (data['PRF_ESTIMATE'].isin(['N', '(X)']) | 
                data['PCT_ESTIMATE'].isin(['N', '(X)']) |
                data['PRF_ESTIMATE'].isna())
    data = data[~invalid_rows]

    # Drop rows where 'TITLE' contains 'Not computed'
    data = data[~data['TITLE'].str.contains('Not computed', na=False)]

    # The rows associated with these (profln) contain duplicated data
    profln_to_remove = ['25.5-26', '32', '46',   # Duplicated 'Employed population 16+'
                        '0.8-1-8']               # Duplicated 'Civilian labor force'
    
    data = data[~data['PROFLN'].isin(profln_to_remove)]

    # Delete the margin of error columns
    data = data.drop(columns=['PRF_MG_ERROR', 'PCT_MG_ERROR'])


    # Convert to number - Remove '+' and ',' from 'PCT_ESTIMATE' and 'PRF_ESTIMATE', then convert to float
    for col in ['PCT_ESTIMATE', 'PRF_ESTIMATE']:
        data[col] = data[col].str.replace(',', '').str.replace('+', '').astype(float)
    
    return data

# %%
AL_econ_df = clean_up_data_econ(AL_econ_df)

# %%
format_districts(AL_econ_df)
# Out:
#      TBLID          GEOID                                            District  \
# 3     DP03  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 4     DP03  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 5     DP03  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 6     DP03  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 7     DP03  5001800US0101  Congressional District 1 (118th Congress), Alabama
# ...    ...            ...                                                 ...
# 1171  DP03  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 1172  DP03  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 1173  DP03  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 1174  DP03  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 1175  DP03  5001800US0107  Congressional District 7 (118th Congress), Alabama
#
#              PROFLN  \
# 3             0.8-1
# 4           0.8-1-2
# 5           0.8-1-3
# 6           0.8-1-4
# 7           0.8-1-5
# ...             ...
# 1171  118.5-128-133
# 1172  118.5-128-134
# 1173  118.5-128-135
# 1174  118.5-128-136
# 1175  118.5-128-137
#
#                                                                                   TITLE  \
# 3                                      EMPLOYMENT STATUS - Population 16 years and over
# 4                     EMPLOYMENT STATUS - Population 16 years and over - In labor force
# 5               EMPLOYMENT STATUS - Population 16 years and over - Civilian labor force
# 6                           EMPLOYMENT STATUS - Population 16 years and over - Employed
# 7                         EMPLOYMENT STATUS - Population 16 years and over - Unemployed
# ...                                                                                 ...
# 1171                        INCOME BELOW POVERTY LEVEL - All people - 18 years and over
# 1172                           INCOME BELOW POVERTY LEVEL - All people - 18 to 64 years
# 1173                        INCOME BELOW POVERTY LEVEL - All people - 65 years and over
# 1174                       INCOME BELOW POVERTY LEVEL - All people - People in families
# 1175  INCOME BELOW POVERTY LEVEL - All people - Unrelated individuals 15 years and over
#
#       PRF_ESTIMATE  PCT_ESTIMATE Formatted_District
# 3         583074.0      583074.0              AL-01
# 4         335093.0          57.5              AL-01
# 5         333456.0          57.2              AL-01
# 6         314029.0          53.9              AL-01
# 7          19427.0           3.3              AL-01
# ...            ...           ...                ...
# 1171          19.6          19.6              AL-07
# 1172          20.9          20.9              AL-07
# 1173          15.2          15.2              AL-07
# 1174          20.7          20.7              AL-07
# 1175          32.3          32.3              AL-07
#
# [931 rows x 8 columns]

# %%
AL_econ_prf, AL_econ_pct = reorient_dfs(AL_econ_df)
AL_econ_prf
# Out:
#   Formatted_District          GEOID  CLASS OF WORKER - Government workers  \
# 0              AL-01  5001800US0101                               50470.0
# 1              AL-02  5001800US0102                               52999.0
# 2              AL-03  5001800US0103                               50660.0
# 3              AL-04  5001800US0104                               40569.0
# 4              AL-05  5001800US0105                               62558.0
# 5              AL-06  5001800US0106                               48426.0
# 6              AL-07  5001800US0107                               49367.0
#
#    CLASS OF WORKER - Private wage and salary workers  \
# 0                                           245427.0
# 1                                           226848.0
# 2                                           229463.0
# 3                                           247849.0
# 4                                           260749.0
# 5                                           277562.0
# 6                                           225287.0
#
#    CLASS OF WORKER - Self-employed in own not incorporated business workers  \
# 0                                                                   18085.0
# 1                                                                   17456.0
# 2                                                                   14093.0
# 3                                                                   19846.0
# 4                                                                   17666.0
# 5                                                                   17422.0
# 6                                                                   15865.0
#
#    CLASS OF WORKER - Unpaid family workers  \
# 0                                     47.0
# 1                                    568.0
# 2                                    213.0
# 3                                    130.0
# 4                                    810.0
# 5                                    265.0
# 6                                    215.0
#
#    COMMUTING TO WORK - Car, truck, or van -- carpooled  \
# 0                                              20665.0
# 1                                              19641.0
# 2                                              24235.0
# 3                                              29722.0
# 4                                              23614.0
# 5                                              24232.0
# 6                                              23240.0
#
#    COMMUTING TO WORK - Car, truck, or van -- drove alone  \
# 0                                               252238.0
# 1                                               256715.0
# 2                                               235963.0
# 3                                               253264.0
# 4                                               257368.0
# 5                                               261958.0
# 6                                               225829.0
#
#    COMMUTING TO WORK - Mean travel time to work (minutes)  \
# 0                                                    26.6
# 1                                                    24.1
# 2                                                    26.0
# 3                                                    25.2
# 4                                                    24.4
# 5                                                    27.0
# 6                                                    23.9
#
#    COMMUTING TO WORK - Other means  ...  INDUSTRY - Public administration  \
# 0                           3289.0  ...                           15685.0
# 1                           3722.0  ...                           23376.0
# 2                           4215.0  ...                           13598.0
# 3                           1320.0  ...                           10153.0
# 4                           3959.0  ...                           26321.0
# 5                           3200.0  ...                           15564.0
# 6                           3391.0  ...                           11651.0
#
#    INDUSTRY - Retail trade  \
# 0                  41999.0
# 1                  34878.0
# 2                  32975.0
# 3                  41709.0
# 4                  36115.0
# 5                  39310.0
# 6                  36029.0
#
#    INDUSTRY - Transportation and warehousing, and utilities  \
# 0                                                   16722.0
# 1                                                   20794.0
# 2                                                   18177.0
# 3                                                   18947.0
# 4                                                   17078.0
# 5                                                   18490.0
# 6                                                   19159.0
#
#    INDUSTRY - Wholesale trade  \
# 0                      8131.0
# 1                      6156.0
# 2                      4214.0
# 3                      7008.0
# 4                      6821.0
# 5                     11981.0
# 6                      4160.0
#
#    OCCUPATION - Management, business, science, and arts occupations  \
# 0                                                          106525.0
# 1                                                          100393.0
# 2                                                          103569.0
# 3                                                           96097.0
# 4                                                          159043.0
# 5                                                          156198.0
# 6                                                           95401.0
#
#    OCCUPATION - Natural resources, construction, and maintenance occupations  \
# 0                                                                    33295.0
# 1                                                                    28405.0
# 2                                                                    30712.0
# 3                                                                    34778.0
# 4                                                                    28587.0
# 5                                                                    31589.0
# 6                                                                    23236.0
#
#    OCCUPATION - Production, transportation, and material moving occupations  \
# 0                                                                   49331.0
# 1                                                                   56946.0
# 2                                                                   50175.0
# 3                                                                   69378.0
# 4                                                                   49293.0
# 5                                                                   40197.0
# 6                                                                   57616.0
#
#    OCCUPATION - Sales and office occupations  \
# 0                                    69133.0
# 1                                    65422.0
# 2                                    60570.0
# 3                                    59951.0
# 4                                    61892.0
# 5                                    70045.0
# 6                                    56690.0
#
#    OCCUPATION - Service occupations  Total households
# 0                           55745.0          284318.0
# 1                           46705.0          278370.0
# 2                           49403.0          278736.0
# 3                           48190.0          271053.0
# 4                           42968.0          294256.0
# 5                           45646.0          279148.0
# 6                           57791.0          281678.0
#
# [7 rows x 135 columns]

# %% [markdown]
# # 4.b - Apply economic data transformation to all 50 states

# %%
## PROCESS ALL 50 STATES HOUSING FUNCTION
def process_econ(file_state_list):
    prf_dfs = []
    pct_dfs = []
    
    for file_state in file_state_list:
        csv, state = file_state

        data = load_and_rename_data(csv)
        data = update_titles_econ(data)
        data = clean_up_data_econ(data)
        data = format_districts(data)

        prf_estimate_df, pct_estimate_df = reorient_dfs(data)

        prf_dfs.append(prf_estimate_df)
        pct_dfs.append(pct_estimate_df)
    
    df_prfecon_all = pd.concat(prf_dfs, ignore_index=True)
    df_pctecon_all = pd.concat(pct_dfs, ignore_index=True)
    
    return df_prfecon_all, df_pctecon_all

# %%
file_state_list = [
 ('data/ALLCD_DP03_AK.csv', 'AK'),('data/ALLCD_DP03_AL.csv', 'AL'),('data/ALLCD_DP03_AR.csv', 'AR'),
 ('data/ALLCD_DP03_AZ.csv', 'AZ'),('data/ALLCD_DP03_CA.csv', 'CA'),('data/ALLCD_DP03_CO.csv', 'CO'),
 ('data/ALLCD_DP03_CT.csv', 'CT'),('data/ALLCD_DP03_DE.csv', 'DE'),('data/ALLCD_DP03_FL.csv', 'FL'),
 ('data/ALLCD_DP03_GA.csv', 'GA'),('data/ALLCD_DP03_HI.csv', 'HI'),('data/ALLCD_DP03_IA.csv', 'IA'),
 ('data/ALLCD_DP03_ID.csv', 'ID'),('data/ALLCD_DP03_IL.csv', 'IL'),('data/ALLCD_DP03_IN.csv', 'IN'),
 ('data/ALLCD_DP03_KS.csv', 'KS'),('data/ALLCD_DP03_KY.csv', 'KY'),('data/ALLCD_DP03_LA.csv', 'LA'),
 ('data/ALLCD_DP03_MA.csv', 'MA'),('data/ALLCD_DP03_MD.csv', 'MD'),('data/ALLCD_DP03_ME.csv', 'ME'),
 ('data/ALLCD_DP03_MI.csv', 'MI'),('data/ALLCD_DP03_MN.csv', 'MN'),('data/ALLCD_DP03_MO.csv', 'MO'),
 ('data/ALLCD_DP03_MS.csv', 'MS'),('data/ALLCD_DP03_MT.csv', 'MT'),('data/ALLCD_DP03_NC.csv', 'NC'),
 ('data/ALLCD_DP03_ND.csv', 'ND'),('data/ALLCD_DP03_NE.csv', 'NE'),('data/ALLCD_DP03_NH.csv', 'NH'),
 ('data/ALLCD_DP03_NJ.csv', 'NJ'),('data/ALLCD_DP03_NM.csv', 'NM'),('data/ALLCD_DP03_NV.csv', 'NV'),
 ('data/ALLCD_DP03_NY.csv', 'NY'),('data/ALLCD_DP03_OH.csv', 'OH'),('data/ALLCD_DP03_OK.csv', 'OK'),
 ('data/ALLCD_DP03_OR.csv', 'OR'),('data/ALLCD_DP03_PA.csv', 'PA'),('data/ALLCD_DP03_RI.csv', 'RI'),
 ('data/ALLCD_DP03_SC.csv', 'SC'),('data/ALLCD_DP03_SD.csv', 'SD'),('data/ALLCD_DP03_TN.csv', 'TN'),
 ('data/ALLCD_DP03_TX.csv', 'TX'),('data/ALLCD_DP03_UT.csv', 'UT'),('data/ALLCD_DP03_VA.csv', 'VA'),
 ('data/ALLCD_DP03_VT.csv', 'VT'),('data/ALLCD_DP03_WA.csv', 'WA'),('data/ALLCD_DP03_WI.csv', 'WI'),
 ('data/ALLCD_DP03_WV.csv', 'WV'),('data/ALLCD_DP03_WY.csv', 'WY')
]


df_prfecon_all, df_pctecon_all = process_econ(file_state_list)

# %%
df_pctecon_all
# Out:
#     Formatted_District          GEOID  CLASS OF WORKER - Government workers  \
# 0                AK-AL  5001800US0200                                  25.8
# 1                AL-01  5001800US0101                                  16.1
# 2                AL-02  5001800US0102                                  17.8
# 3                AL-03  5001800US0103                                  17.2
# 4                AL-04  5001800US0104                                  13.2
# ..                 ...            ...                                   ...
# 430              WI-07  5001800US5507                                  13.2
# 431              WI-08  5001800US5508                                  11.3
# 432              WV-01  5001800US5401                                  19.5
# 433              WV-02  5001800US5402                                  20.3
# 434              WY-AL  5001800US5600                                  21.1
#
#      CLASS OF WORKER - Private wage and salary workers  \
# 0                                                 67.8
# 1                                                 78.2
# 2                                                 76.2
# 3                                                 77.9
# 4                                                 80.4
# ..                                                 ...
# 430                                               79.1
# 431                                               83.2
# 432                                               75.3
# 433                                               75.2
# 434                                               71.7
#
#      CLASS OF WORKER - Self-employed in own not incorporated business workers  \
# 0                                                                         6.1
# 1                                                                         5.8
# 2                                                                         5.9
# 3                                                                         4.8
# 4                                                                         6.4
# ..                                                                        ...
# 430                                                                       7.4
# 431                                                                       5.3
# 432                                                                       4.8
# 433                                                                       4.3
# 434                                                                       6.9
#
#      CLASS OF WORKER - Unpaid family workers  \
# 0                                        0.3
# 1                                        0.0
# 2                                        0.2
# 3                                        0.1
# 4                                        0.0
# ..                                       ...
# 430                                      0.3
# 431                                      0.2
# 432                                      0.4
# 433                                      0.2
# 434                                      0.3
#
#      COMMUTING TO WORK - Car, truck, or van -- carpooled  \
# 0                                                   11.1
# 1                                                    6.7
# 2                                                    6.5
# 3                                                    8.3
# 4                                                    9.8
# ..                                                   ...
# 430                                                  8.2
# 431                                                  6.6
# 432                                                  9.1
# 433                                                  8.6
# 434                                                  9.2
#
#      COMMUTING TO WORK - Car, truck, or van -- drove alone  \
# 0                                                     66.2
# 1                                                     82.1
# 2                                                     85.2
# 3                                                     80.9
# 4                                                     83.4
# ..                                                     ...
# 430                                                   74.8
# 431                                                   75.6
# 432                                                   78.8
# 433                                                   75.7
# 434                                                   75.9
#
#      COMMUTING TO WORK - Mean travel time to work (minutes)  \
# 0                                                      19.8
# 1                                                      26.6
# 2                                                      24.1
# 3                                                      26.0
# 4                                                      25.2
# ..                                                      ...
# 430                                                    22.3
# 431                                                    21.1
# 432                                                    24.9
# 433                                                    26.4
# 434                                                    18.3
#
#      COMMUTING TO WORK - Other means  ...  INDUSTRY - Public administration  \
# 0                                4.8  ...                              12.2
# 1                                1.1  ...                               5.0
# 2                                1.2  ...                               7.8
# 3                                1.4  ...                               4.6
# 4                                0.4  ...                               3.3
# ..                               ...  ...                               ...
# 430                              1.5  ...                               4.0
# 431                              1.6  ...                               3.3
# 432                              1.2  ...                               6.4
# 433                              1.4  ...                               6.8
# 434                              1.8  ...                               6.9
#
#      INDUSTRY - Retail trade  \
# 0                       10.1
# 1                       13.4
# 2                       11.7
# 3                       11.2
# 4                       13.5
# ..                       ...
# 430                     11.0
# 431                     10.3
# 432                     11.8
# 433                     12.2
# 434                     11.8
#
#      INDUSTRY - Transportation and warehousing, and utilities  \
# 0                                                         9.4
# 1                                                         5.3
# 2                                                         7.0
# 3                                                         6.2
# 4                                                         6.1
# ..                                                        ...
# 430                                                       6.2
# 431                                                       5.5
# 432                                                       5.9
# 433                                                       5.9
# 434                                                       6.3
#
#      INDUSTRY - Wholesale trade  \
# 0                           1.2
# 1                           2.6
# 2                           2.1
# 3                           1.4
# 4                           2.3
# ..                          ...
# 430                         2.4
# 431                         2.4
# 432                         2.2
# 433                         1.6
# 434                         1.7
#
#      OCCUPATION - Management, business, science, and arts occupations  \
# 0                                                                39.9
# 1                                                                33.9
# 2                                                                33.7
# 3                                                                35.2
# 4                                                                31.2
# ..                                                                ...
# 430                                                              35.1
# 431                                                              38.3
# 432                                                              36.3
# 433                                                              37.9
# 434                                                              37.3
#
#      OCCUPATION - Natural resources, construction, and maintenance occupations  \
# 0                                                                         10.7
# 1                                                                         10.6
# 2                                                                          9.5
# 3                                                                         10.4
# 4                                                                         11.3
# ..                                                                         ...
# 430                                                                       10.8
# 431                                                                       10.3
# 432                                                                       10.4
# 433                                                                       10.0
# 434                                                                       14.1
#
#      OCCUPATION - Production, transportation, and material moving occupations  \
# 0                                                                        13.7
# 1                                                                        15.7
# 2                                                                        19.1
# 3                                                                        17.0
# 4                                                                        22.5
# ..                                                                        ...
# 430                                                                      19.8
# 431                                                                      18.9
# 432                                                                      12.6
# 433                                                                      15.1
# 434                                                                      13.6
#
#      OCCUPATION - Sales and office occupations  \
# 0                                         18.4
# 1                                         22.0
# 2                                         22.0
# 3                                         20.6
# 4                                         19.4
# ..                                         ...
# 430                                       19.3
# 431                                       18.7
# 432                                       21.2
# 433                                       19.6
# 434                                       18.2
#
#      OCCUPATION - Service occupations  Total households
# 0                                17.2          271311.0
# 1                                17.8          284318.0
# 2                                15.7          278370.0
# 3                                16.8          278736.0
# 4                                15.6          271053.0
# ..                                ...               ...
# 430                              15.0          314894.0
# 431                              13.8          305166.0
# 432                              19.5          359332.0
# 433                              17.3          362869.0
# 434                              16.8          242763.0
#
# [435 rows x 135 columns]

# %% [markdown]
# # _______________________________________________________________________________________________________________

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Now that all characteristic profiles have been consolidated, it's time to merge them all together into a mega dataframe combining all unique features for every congressional districts

# %%
#merge all the PERCENT dataframes

df_pct_merged = pd.merge(df_pctdemo_all, df_pcthousing_all, on=['Formatted_District', 'GEOID'])
df_pct_merged = pd.merge(df_pct_merged, df_pctsocial_all, on=['Formatted_District', 'GEOID'])
df_pct_merged = pd.merge(df_pct_merged, df_pctecon_all, on=['Formatted_District', 'GEOID'])
# check shape to ensure we maintained all 435 districts
print(df_pct_merged.head())
print(df_pct_merged.shape)
# Out:
#   Formatted_District          GEOID  \
# 0              AK-AL  5001800US0200
# 1              AL-01  5001800US0101
# 2              AL-02  5001800US0102
# 3              AL-03  5001800US0103
# 4              AL-04  5001800US0104
#
#    CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population  \
# 0                                                          533852.0
# 1                                                          555123.0
# 2                                                          539010.0
# 3                                                          558552.0
# 4                                                          541258.0
#
#    CITIZEN, VOTING AGE POPULATION - Female  \
# 0                                     47.3
# 1                                     52.2
# 2                                     52.8
# 3                                     51.8
# 4                                     51.9
#
#    CITIZEN, VOTING AGE POPULATION - Male  HISPANIC OR LATINO AND RACE - Cuban  \
# 0                                   52.7                                  0.4
# 1                                   47.8                                  0.2
# 2                                   47.2                                  0.1
# 3                                   48.2                                  0.1
# 4                                   48.1                                  0.2
#
#    HISPANIC OR LATINO AND RACE - Hispanic or Latino (of any race)  \
# 0                                                             7.1
# 1                                                             3.5
# 2                                                             4.1
# 3                                                             3.2
# 4                                                             7.3
#
#    HISPANIC OR LATINO AND RACE - Mexican  \
# 0                                    3.0
# 1                                    1.9
# 2                                    2.6
# 3                                    1.6
# 4                                    5.2
#
#    HISPANIC OR LATINO AND RACE - Other Hispanic or Latino  \
# 0                                                     2.5
# 1                                                     0.9
# 2                                                     0.8
# 3                                                     0.9
# 4                                                     1.7
#
#    HISPANIC OR LATINO AND RACE - Puerto Rican  ...  \
# 0                                         1.2  ...
# 1                                         0.4  ...
# 2                                         0.6  ...
# 3                                         0.6  ...
# 4                                         0.3  ...
#
#    INDUSTRY - Public administration  INDUSTRY - Retail trade  \
# 0                              12.2                     10.1
# 1                               5.0                     13.4
# 2                               7.8                     11.7
# 3                               4.6                     11.2
# 4                               3.3                     13.5
#
#    INDUSTRY - Transportation and warehousing, and utilities  \
# 0                                                       9.4
# 1                                                       5.3
# 2                                                       7.0
# 3                                                       6.2
# 4                                                       6.1
#
#    INDUSTRY - Wholesale trade  \
# 0                         1.2
# 1                         2.6
# 2                         2.1
# 3                         1.4
# 4                         2.3
#
#    OCCUPATION - Management, business, science, and arts occupations  \
# 0                                                              39.9
# 1                                                              33.9
# 2                                                              33.7
# 3                                                              35.2
# 4                                                              31.2
#
#    OCCUPATION - Natural resources, construction, and maintenance occupations  \
# 0                                                                       10.7
# 1                                                                       10.6
# 2                                                                        9.5
# 3                                                                       10.4
# 4                                                                       11.3
#
#    OCCUPATION - Production, transportation, and material moving occupations  \
# 0                                                                      13.7
# 1                                                                      15.7
# 2                                                                      19.1
# 3                                                                      17.0
# 4                                                                      22.5
#
#    OCCUPATION - Sales and office occupations  \
# 0                                       18.4
# 1                                       22.0
# 2                                       22.0
# 3                                       20.6
# 4                                       19.4
#
#    OCCUPATION - Service occupations  Total households
# 0                              17.2          271311.0
# 1                              17.8          284318.0
# 2                              15.7          278370.0
# 3                              16.8          278736.0
# 4                              15.6          271053.0
#
# [5 rows x 461 columns]
# (435, 461)

# %%
#merge all the RAW NUMBER (PRF) dataframes

df_prf_merged = pd.merge(df_prfdemo_all, df_prfhousing_all, on=['Formatted_District', 'GEOID'])
df_prf_merged = pd.merge(df_prf_merged, df_prfsocial_all, on=['Formatted_District', 'GEOID'])
df_prf_merged = pd.merge(df_prf_merged, df_prfecon_all, on=['Formatted_District', 'GEOID'])
# check shape to ensure we maintained all 435 districts
print(df_prf_merged.head())
print(df_prf_merged.shape)
# Out:
#   Formatted_District          GEOID  \
# 0              AK-AL  5001800US0200
# 1              AL-01  5001800US0101
# 2              AL-02  5001800US0102
# 3              AL-03  5001800US0103
# 4              AL-04  5001800US0104
#
#    CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population  \
# 0                                                          533852.0
# 1                                                          555123.0
# 2                                                          539010.0
# 3                                                          558552.0
# 4                                                          541258.0
#
#    CITIZEN, VOTING AGE POPULATION - Female  \
# 0                                 252485.0
# 1                                 289663.0
# 2                                 284652.0
# 3                                 289423.0
# 4                                 280884.0
#
#    CITIZEN, VOTING AGE POPULATION - Male  HISPANIC OR LATINO AND RACE - Cuban  \
# 0                               281367.0                               3182.0
# 1                               265460.0                               1480.0
# 2                               254358.0                                479.0
# 3                               269129.0                                766.0
# 4                               260374.0                               1322.0
#
#    HISPANIC OR LATINO AND RACE - Hispanic or Latino (of any race)  \
# 0                                                         52291.0
# 1                                                         25346.0
# 2                                                         29072.0
# 3                                                         22960.0
# 4                                                         52766.0
#
#    HISPANIC OR LATINO AND RACE - Mexican  \
# 0                                22299.0
# 1                                14082.0
# 2                                18554.0
# 3                                11728.0
# 4                                37454.0
#
#    HISPANIC OR LATINO AND RACE - Other Hispanic or Latino  \
# 0                                                 18157.0
# 1                                                  6571.0
# 2                                                  5484.0
# 3                                                  6468.0
# 4                                                 11988.0
#
#    HISPANIC OR LATINO AND RACE - Puerto Rican  ...  \
# 0                                      8653.0  ...
# 1                                      3213.0  ...
# 2                                      4555.0  ...
# 3                                      3998.0  ...
# 4                                      2002.0  ...
#
#    INDUSTRY - Public administration  INDUSTRY - Retail trade  \
# 0                           40054.0                  33233.0
# 1                           15685.0                  41999.0
# 2                           23376.0                  34878.0
# 3                           13598.0                  32975.0
# 4                           10153.0                  41709.0
#
#    INDUSTRY - Transportation and warehousing, and utilities  \
# 0                                                   30863.0
# 1                                                   16722.0
# 2                                                   20794.0
# 3                                                   18177.0
# 4                                                   18947.0
#
#    INDUSTRY - Wholesale trade  \
# 0                      4026.0
# 1                      8131.0
# 2                      6156.0
# 3                      4214.0
# 4                      7008.0
#
#    OCCUPATION - Management, business, science, and arts occupations  \
# 0                                                          130810.0
# 1                                                          106525.0
# 2                                                          100393.0
# 3                                                          103569.0
# 4                                                           96097.0
#
#    OCCUPATION - Natural resources, construction, and maintenance occupations  \
# 0                                                                    35248.0
# 1                                                                    33295.0
# 2                                                                    28405.0
# 3                                                                    30712.0
# 4                                                                    34778.0
#
#    OCCUPATION - Production, transportation, and material moving occupations  \
# 0                                                                   45060.0
# 1                                                                   49331.0
# 2                                                                   56946.0
# 3                                                                   50175.0
# 4                                                                   69378.0
#
#    OCCUPATION - Sales and office occupations  \
# 0                                    60360.0
# 1                                    69133.0
# 2                                    65422.0
# 3                                    60570.0
# 4                                    59951.0
#
#    OCCUPATION - Service occupations  Total households
# 0                           56475.0          271311.0
# 1                           55745.0          284318.0
# 2                           46705.0          278370.0
# 3                           49403.0          278736.0
# 4                           48190.0          271053.0
#
# [5 rows x 461 columns]
# (435, 461)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_pct_merged.to_csv('data/ACS_Surveys_MERGED_Percentages.csv')
df_prf_merged.to_csv('data/ACS_Surveys_MERGED_Population.csv')

# %% [markdown]
# # _______________________________________________________________________________________________________________

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 6.a - Partisan Lean
# ### The first target integrated into the ACS Megaframe is the partisan lean of a district. This is quantified by the Partisan Voter Index (PVI-score), developed by [The Cook Political Report](https://www.cookpolitical.com/). The PVI-score is derived from the district's voting behavior in the two most recent presidential elections (2020 and 2016), with the latter election weighted more heavily.
# ### The specific PVI data incorporated is available [here](https://www.cookpolitical.com/cook-pvi/2a023-partisan-voting-index/118-district-map-and-list).

# %%
pvi_df = pd.read_csv('data/2023_PVI.csv')

# %%
def convert_pvi(pvi):
    # Check if the value is a string
    if isinstance(pvi, str):
        # Check the first character and convert the remainder of the string to a number
        if pvi[0] == 'D':
            return float(pvi[2:])
        elif pvi[0] == 'R':
            return -float(pvi[2:])
    # Return NaN for non-string values
    return float('nan')

# %%
pvi_df['2023 Raw PVI'] = pvi_df['2023 Raw PVI'].apply(convert_pvi)
pvi_df
# Out:
#       Dist    First        Last Party 2023 PVI  2023 Raw PVI  Rank
# 0    AL-01    Jerry        Carl     R     R+16        -16.47   366
# 1    AL-02    Barry       Moore     R     R+17        -17.32   373
# 2    AL-03     Mike      Rogers     R     R+19        -19.36   393
# 3    AL-04   Robert    Aderholt     R     R+33        -33.24   435
# 4    AL-05     Dale      Strong     R     R+17        -16.67   370
# ..     ...      ...         ...   ...      ...           ...   ...
# 430  WI-05    Scott  Fitzgerald     R     R+14        -14.29   342
# 431  WI-06    Glenn    Grothman     R     R+10        -10.24   294
# 432  WI-07      Tom     Tiffany     R     R+12        -12.27   315
# 433  WI-08     Mike   Gallagher     R     R+10        -10.16   293
# 434  WY-AL  Harriet     Hageman     R     R+25        -25.27   426
#
# [435 rows x 7 columns]

# %%
pvi_df['Representative'] = pvi_df['Last'] + ", " + pvi_df['First']
pvi_df.head()
# Out:
#     Dist   First      Last Party 2023 PVI  2023 Raw PVI  Rank  \
# 0  AL-01   Jerry      Carl     R     R+16        -16.47   366
# 1  AL-02   Barry     Moore     R     R+17        -17.32   373
# 2  AL-03    Mike    Rogers     R     R+19        -19.36   393
# 3  AL-04  Robert  Aderholt     R     R+33        -33.24   435
# 4  AL-05    Dale    Strong     R     R+17        -16.67   370
#
#      Representative
# 0       Carl, Jerry
# 1      Moore, Barry
# 2      Rogers, Mike
# 3  Aderholt, Robert
# 4      Strong, Dale

# %%
pvi_df  = pvi_df[['Dist','Representative','2023 Raw PVI']]

# %%
pvi_df = pvi_df.rename(columns={'Dist': 'Formatted_District', '2023 Raw PVI': 'PVI_2023'})

# %%
pvi_df
# Out:
#     Formatted_District     Representative  PVI_2023
# 0                AL-01        Carl, Jerry    -16.47
# 1                AL-02       Moore, Barry    -17.32
# 2                AL-03       Rogers, Mike    -19.36
# 3                AL-04   Aderholt, Robert    -33.24
# 4                AL-05       Strong, Dale    -16.67
# ..                 ...                ...       ...
# 430              WI-05  Fitzgerald, Scott    -14.29
# 431              WI-06    Grothman, Glenn    -10.24
# 432              WI-07       Tiffany, Tom    -12.27
# 433              WI-08    Gallagher, Mike    -10.16
# 434              WY-AL   Hageman, Harriet    -25.27
#
# [435 rows x 3 columns]

# %%
pvi_prf_df= pd.merge(df_prf_merged, pvi_df, on=['Formatted_District'])

# %%
pvi_pct_df= pd.merge(df_pct_merged, pvi_df, on=['Formatted_District'])

# %%
pvi_pct_df
# Out:
#     Formatted_District          GEOID  \
# 0                AK-AL  5001800US0200
# 1                AL-01  5001800US0101
# 2                AL-02  5001800US0102
# 3                AL-03  5001800US0103
# 4                AL-04  5001800US0104
# ..                 ...            ...
# 430              WI-07  5001800US5507
# 431              WI-08  5001800US5508
# 432              WV-01  5001800US5401
# 433              WV-02  5001800US5402
# 434              WY-AL  5001800US5600
#
#      CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population  \
# 0                                                            533852.0
# 1                                                            555123.0
# 2                                                            539010.0
# 3                                                            558552.0
# 4                                                            541258.0
# ..                                                                ...
# 430                                                          579658.0
# 431                                                          562233.0
# 432                                                          696591.0
# 433                                                          712176.0
# 434                                                          436049.0
#
#      CITIZEN, VOTING AGE POPULATION - Female  \
# 0                                       47.3
# 1                                       52.2
# 2                                       52.8
# 3                                       51.8
# 4                                       51.9
# ..                                       ...
# 430                                     49.1
# 431                                     50.1
# 432                                     51.3
# 433                                     50.1
# 434                                     49.1
#
#      CITIZEN, VOTING AGE POPULATION - Male  \
# 0                                     52.7
# 1                                     47.8
# 2                                     47.2
# 3                                     48.2
# 4                                     48.1
# ..                                     ...
# 430                                   50.9
# 431                                   49.9
# 432                                   48.7
# 433                                   49.9
# 434                                   50.9
#
#      HISPANIC OR LATINO AND RACE - Cuban  \
# 0                                    0.4
# 1                                    0.2
# 2                                    0.1
# 3                                    0.1
# 4                                    0.2
# ..                                   ...
# 430                                  0.1
# 431                                  0.1
# 432                                  0.0
# 433                                  0.1
# 434                                  0.0
#
#      HISPANIC OR LATINO AND RACE - Hispanic or Latino (of any race)  \
# 0                                                               7.1
# 1                                                               3.5
# 2                                                               4.1
# 3                                                               3.2
# 4                                                               7.3
# ..                                                              ...
# 430                                                             2.6
# 431                                                             6.0
# 432                                                             1.1
# 433                                                             2.3
# 434                                                            10.6
#
#      HISPANIC OR LATINO AND RACE - Mexican  \
# 0                                      3.0
# 1                                      1.9
# 2                                      2.6
# 3                                      1.6
# 4                                      5.2
# ..                                     ...
# 430                                    1.5
# 431                                    4.0
# 432                                    0.4
# 433                                    0.8
# 434                                    7.5
#
#      HISPANIC OR LATINO AND RACE - Other Hispanic or Latino  \
# 0                                                       2.5
# 1                                                       0.9
# 2                                                       0.8
# 3                                                       0.9
# 4                                                       1.7
# ..                                                      ...
# 430                                                     0.7
# 431                                                     1.1
# 432                                                     0.4
# 433                                                     1.0
# 434                                                     2.7
#
#      HISPANIC OR LATINO AND RACE - Puerto Rican  ...  \
# 0                                           1.2  ...
# 1                                           0.4  ...
# 2                                           0.6  ...
# 3                                           0.6  ...
# 4                                           0.3  ...
# ..                                          ...  ...
# 430                                         0.3  ...
# 431                                         0.9  ...
# 432                                         0.2  ...
# 433                                         0.4  ...
# 434                                         0.3  ...
#
#      INDUSTRY - Transportation and warehousing, and utilities  \
# 0                                                         9.4
# 1                                                         5.3
# 2                                                         7.0
# 3                                                         6.2
# 4                                                         6.1
# ..                                                        ...
# 430                                                       6.2
# 431                                                       5.5
# 432                                                       5.9
# 433                                                       5.9
# 434                                                       6.3
#
#      INDUSTRY - Wholesale trade  \
# 0                           1.2
# 1                           2.6
# 2                           2.1
# 3                           1.4
# 4                           2.3
# ..                          ...
# 430                         2.4
# 431                         2.4
# 432                         2.2
# 433                         1.6
# 434                         1.7
#
#      OCCUPATION - Management, business, science, and arts occupations  \
# 0                                                                39.9
# 1                                                                33.9
# 2                                                                33.7
# 3                                                                35.2
# 4                                                                31.2
# ..                                                                ...
# 430                                                              35.1
# 431                                                              38.3
# 432                                                              36.3
# 433                                                              37.9
# 434                                                              37.3
#
#      OCCUPATION - Natural resources, construction, and maintenance occupations  \
# 0                                                                         10.7
# 1                                                                         10.6
# 2                                                                          9.5
# 3                                                                         10.4
# 4                                                                         11.3
# ..                                                                         ...
# 430                                                                       10.8
# 431                                                                       10.3
# 432                                                                       10.4
# 433                                                                       10.0
# 434                                                                       14.1
#
#      OCCUPATION - Production, transportation, and material moving occupations  \
# 0                                                                        13.7
# 1                                                                        15.7
# 2                                                                        19.1
# 3                                                                        17.0
# 4                                                                        22.5
# ..                                                                        ...
# 430                                                                      19.8
# 431                                                                      18.9
# 432                                                                      12.6
# 433                                                                      15.1
# 434                                                                      13.6
#
#      OCCUPATION - Sales and office occupations  \
# 0                                         18.4
# 1                                         22.0
# 2                                         22.0
# 3                                         20.6
# 4                                         19.4
# ..                                         ...
# 430                                       19.3
# 431                                       18.7
# 432                                       21.2
# 433                                       19.6
# 434                                       18.2
#
#      OCCUPATION - Service occupations  Total households    Representative  \
# 0                                17.2          271311.0     Peltola, Mary
# 1                                17.8          284318.0       Carl, Jerry
# 2                                15.7          278370.0      Moore, Barry
# 3                                16.8          278736.0      Rogers, Mike
# 4                                15.6          271053.0  Aderholt, Robert
# ..                                ...               ...               ...
# 430                              15.0          314894.0      Tiffany, Tom
# 431                              13.8          305166.0   Gallagher, Mike
# 432                              19.5          359332.0     Miller, Carol
# 433                              17.3          362869.0      Mooney, Alex
# 434                              16.8          242763.0  Hageman, Harriet
#
#      PVI_2023
# 0       -8.02
# 1      -16.47
# 2      -17.32
# 3      -19.36
# 4      -33.24
# ..        ...
# 430    -12.27
# 431    -10.16
# 432    -23.23
# 433    -21.52
# 434    -25.27
#
# [435 rows x 463 columns]

# %%
pvi_prf_df.to_csv('raw_2023_PVI_ACS.csv')

# %% [markdown]
# # 6.b - 2022 Midterm Election Results
#
# ### The second target involves analyzing voter behavior in 2022, focusing on exact vote totals and margins of victory for each congressional district. This data was compiled by [Daily Kos](https://www.dailykos.com/) and serves as a crucial component for understanding recent electoral dynamics.
#
# ### The detailed dataset is accessible [here](https://docs.google.com/spreadsheets/d/1zBk-LakSmWl3i4jdQ0_efpfj9LVCHMCDcfPxWQhrZeE/edit#gid=1178631925).

# %%
results_2022_metrics = pd.read_csv('data/2022_house_results.csv')

# %%
results_2022_metrics
# Out:
#     Formatted_District                  Rep           Status Dem Votes  \
# 0                AK-AL     Mary Peltola (D)  Democratic hold   137,263
# 1                AL-01       Jerry Carl (R)  Republican hold       NaN
# 2                AL-02      Barry Moore (R)  Republican hold    58,014
# 3                AL-03      Mike Rogers (R)  Republican hold    47,859
# 4                AL-04  Robert Aderholt (R)  Republican hold    26,694
# ..                 ...                  ...              ...       ...
# 430              WI-07      Tom Tiffany (R)  Republican hold   128,877
# 431              WI-08   Mike Gallagher (R)  Republican hold     5,320
# 432              WV-01     Carol Miller (R)  Republican hold    65,428
# 433              WV-02      Alex Mooney (R)  Republican hold    84,278
# 434              WY-AL  Harriet Hageman (R)  Republican hold    47,250
#
#     Rep Votes Other Votes  Dem %  Rep % Other % 2022 Margin  \
# 0     112,471           0  55.0%  45.0%    0.0%       D+9.9
# 1     140,592      27,558   0.0%  83.6%   16.4%      R+83.6
# 2     137,460       3,487  29.2%  69.1%    1.8%      R+39.9
# 3     135,602       6,945  25.1%  71.2%    3.6%      R+46.1
# 4     164,655       4,384  13.6%  84.1%    2.2%      R+70.5
# ..        ...         ...    ...    ...     ...         ...
# 430   209,224         167  38.1%  61.9%    0.0%      R+23.8
# 431   223,981      78,928   1.7%  72.7%   25.6%      R+70.9
# 432   151,511      10,257  28.8%  66.7%    4.5%      R+37.9
# 433   160,493           0  34.4%  65.6%    0.0%      R+31.1
# 434   132,206      14,446  24.4%  68.2%    7.5%      R+43.8
#
#     Swing from 2020 presidential Percent of 2020 turnout
# 0                           D+20                     70%
# 1                         R+55.4                     51%
# 2                         R+10.6                     62%
# 3                         R+12.1                     60%
# 4                          R+8.8                     60%
# ..                           ...                     ...
# 430                        R+3.8                     80%
# 431                       R+55.5                     75%
# 432                          D+3                     58%
# 433                        D+5.9                     61%
# 434                        R+0.5                     70%
#
# [435 rows x 12 columns]

# %%
results_2022_metrics['2022 Margin'] = results_2022_metrics['2022 Margin'].apply(convert_pvi)
results_2022_metrics['Swing from 2020 presidential'] = \
results_2022_metrics['Swing from 2020 presidential'].apply(convert_pvi)

# %%
num_nan_dem = results_2022_metrics['Dem Votes'].isna().sum()
print(num_nan_dem)
num_nan_rep = results_2022_metrics['Rep Votes'].isna().sum()
print(num_nan_rep)
# Out:
# 9
# 10

# %%
num_zero_dem = (results_2022_metrics['Dem Votes'] == 0).sum()
print(num_zero_dem)

num_zero_rep = (results_2022_metrics['Rep Votes'] == 0).sum()
print(num_zero_rep)
# Out:
# 0
# 0

# %%
# Replacing NaN values with 0's in races that ran unopposed
results_2022_metrics = results_2022_metrics.fillna({'Dem Votes': 0, 'Rep Votes': 0})

# Remove '%' and ',' then convert to float
cols = ['Dem %', 'Rep %', 'Other %','Dem Votes', 'Rep Votes', 'Other Votes']
for col in cols:
    results_2022_metrics.loc[:, col] = results_2022_metrics.loc[:, col].astype(str).str.replace('%', '').str.replace(',', '').astype(float)

# %%
results_2022_metrics['Dem Votes'].isna().sum()
# Out:
# 0

# %%
results_2022_metrics
# Out:
#     Formatted_District                  Rep           Status Dem Votes  \
# 0                AK-AL     Mary Peltola (D)  Democratic hold  137263.0
# 1                AL-01       Jerry Carl (R)  Republican hold       0.0
# 2                AL-02      Barry Moore (R)  Republican hold   58014.0
# 3                AL-03      Mike Rogers (R)  Republican hold   47859.0
# 4                AL-04  Robert Aderholt (R)  Republican hold   26694.0
# ..                 ...                  ...              ...       ...
# 430              WI-07      Tom Tiffany (R)  Republican hold  128877.0
# 431              WI-08   Mike Gallagher (R)  Republican hold    5320.0
# 432              WV-01     Carol Miller (R)  Republican hold   65428.0
# 433              WV-02      Alex Mooney (R)  Republican hold   84278.0
# 434              WY-AL  Harriet Hageman (R)  Republican hold   47250.0
#
#     Rep Votes Other Votes Dem % Rep % Other %  2022 Margin  \
# 0    112471.0         0.0  55.0  45.0     0.0          9.9
# 1    140592.0     27558.0   0.0  83.6    16.4        -83.6
# 2    137460.0      3487.0  29.2  69.1     1.8        -39.9
# 3    135602.0      6945.0  25.1  71.2     3.6        -46.1
# 4    164655.0      4384.0  13.6  84.1     2.2        -70.5
# ..        ...         ...   ...   ...     ...          ...
# 430  209224.0       167.0  38.1  61.9     0.0        -23.8
# 431  223981.0     78928.0   1.7  72.7    25.6        -70.9
# 432  151511.0     10257.0  28.8  66.7     4.5        -37.9
# 433  160493.0         0.0  34.4  65.6     0.0        -31.1
# 434  132206.0     14446.0  24.4  68.2     7.5        -43.8
#
#      Swing from 2020 presidential Percent of 2020 turnout
# 0                            20.0                     70%
# 1                           -55.4                     51%
# 2                           -10.6                     62%
# 3                           -12.1                     60%
# 4                            -8.8                     60%
# ..                            ...                     ...
# 430                          -3.8                     80%
# 431                         -55.5                     75%
# 432                           3.0                     58%
# 433                           5.9                     61%
# 434                          -0.5                     70%
#
# [435 rows x 12 columns]

# %%
fulldata_pct_df= pd.merge(pvi_pct_df, results_2022_metrics, on=['Formatted_District'])
fulldata_prf_df= pd.merge(pvi_prf_df, results_2022_metrics, on=['Formatted_District'])

# %% [markdown]
# # _________________________________________________________________________

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 7.a - deleting duplicated columns and dealing with NaN values

# %%
# duplicated columns between datsets
columns_to_delete = [
    'HOUSING OCCUPANCY - Total housing units',
    'PLACE OF BIRTH - Total population',
    'EMPLOYMENT STATUS - Population 16 years and over',
    'HOUSING OCCUPANCY - Occupied housing units',
    'COMPUTERS AND INTERNET USE - Total households',
    'Population in households - Householder',
    'Population born outside the United States - Native',
    'Total Civilian Noninstitutionalized Population'
]


# deleting the columns
fulldata_pct_df = fulldata_pct_df.drop(columns=columns_to_delete)
fulldata_prf_df = fulldata_prf_df.drop(columns=columns_to_delete)

# %%
# Identify numeric columns
numeric_cols_prf = fulldata_prf_df.select_dtypes(include=np.number).columns.tolist()
numeric_cols_pct = fulldata_pct_df.select_dtypes(include=np.number).columns.tolist()

# Replace NaNs in numeric columns with their median
fulldata_prf_df.loc[:, numeric_cols_prf] = fulldata_prf_df.loc[:, numeric_cols_prf].fillna(fulldata_prf_df[numeric_cols_prf].median())
fulldata_pct_df.loc[:, numeric_cols_pct] = fulldata_pct_df.loc[:, numeric_cols_pct].fillna(fulldata_pct_df[numeric_cols_pct].median())

# %%
# Replace NaNs in 'Other Votes' with 0
fulldata_prf_df['Other Votes'].fillna(0, inplace=True)
fulldata_pct_df['Other Votes'].fillna(0, inplace=True)

# Find columns with more than 100 NaNs
cols_to_drop_prf = fulldata_prf_df.columns[fulldata_prf_df.isnull().sum() > 100].tolist()
cols_to_drop_pct = fulldata_pct_df.columns[fulldata_pct_df.isnull().sum() > 100].tolist()

# # Exclude 'Other Votes' from the list
cols_to_drop_prf = [col for col in cols_to_drop_prf if col != 'Other Votes']
cols_to_drop_pct = [col for col in cols_to_drop_pct if col != 'Other Votes']
# cols_to_drop_prf = [col for col in cols_to_drop_prf]
# cols_to_drop_pct = [col for col in cols_to_drop_pct]

# Drop these columns
fulldata_prf_df.drop(columns=cols_to_drop_prf, inplace=True)
fulldata_pct_df.drop(columns=cols_to_drop_pct, inplace=True)

# For 'RACE - ...' and 'LANGUAGE SPOKEN AT HOME...' categories, replace NaNs with 0
race_language_cols_prf = [col for col in fulldata_prf_df if 'RACE -' in col or 'LANGUAGE SPOKEN AT HOME' in col]
race_language_cols_pct = [col for col in fulldata_pct_df if 'RACE -' in col or 'LANGUAGE SPOKEN AT HOME' in col]

fulldata_prf_df[race_language_cols_prf] = fulldata_prf_df[race_language_cols_prf].fillna(0)
fulldata_pct_df[race_language_cols_pct] = fulldata_pct_df[race_language_cols_pct].fillna(0)

# For the remaining numeric columns, replace NaNs with the column's median
fulldata_prf_df.loc[:, numeric_cols_prf] = fulldata_prf_df.loc[:, numeric_cols_prf].fillna(fulldata_prf_df[numeric_cols_prf].median())
fulldata_pct_df.loc[:, numeric_cols_pct] = fulldata_pct_df.loc[:, numeric_cols_pct].fillna(fulldata_pct_df[numeric_cols_pct].median())

# %%
fulldata_pct_df.shape
# Out:
# (435, 466)

# %%
fulldata_prf_df.shape
# Out:
# (435, 466)

# %% [markdown]
# # 7.b Add on State-level PVI info

# %%
# Load the data
state_pvi_df = pd.read_csv('data/2022 State PVI.csv')

# Convert %'s to numeric
# Remove the "%" character and convert to numeric type
for col in ["2020 Biden %", "2020 Trump %", "2016 Clinton %", "2016 Trump %"]:
    state_pvi_df[col] = state_pvi_df[col].str.replace("%", "").astype(float)
    
# Create new column for the state overall 2020 and 2016 performance
state_pvi_df["2020 State Diff"] = state_pvi_df["2020 Biden %"] - state_pvi_df["2020 Trump %"]
state_pvi_df["2016 State Diff"] = state_pvi_df["2016 Clinton %"] - state_pvi_df["2016 Trump %"]

# Convert state pvi with convert_pvi function
state_pvi_df['2022 State PVI'] = state_pvi_df['2022 State PVI'].apply(convert_pvi)

state_pvi_df.head()
# Out:
#         State  2022 State PVI  2020 Biden %  2020 Trump %  2016 Clinton %  \
# 0     Alabama           -15.0          36.6          62.0            34.4
# 1      Alaska            -8.0          42.8          52.8            36.6
# 2     Arizona            -2.0          49.4          49.1            44.6
# 3    Arkansas           -16.0          34.8          62.4            33.7
# 4  California            13.0          63.5          34.3            61.7
#
#    2016 Trump %  National 2020 Pres Popular %  National 2022 House Popular %  \
# 0          62.1                         4.539                         -2.183
# 1          51.3                         4.539                         -2.183
# 2          48.1                         4.539                         -2.183
# 3          60.6                         4.539                         -2.183
# 4          31.6                         4.539                         -2.183
#
#    2020 State Diff  2016 State Diff
# 0            -25.4            -27.7
# 1            -10.0            -14.7
# 2              0.3             -3.5
# 3            -27.6            -26.9
# 4             29.2             30.1

# %%
# Invert my states dictionary
state_mapping = {v: k for k, v in states.items()}

# Extract the state abbreviation and map it to the full state name
fulldata_pct_df['State'] = fulldata_pct_df['Formatted_District'].str.split('-').str[0].map(state_mapping)
fulldata_prf_df['State'] = fulldata_prf_df['Formatted_District'].str.split('-').str[0].map(state_mapping)

# Merge the two dataframes
fulldata_pct_df = pd.merge(fulldata_pct_df, state_pvi_df, on='State', how='left')
fulldata_prf_df = pd.merge(fulldata_prf_df, state_pvi_df, on='State', how='left')

# %%
drop_merge_cols = ['State']

fulldata_pct_df = fulldata_pct_df.drop(columns = drop_merge_cols)
fulldata_prf_df = fulldata_prf_df.drop(columns = drop_merge_cols)

# %%
fulldata_pct_df.to_csv('data/Full_Dataset_PCT.csv')
fulldata_prf_df.to_csv('data/Full_Dataset_PRF.csv')
